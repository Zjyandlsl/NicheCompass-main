# %%
# =========================================================
# n_sampled_neighbors 单参数敏感性分析
# 功能：每次只改变 n_sampled_neighbors，其它参数保持不变；
#      每个取值重新训练 NicheCompass -> 生成 TMCN 生态位 -> 计算 ARI -> 画曲线。
# 使用方式：直接复制到对应 notebook 的一个新 Cell 运行。
# =========================================================

import os
import sys
import gc
import random
import warnings
from io import StringIO

import numpy as np
import pandas as pd
import scipy.sparse as sp
import matplotlib.pyplot as plt

import anndata as ad
import scanpy as sc
import squidpy as sq
import decoupler as dc

from sklearn.preprocessing import MinMaxScaler
from sklearn.mixture import GaussianMixture
from sklearn.metrics import adjusted_rand_score
from scipy.stats import hypergeom
from statsmodels.stats.multitest import multipletests

warnings.filterwarnings("ignore")

# --------------------------
# 0. 当前数据集配置
# --------------------------
CONFIG = {'dataset_name': 'CRC_SN048_A121573_Rep1', 'input_h5ad': '/home/zhangjunyi/xiangmu/nichecompass-main/datasets/12_colorectal_cancer_CRC/12_colorectal_cancer_CRC_h5ad/SN048_A121573_Rep1.h5ad', 'gmm_threshold_csv_candidates': ['/home/zhangjunyi/xiangmu/nichecompass-main/outputs/test/colorectal_12_cancer_CRC/SN048_A121573_Rep1/SpaCET/GMM_Optimal_Threshold_Result.csv', '/home/zhangjunyi/xiangmu/nichecompass-main/outputs/colorectal_12_cancer_CRC/SN048_A121573_Rep1/SpaCET/GMM_Optimal_Threshold_Result.csv'], 'save_root': '/home/zhangjunyi/xiangmu/nichecompass-main/outputs/test/parameter_sensitivity/colorectal_12_cancer_CRC/SN048_A121573_Rep1/n_sampled_neighbors', 'file_prefix': 'SN048_A121573_Rep1', 'pathology_col_candidates': ['pathology_annotation'], 'gt_map': {'tumor': 1, 'tumor&stroma_IC med to high': 1, 'stroma_fibroblastic_IC high': 1, 'epithelium&submucosa': 0, 'non neo epithelium': 0, 'submucosa': 0, 'IC aggregregate_submucosa': 0, 'IC aggregate_submucosa': 0, 'IC aggregate connective tissue': 0}, 'n_epochs': 125, 'n_sampled_neighbors_range': [2, 4, 6, 8, 10, 12], 'seed': 42, 'local_src': '/home/zhangjunyi/xiangmu/nichecompass-main/src', 'nichenet_cache_dir': '/home/zhangjunyi/xiangmu/nichecompass-main/cache_nichenet', 'n_top_hvg': 3000, 'spatial_graph_n_neighs': 8, 'latent_key': 'nichecompass_latent', 'native_cluster_key': 'latent_leiden_0.6', 'leiden_resolution': 0.6, 'latent_node_batch_size': 128, 'low_malig_offset': 0.2, 'MIN_FC': 1.3, 'MIN_ACTIVE_SPOTS': 10, 'MIN_INTENSITY_RATIO': 1.2, 'QUIESCENT_COLD_AXIS_NUM': 6}

# --------------------------
# 1. 固定随机种子
# --------------------------
def set_seed(seed=42):
    os.environ["PYTHONHASHSEED"] = str(seed)
    os.environ["OMP_NUM_THREADS"] = "1"
    os.environ["MKL_NUM_THREADS"] = "1"
    os.environ["OPENBLAS_NUM_THREADS"] = "1"
    os.environ["NUMEXPR_NUM_THREADS"] = "1"
    os.environ["CUBLAS_WORKSPACE_CONFIG"] = ":4096:8"

    random.seed(seed)
    np.random.seed(seed)

    import torch
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    try:
        torch.use_deterministic_algorithms(True, warn_only=True)
    except Exception as e:
        print("deterministic warn_only 模式未完全启用：", e)
    torch.set_num_threads(1)

set_seed(CONFIG["seed"])

# --------------------------
# 2. 导入 NicheCompass
# --------------------------
LOCAL_SRC = CONFIG["local_src"]
if LOCAL_SRC not in sys.path:
    sys.path.insert(0, LOCAL_SRC)

import nichecompass as nc
import torch

print("✅ CUDA 可用状态:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("✅ 当前使用 GPU:", torch.cuda.get_device_name(0))
print("✅ NicheCompass 路径:", nc.__file__)
CONFIG["save_root"] = "/home/zhangjunyi/xiangmu/nichecompass-main/outputs/case/parameter_analysis/n_sampled_neighbors/SN048_A121573_Rep1"
os.makedirs(CONFIG["save_root"], exist_ok=True)
# Out:
# ✅ CUDA 可用状态: True
# ✅ 当前使用 GPU: A100 80GB PCIe
# ✅ NicheCompass 路径: /home/zhangjunyi/xiangmu/nichecompass-main/src/nichecompass/__init__.py

# %%
# --------------------------
# 3. TMCN 代谢通讯轴知识库
# 从外部四元组 CSV 文件读取
# --------------------------

tmcn_file_path = "/home/zhangjunyi/xiangmu/nichecompass-main/data/pre_data/siyuanzu/my_metabolite_network.csv"

if not os.path.exists(tmcn_file_path):
    raise FileNotFoundError(f"❌ 未找到四元组文件: {tmcn_file_path}")

axis_table = pd.read_csv(tmcn_file_path, encoding="utf-8-sig")

required_cols = [
    "TMCN_Name",
    "Source_Pathways",
    "Source_Genes",
    "Target_Genes",
    "Biologic_Meaning"
]

missing_cols = [c for c in required_cols if c not in axis_table.columns]
if len(missing_cols) > 0:
    raise ValueError(
        f"❌ 四元组文件缺少必要列: {missing_cols}\n"
        f"当前文件列名为: {axis_table.columns.tolist()}"
    )

axis_table["TMCN_Name"] = axis_table["TMCN_Name"].astype(str).str.strip()

AXES = [
    x.replace("TMCN_", "").replace("_Axis", "")
    for x in axis_table["TMCN_Name"]
]

print("✅ 已从外部 CSV 文件加载 TMCN 四元组知识库")
print(f"📄 文件路径: {tmcn_file_path}")
print(f"✅ 共加载 {len(axis_table)} 条代谢通讯轴")
print(f"✅ AXES = {AXES}")

display(axis_table)


def split_items(x):
    return [i.strip() for i in str(x).split(",") if i.strip()]


def get_valid_genes(adata_obj, genes):
    return [g for g in genes if g in adata_obj.var_names]


def read_gmm_threshold():
    for p in CONFIG["gmm_threshold_csv_candidates"]:
        if os.path.exists(p):
            gmm_df = pd.read_csv(p)
            val = float(gmm_df.loc[gmm_df["Metric"] == "Optimal_GMM_Threshold", "Value"].iloc[0])
            print(f"✅ 读取 GMM 阈值: {val:.4f} | {p}")
            return val
    raise FileNotFoundError("❌ 未找到 GMM_Optimal_Threshold_Result.csv，请检查 CONFIG['gmm_threshold_csv_candidates']。")


def find_malig_col(adata_obj):
    for c in ["Malignant", "malignant", "Tumor", "tumor", "Cancer", "cancer"]:
        if c in adata_obj.obs.columns:
            return c
    raise KeyError("❌ 未找到 SpaCET 恶性分数字段，如 Malignant。")


def find_pathology_col(adata_obj):
    for c in CONFIG["pathology_col_candidates"]:
        if c in adata_obj.obs.columns:
            return c
    raise KeyError(f"❌ 未找到病理注释列。候选列: {CONFIG['pathology_col_candidates']}\n当前列: {adata_obj.obs.columns.tolist()}")


# =========================================================
# A. 只计算一次：Sender / Receiver 分数
# =========================================================
def compute_sender_receiver_scores():
    print("\n=== A. 加载数据并计算 Sender / Receiver 分数 ===")
    adata_raw = sc.read_h5ad(CONFIG["input_h5ad"])
    print(f"✅ 数据加载成功: {adata_raw.n_obs} spots, {adata_raw.n_vars} genes")

    # PROGENy pathway score
    print("--> 计算 Pathway_score (PROGENy)...")
    net_progeny = dc.get_progeny(organism="human", top=500)
    dc.run_mlm(
        mat=adata_raw,
        net=net_progeny,
        source="source",
        target="target",
        weight="weight",
        verbose=False,
        use_raw=False
    )
    df_pathway = dc.get_acts(adata_raw, obsm_key="mlm_estimate").to_df()
    df_pathway.columns = [c.strip().replace("-", "_").replace(" ", "_") for c in df_pathway.columns]

    # AUCell enzyme score
    print("--> 计算 Enzyme_score (AUCell)...")
    enzyme_records = []
    for _, row in axis_table.iterrows():
        ax = row["TMCN_Name"].replace("TMCN_", "").replace("_Axis", "")
        for g in split_items(row["Source_Genes"]):
            if g in adata_raw.var_names:
                enzyme_records.append({"source": ax, "target": g})

    if len(enzyme_records) == 0:
        raise ValueError("❌ 当前数据中没有任何 TMCN Source_Genes，可检查基因名是否为 Gene Symbol。")

    dc.run_aucell(
        mat=adata_raw,
        net=pd.DataFrame(enzyme_records),
        source="source",
        target="target",
        min_n=1,
        verbose=False,
        use_raw=False
    )
    df_enzyme = dc.get_acts(adata_raw, obsm_key="aucell_estimate").to_df()

    scaler = MinMaxScaler()
    df_pathway_scaled = pd.DataFrame(
        scaler.fit_transform(df_pathway),
        index=df_pathway.index,
        columns=df_pathway.columns
    )
    df_enzyme_scaled = pd.DataFrame(
        scaler.fit_transform(df_enzyme),
        index=df_enzyme.index,
        columns=df_enzyme.columns
    )

    def calc_receptor_score(genes):
        valid = get_valid_genes(adata_raw, genes)
        if not valid:
            return np.zeros(adata_raw.n_obs)
        X_sub = adata_raw[:, valid].X
        if sp.issparse(X_sub):
            mean_exp = np.asarray(X_sub.mean(axis=1)).reshape(-1)
        else:
            mean_exp = np.asarray(X_sub).mean(axis=1).reshape(-1)
        return scaler.fit_transform(mean_exp.reshape(-1, 1)).flatten()

    print("--> 计算 Sender_score 与 Receiver_score...")
    for _, row in axis_table.iterrows():
        ax = row["TMCN_Name"].replace("TMCN_", "").replace("_Axis", "")
        pathways = [p.strip().replace("-", "_").replace(" ", "_") for p in split_items(row["Source_Pathways"])]
        target_genes = split_items(row["Target_Genes"])

        valid_paths = [p for p in pathways if p in df_pathway_scaled.columns]
        if len(valid_paths) > 0:
            p_score = df_pathway_scaled[valid_paths].mean(axis=1).values
        else:
            p_score = np.zeros(adata_raw.n_obs)

        if ax in df_enzyme_scaled.columns:
            e_score = df_enzyme_scaled[ax].values
        else:
            e_score = np.zeros(adata_raw.n_obs)

        adata_raw.obs[f"{ax}_Sender_Score"] = p_score * e_score
        adata_raw.obs[f"{ax}_Receiver_Score"] = calc_receptor_score(target_genes)

    print("✅ Sender / Receiver 分数计算完成。")
    return adata_raw


# =========================================================
# B. 每个参数值重新构建 adata_model 并训练
# =========================================================
def prepare_adata_model(adata_scored):
    adata_model = adata_scored.copy()

    sc.pp.filter_genes(adata_model, min_cells=10)
    sc.pp.highly_variable_genes(
        adata_model,
        n_top_genes=CONFIG["n_top_hvg"],
        flavor="seurat_v3",
        subset=False
    )

    tmcn_gene_set = set()
    for _, row in axis_table.iterrows():
        tmcn_gene_set.update(split_items(row["Source_Genes"]))
        tmcn_gene_set.update(split_items(row["Target_Genes"]))
    tmcn_gene_set = {g for g in tmcn_gene_set if g in adata_model.var_names}

    keep_mask = adata_model.var["highly_variable"].values | adata_model.var_names.isin(list(tmcn_gene_set))
    adata_model = adata_model[:, keep_mask].copy()

    counts_key = "counts" if "counts" in adata_model.layers else None
    x_for_lib = adata_model.layers[counts_key] if counts_key is not None else adata_model.X
    lib_size = np.asarray(x_for_lib.sum(axis=1)).reshape(-1)
    valid_spot_mask = np.isfinite(lib_size) & (lib_size > 0)
    adata_model = adata_model[valid_spot_mask].copy()

    mat = adata_model.layers.get(counts_key) if counts_key else adata_model.X
    if sp.issparse(mat):
        mat = mat.copy()
        mat.data = np.nan_to_num(mat.data, nan=0.0, posinf=0.0, neginf=0.0)
        mat.data = np.clip(mat.data, a_min=0, a_max=None)
    else:
        mat = np.nan_to_num(mat, nan=0.0, posinf=0.0, neginf=0.0)
        mat = np.clip(mat, a_min=0, a_max=None)

    if counts_key:
        adata_model.layers[counts_key] = mat
    else:
        adata_model.X = mat

    sq.gr.spatial_neighbors(
        adata_model,
        coord_type="generic",
        spatial_key="spatial",
        n_neighs=CONFIG["spatial_graph_n_neighs"]
    )

    cache_dir = CONFIG["nichenet_cache_dir"]
    gp_dict = nc.utils.extract_gp_dict_from_nichenet_lrt_interactions(
        species="human",
        version="v2",
        keep_target_genes_ratio=0.25,
        max_n_target_genes_per_gp=50,
        load_from_disk=True,
        lr_network_file_path=f"{cache_dir}/nichenet_lr_network.csv",
        ligand_target_matrix_file_path=f"{cache_dir}/nichenet_ligand_target_matrix.csv"
    )
    nc.utils.add_gps_from_gp_dict_to_adata(gp_dict=gp_dict, adata=adata_model)

    return adata_model, counts_key


def train_nichecompass(adata_model, counts_key, n_sampled_neighbors):
    latent_key = CONFIG["latent_key"]
    adj_key = "spatial_connectivities"

    model = nc.models.NicheCompass(
        adata_model,
        counts_key=counts_key,
        adj_key=adj_key,
        gp_names_key="nichecompass_gp_names",
        active_gp_names_key="nichecompass_active_gp_names",
        gp_targets_mask_key="nichecompass_gp_targets",
        gp_targets_categories_mask_key="nichecompass_gp_targets_categories",
        gp_sources_mask_key="nichecompass_gp_sources",
        gp_sources_categories_mask_key="nichecompass_gp_sources_categories",
        latent_key=latent_key,
        conv_layer_encoder="gcnconv",
        active_gp_thresh_ratio=0.01,
    )

    full_node_batch_size = adata_model.n_obs
    full_edge_batch_size = int(adata_model.obsp["spatial_connectivities"].nnz)

    print(f"  全量 nodes: {full_node_batch_size}")
    print(f"  全量 edges: {full_edge_batch_size}")

    model.train(
        n_epochs=CONFIG["n_epochs"],
        n_epochs_all_gps=10,
        lr=1e-4,
        lambda_edge_recon=1e5,
        lambda_gene_expr_recon=100.0,
        lambda_l1_masked=0.0,
        edge_batch_size=full_edge_batch_size,
        node_batch_size=full_node_batch_size,
        n_sampled_neighbors=n_sampled_neighbors,
        edge_val_ratio=0.0,
        node_val_ratio=0.0,
        use_cuda_if_available=True,
        verbose=False
    )

    adata_model.obsm[latent_key] = model.get_latent_representation(
        adata=adata_model,
        counts_key=counts_key,
        adj_key=adj_key,
        node_batch_size=CONFIG["latent_node_batch_size"],
    )

    sc.pp.neighbors(
        adata_model,
        use_rep=latent_key,
        key_added=latent_key,
        random_state=CONFIG["seed"]
    )
    sc.tl.umap(
        adata_model,
        neighbors_key=latent_key,
        random_state=CONFIG["seed"]
    )
    sc.tl.leiden(
        adata_model,
        neighbors_key=latent_key,
        key_added=CONFIG["native_cluster_key"],
        resolution=CONFIG["leiden_resolution"],
        random_state=CONFIG["seed"]
    )

    return adata_model, model


# =========================================================
# C. TMCN 生态位判定：复刻 Cell 7 核心逻辑
# =========================================================
def annotate_tmcn_niches(adata_model, hard_tumor_threshold):
    native_cluster_key = CONFIG["native_cluster_key"]
    adj_matrix = adata_model.obsp["spatial_connectivities"]

    # 1. Coupling Score
    for k in AXES:
        sender_scores = adata_model.obs[f"{k}_Sender_Score"].values
        receiver_scores = adata_model.obs[f"{k}_Receiver_Score"].values
        neighbor_receiver_sum = adj_matrix.dot(receiver_scores)
        raw_coupling = sender_scores * neighbor_receiver_sum
        adata_model.obs[f"Coupling_{k}"] = np.log1p(raw_coupling)

    # 2. 每条轴自适应阈值
    thresholds_dict = {}
    for k in AXES:
        scores = adata_model.obs[f"Coupling_{k}"].values
        scores_clean = scores[~np.isnan(scores) & (scores > 0)].reshape(-1, 1)
        t_high, t_quiet = None, None
        method_used = "Robust Dynamic Fallback"

        if len(scores_clean) > 50:
            try:
                gmm = GaussianMixture(n_components=2, random_state=CONFIG["seed"])
                labels = gmm.fit_predict(scores_clean)
                m0, m1 = gmm.means_[0][0], gmm.means_[1][0]
                s0 = np.sqrt(gmm.covariances_[0][0][0])
                s1 = np.sqrt(gmm.covariances_[1][0][0])
                if abs(m0 - m1) > 0.8 * np.std(scores_clean):
                    if m0 > m1:
                        t_high = np.min(scores_clean[labels == 0])
                        t_quiet = m1 + s1
                    else:
                        t_high = np.min(scores_clean[labels == 1])
                        t_quiet = m0 + s0
                    method_used = "GMM (2-Components)"
            except Exception:
                pass

        if t_high is None:
            mean_val = np.mean(scores)
            std_val = np.std(scores)
            t_high_candidate_1 = mean_val + 1.5 * std_val
            t_high_candidate_2 = np.quantile(scores, 0.95)
            t_high = max(t_high_candidate_1, t_high_candidate_2)
            t_quiet = mean_val

        if t_high < 0.15:
            t_high = np.inf

        thresholds_dict[k] = {"T_high": t_high, "T_quiet": t_quiet, "Method": method_used}
        adata_model.obs[f"Active_{k}"] = (scores >= t_high).astype(int)
        adata_model.obs[f"Quiet_{k}"] = (scores <= t_quiet).astype(int)

    # 3. low_malig_gate
    malig_col = find_malig_col(adata_model)
    low_malig_gate = max(0.0, hard_tumor_threshold - CONFIG["low_malig_offset"])
    adata_model.obs["Keep_By_LowMalig"] = (adata_model.obs[malig_col].astype(float).values >= low_malig_gate).astype(int)

    # 4. cluster 级统计富集
    M_global = adata_model.n_obs
    bg_active_counts = {k: int(adata_model.obs[f"Active_{k}"].sum()) for k in AXES}
    bg_quiet_counts = {k: int(adata_model.obs[f"Quiet_{k}"].sum()) for k in AXES}
    bg_active_fracs = {k: bg_active_counts[k] / M_global for k in AXES}
    bg_quiet_fracs = {k: bg_quiet_counts[k] / M_global for k in AXES}
    global_mean_scores = {k: adata_model.obs[f"Coupling_{k}"].mean() for k in AXES}

    native_clusters = sorted(adata_model.obs[native_cluster_key].astype(str).unique())
    pvals_active_dict = {k: [] for k in AXES}
    pvals_quiet_dict = {k: [] for k in AXES}

    for k in AXES:
        adata_model.obs[f"{k}_Cluster_Active_Frac"] = 0.0

    for c in native_clusters:
        c_mask = adata_model.obs[native_cluster_key].astype(str) == str(c)
        N_cluster = int(c_mask.sum())
        for k in AXES:
            k_obs_act = int(adata_model.obs.loc[c_mask, f"Active_{k}"].sum())
            k_obs_qui = int(adata_model.obs.loc[c_mask, f"Quiet_{k}"].sum())
            act_frac = k_obs_act / N_cluster if N_cluster > 0 else 0.0
            adata_model.obs.loc[c_mask, f"{k}_Cluster_Active_Frac"] = act_frac
            pval_a = hypergeom.sf(k_obs_act - 1, M_global, bg_active_counts[k], N_cluster) if k_obs_act > 0 else 1.0
            pval_q = hypergeom.sf(k_obs_qui - 1, M_global, bg_quiet_counts[k], N_cluster) if k_obs_qui > 0 else 1.0
            pvals_active_dict[k].append(pval_a)
            pvals_quiet_dict[k].append(pval_q)

    fdr_active_dict = {}
    for k in AXES:
        _, fdr_a, _, _ = multipletests(pvals_active_dict[k], method="fdr_bh")
        fdr_active_dict[k] = fdr_a

    cluster_annotations = {}
    cluster_stats = []
    for idx, c in enumerate(native_clusters):
        c_mask = adata_model.obs[native_cluster_key].astype(str) == str(c)
        N_cluster = int(c_mask.sum())
        sig_active_axes = []
        cold_axes = []

        for k in AXES:
            act_frac = float(adata_model.obs.loc[c_mask, f"{k}_Cluster_Active_Frac"].iloc[0]) if N_cluster > 0 else 0.0
            qui_frac = float(adata_model.obs.loc[c_mask, f"Quiet_{k}"].sum() / N_cluster) if N_cluster > 0 else 0.0
            k_obs_act = int(adata_model.obs.loc[c_mask, f"Active_{k}"].sum())
            cluster_mean_score = float(adata_model.obs.loc[c_mask, f"Coupling_{k}"].mean()) if N_cluster > 0 else 0.0
            fc_act = act_frac / (bg_active_fracs[k] + 1e-9)
            fdr_a = float(fdr_active_dict[k][idx])
            intensity_ratio = cluster_mean_score / (global_mean_scores[k] + 1e-9)

            if (fc_act >= CONFIG["MIN_FC"] and
                k_obs_act >= CONFIG["MIN_ACTIVE_SPOTS"] and
                intensity_ratio >= CONFIG["MIN_INTENSITY_RATIO"] and
                fdr_a < 0.05):
                sig_active_axes.append(k)

            if qui_frac > bg_quiet_fracs[k] or fc_act < 0.5:
                cold_axes.append(k)

        if len(sig_active_axes) == 0 and len(cold_axes) >= CONFIG["QUIESCENT_COLD_AXIS_NUM"]:
            c_label = "Quiescent (Background)"
        elif len(sig_active_axes) == 1:
            c_label = f"Single-axis: {sig_active_axes[0]}"
        elif len(sig_active_axes) >= 2:
            c_label = f"Multi-axis: {'_'.join(sig_active_axes)}"
        else:
            c_label = "Transitional"

        cluster_annotations[c] = c_label
        cluster_stats.append({
            "Cluster_ID": c,
            "Spot_Count": N_cluster,
            "Sig_Active_Axes": ",".join(sig_active_axes) if sig_active_axes else "None",
            "Cold_Axis_Count": len(cold_axes),
            "Initial_Label": c_label
        })

    adata_model.obs["Niche_Annotation_PreFilter"] = adata_model.obs[native_cluster_key].astype(str).map(cluster_annotations).astype(str)
    adata_model.obs["Niche_Annotation"] = adata_model.obs["Niche_Annotation_PreFilter"].astype(str)

    # 5. spot 级 low_malig_gate 过滤
    is_active_niche = adata_model.obs["Niche_Annotation"].str.startswith("Single-axis") | adata_model.obs["Niche_Annotation"].str.startswith("Multi-axis")
    low_malig_fail = adata_model.obs["Keep_By_LowMalig"].astype(int).values == 0
    adata_model.obs.loc[is_active_niche & low_malig_fail, "Niche_Annotation"] = "Transitional"

    # 6. 标准化成 Final_Niche_Type
    def standardize_label(x):
        x = str(x)
        if x.startswith("Single-axis:"):
            ax = x.split(":", 1)[1].strip()
            return f"TMCN_{ax}_Axis"
        if x.startswith("Multi-axis:"):
            axes = x.split(":", 1)[1].strip()
            return f"Multi_Axis_{axes}"
        if x.startswith("Quiescent"):
            return "TMCN_Quiescent"
        return "TMCN_Transitional"

    adata_model.obs["Final_Niche_Type"] = adata_model.obs["Niche_Annotation"].map(standardize_label).astype("category")

    cluster_stats_df = pd.DataFrame(cluster_stats)
    return adata_model, pd.DataFrame(thresholds_dict).T, cluster_stats_df


# =========================================================
# D. Cell 10 核心：生成 Level1 / Level2
# =========================================================
def build_level1_level2(adata_model, hard_tumor_threshold):
    malig_col = find_malig_col(adata_model)
    final_niche_str = adata_model.obs["Final_Niche_Type"].astype(str)

    is_spacet_tumor = adata_model.obs[malig_col].astype(float).values > hard_tumor_threshold
    is_quiescent = final_niche_str == "TMCN_Quiescent"
    is_transitional = final_niche_str == "TMCN_Transitional"
    is_quiescent_or_transitional = is_quiescent | is_transitional

    adata_model.obs["Level1_Macro_Region"] = "Healthy_Region"
    adata_model.obs["Level2_Micro_Niche"] = "Healthy_Region"

    tumor_mask = is_spacet_tumor | (~is_quiescent_or_transitional)
    adata_model.obs.loc[tumor_mask, "Level1_Macro_Region"] = "Tumor_Region"

    active_niche_mask = ~is_quiescent_or_transitional
    adata_model.obs.loc[active_niche_mask, "Level2_Micro_Niche"] = final_niche_str[active_niche_mask]

    target_tumor_quiescent_mask = is_spacet_tumor & is_quiescent_or_transitional
    adata_model.obs.loc[target_tumor_quiescent_mask, "Level2_Micro_Niche"] = "TMCN_Quiescent"

    adata_model.obs["Level1_Macro_Region"] = adata_model.obs["Level1_Macro_Region"].astype("category")
    adata_model.obs["Level2_Micro_Niche"] = adata_model.obs["Level2_Micro_Niche"].astype("category")
    return adata_model


# =========================================================
# E. 计算 ARI
# =========================================================
def calculate_level1_ari(adata_model):
    pathology_col = find_pathology_col(adata_model)
    patho = adata_model.obs[pathology_col].astype(str).str.strip()

    if CONFIG["gt_map"] == "prostate_dynamic":
        gt_raw = patho.map(lambda x: 1 if x == "Invasive carcinoma" else 0).astype(float).values
    else:
        gt_raw = patho.map(CONFIG["gt_map"]).astype(float).values

    pred_map = {
        "Healthy_Region": 0,
        "Tumor_Region": 1
    }
    pred_raw = adata_model.obs["Level1_Macro_Region"].astype(str).map(pred_map).astype(float).values

    valid_mask = (~np.isnan(gt_raw)) & (~np.isnan(pred_raw))
    y_true = gt_raw[valid_mask]
    y_pred = pred_raw[valid_mask]

    if len(y_true) == 0:
        raise ValueError(
            f"❌ ARI 有效 spot 数为 0。请检查病理列 {pathology_col} 和 gt_map。\n"
            f"当前病理标签: {patho.unique().tolist()}"
        )

    ari = adjusted_rand_score(y_true, y_pred)
    return float(ari), int(len(y_true)), pathology_col

# %%
# =========================================================
# Cell 3: 主循环：遍历不同 n_sampled_neighbors 并计算 ARI
# =========================================================

def run_sensitivity_analysis():
    os.makedirs(CONFIG["save_root"], exist_ok=True)

    hard_tumor_threshold = read_gmm_threshold()
    adata_scored = compute_sender_receiver_scores()

    all_results = []

    for n_neighbors in CONFIG["n_sampled_neighbors_range"]:
        print("\n" + "=" * 80)
        print(f"🚀 开始参数实验: n_sampled_neighbors = {n_neighbors}")
        print("=" * 80)

        set_seed(CONFIG["seed"])

        run_dir = os.path.join(
            CONFIG["save_root"],
            f"n_sampled_neighbors_{n_neighbors}"
        )
        os.makedirs(run_dir, exist_ok=True)

        adata_model, counts_key = prepare_adata_model(adata_scored)

        adata_model, model = train_nichecompass(
            adata_model=adata_model,
            counts_key=counts_key,
            n_sampled_neighbors=n_neighbors
        )

        adata_model, thresholds_df, cluster_stats_df = annotate_tmcn_niches(
            adata_model=adata_model,
            hard_tumor_threshold=hard_tumor_threshold
        )

        adata_model = build_level1_level2(
            adata_model=adata_model,
            hard_tumor_threshold=hard_tumor_threshold
        )

        ari, n_valid, pathology_col = calculate_level1_ari(adata_model)

        print(
            f"✅ n_sampled_neighbors = {n_neighbors} | "
            f"ARI = {ari:.4f} | valid spots = {n_valid}"
        )

        h5ad_path = os.path.join(
            run_dir,
            f"{CONFIG['file_prefix']}_n_sampled_neighbors_{n_neighbors}.h5ad"
        )

        adata_model.write_h5ad(h5ad_path)

        thresholds_df.to_csv(
            os.path.join(run_dir, "TMCN_thresholds.csv"),
            encoding="utf-8-sig"
        )

        cluster_stats_df.to_csv(
            os.path.join(run_dir, "TMCN_cluster_stats.csv"),
            index=False,
            encoding="utf-8-sig"
        )

        all_results.append({
            "parameter": "n_sampled_neighbors",
            "n_sampled_neighbors": n_neighbors,
            "ARI": round(ari, 6),
            "valid_spots_for_ARI": n_valid,
            "pathology_column": pathology_col,
            "h5ad_path": h5ad_path
        })

        try:
            del model
        except Exception:
            pass

        del adata_model
        gc.collect()

        if torch.cuda.is_available():
            torch.cuda.empty_cache()

    results_df = pd.DataFrame(all_results)

    csv_path = os.path.join(
        CONFIG["save_root"],
        "parameter_sensitivity_n_sampled_neighbors_ARI.csv"
    )

    results_df.to_csv(
        csv_path,
        index=False,
        encoding="utf-8-sig"
    )

    print("\n" + "=" * 80)
    print("🎉 n_sampled_neighbors 参数敏感性分析完成！")
    print(f"✅ 结果 CSV 已保存至: {csv_path}")
    print("=" * 80)

    display(results_df)

    return results_df


results_df = run_sensitivity_analysis()
# Out:
# ✅ 读取 GMM 阈值: 0.4311 | /home/zhangjunyi/xiangmu/nichecompass-main/outputs/test/colorectal_12_cancer_CRC/SN048_A121573_Rep1/SpaCET/GMM_Optimal_Threshold_Result.csv
#
# === A. 加载数据并计算 Sender / Receiver 分数 ===
# ✅ 数据加载成功: 2052 spots, 36601 genes
# --> 计算 Pathway_score (PROGENy)...
# --> 计算 Enzyme_score (AUCell)...
# --> 计算 Sender_score 与 Receiver_score...
# ✅ Sender / Receiver 分数计算完成。
#
# ================================================================================
# 🚀 开始参数实验: n_sampled_neighbors = 2
# ================================================================================
# --- INITIALIZING NEW NETWORK MODULE: VARIATIONAL GENE PROGRAM GRAPH AUTOENCODER ---
# LOSS -> include_edge_recon_loss: True, include_gene_expr_recon_loss: True, rna_recon_loss: nb
# NODE LABEL METHOD -> one-hop-norm
# ACTIVE GP THRESHOLD RATIO -> 0.01
# LOG VARIATIONAL -> True
# ONE HOP GCN NORM RNA NODE LABEL AGGREGATOR
# ENCODER -> n_input: 3045, n_cat_covariates_embed_input: 0, n_hidden: 1325, n_latent: 1225, n_addon_latent: 100, n_fc_layers: 1, n_layers: 1, conv_layer: gcnconv, n_attention_heads: 0, dropout_rate: 0.0,
# COSINE SIM GRAPH DECODER -> dropout_rate: 0.0
# MASKED TARGET RNA DECODER -> n_prior_gp_input: 1225, n_addon_gp_input: 100, n_cat_covariates_embed_input: 0, n_output: 3045
# MASKED SOURCE RNA DECODER -> n_prior_gp_input: 1225, n_addon_gp_input: 100, n_cat_covariates_embed_input: 0, n_output: 3045
#   全量 nodes: 2052
#   全量 edges: 16416
#
# --- INITIALIZING TRAINER ---
# Number of training nodes: 2052
# Number of validation nodes: 0
# Number of training edges: 8204
# Number of validation edges: 0
# Edge batch size: 16416
# Node batch size: 2052
#
# --- MODEL TRAINING ---
# Epoch 1/125 |--------------------| 0.8% train_global_loss: 1673648.5000; train_optim_loss: 1673648.5000
# Epoch 2/125 |--------------------| 1.6% train_global_loss: 1644085.5000; train_optim_loss: 1644085.5000
# Epoch 3/125 |--------------------| 2.4% train_global_loss: 1624316.1250; train_optim_loss: 1624316.1250
# Epoch 4/125 |--------------------| 3.2% train_global_loss: 1609486.6250; train_optim_loss: 1609486.6250
# Epoch 5/125 |--------------------| 4.0% train_global_loss: 1598370.2500; train_optim_loss: 1598370.2500
# Epoch 6/125 |--------------------| 4.8% train_global_loss: 1589524.7500; train_optim_loss: 1589524.7500
# Epoch 7/125 |█-------------------| 5.6% train_global_loss: 1582880.7500; train_optim_loss: 1582880.7500
# Epoch 8/125 |█-------------------| 6.4% train_global_loss: 1577406.5000; train_optim_loss: 1577406.5000
# Epoch 9/125 |█-------------------| 7.2% train_global_loss: 1573007.3750; train_optim_loss: 1573007.3750
# Epoch 10/125 |█-------------------| 8.0% train_global_loss: 1569023.8750; train_optim_loss: 1569023.8750
# Epoch 11/125 |█-------------------| 8.8% train_global_loss: 1565107.7500; train_optim_loss: 1565107.7500
# Epoch 12/125 |█-------------------| 9.6% train_global_loss: 1561192.7500; train_optim_loss: 1561192.7500
# Epoch 13/125 |██------------------| 10.4% train_global_loss: 1557346.5000; train_optim_loss: 1557346.5000
# Epoch 14/125 |██------------------| 11.2% train_global_loss: 1553615.5000; train_optim_loss: 1553615.5000
# Epoch 15/125 |██------------------| 12.0% train_global_loss: 1550006.2500; train_optim_loss: 1550006.2500
# Epoch 16/125 |██------------------| 12.8% train_global_loss: 1546500.0000; train_optim_loss: 1546500.0000
# Epoch 17/125 |██------------------| 13.6% train_global_loss: 1543010.2500; train_optim_loss: 1543010.2500
# Epoch 18/125 |██------------------| 14.4% train_global_loss: 1539641.6250; train_optim_loss: 1539641.6250
# Epoch 19/125 |███-----------------| 15.2% train_global_loss: 1536385.5000; train_optim_loss: 1536385.5000
# Epoch 20/125 |███-----------------| 16.0% train_global_loss: 1533051.0000; train_optim_loss: 1533051.0000
# Epoch 21/125 |███-----------------| 16.8% train_global_loss: 1529694.7500; train_optim_loss: 1529694.7500
# Epoch 22/125 |███-----------------| 17.6% train_global_loss: 1526366.0000; train_optim_loss: 1526366.0000
# Epoch 23/125 |███-----------------| 18.4% train_global_loss: 1522982.2500; train_optim_loss: 1522982.2500
# Epoch 24/125 |███-----------------| 19.2% train_global_loss: 1519588.2500; train_optim_loss: 1519588.2500
# Epoch 25/125 |████----------------| 20.0% train_global_loss: 1516141.3750; train_optim_loss: 1516141.3750
# Epoch 26/125 |████----------------| 20.8% train_global_loss: 1512757.7500; train_optim_loss: 1512757.7500
# Epoch 27/125 |████----------------| 21.6% train_global_loss: 1509348.5000; train_optim_loss: 1509348.5000
# Epoch 28/125 |████----------------| 22.4% train_global_loss: 1505876.2500; train_optim_loss: 1505876.2500
# Epoch 29/125 |████----------------| 23.2% train_global_loss: 1502363.2500; train_optim_loss: 1502363.2500
# Epoch 30/125 |████----------------| 24.0% train_global_loss: 1498865.2500; train_optim_loss: 1498865.2500
# Epoch 31/125 |████----------------| 24.8% train_global_loss: 1495338.1250; train_optim_loss: 1495338.1250
# Epoch 32/125 |█████---------------| 25.6% train_global_loss: 1491808.3750; train_optim_loss: 1491808.3750
# Epoch 33/125 |█████---------------| 26.4% train_global_loss: 1488162.1250; train_optim_loss: 1488162.1250
# Epoch 34/125 |█████---------------| 27.2% train_global_loss: 1484579.5000; train_optim_loss: 1484579.5000
# Epoch 35/125 |█████---------------| 28.0% train_global_loss: 1480900.6250; train_optim_loss: 1480900.6250
# Epoch 36/125 |█████---------------| 28.8% train_global_loss: 1477219.2500; train_optim_loss: 1477219.2500
# Epoch 37/125 |█████---------------| 29.6% train_global_loss: 1473512.2500; train_optim_loss: 1473512.2500
# Epoch 38/125 |██████--------------| 30.4% train_global_loss: 1469732.5000; train_optim_loss: 1469732.5000
# Epoch 39/125 |██████--------------| 31.2% train_global_loss: 1466023.5000; train_optim_loss: 1466023.5000
# Epoch 40/125 |██████--------------| 32.0% train_global_loss: 1462247.5000; train_optim_loss: 1462247.5000
# Epoch 41/125 |██████--------------| 32.8% train_global_loss: 1458463.6250; train_optim_loss: 1458463.6250
# Epoch 42/125 |██████--------------| 33.6% train_global_loss: 1454707.0000; train_optim_loss: 1454707.0000
# Epoch 43/125 |██████--------------| 34.4% train_global_loss: 1450870.0000; train_optim_loss: 1450870.0000
# Epoch 44/125 |███████-------------| 35.2% train_global_loss: 1447061.1250; train_optim_loss: 1447061.1250
# Epoch 45/125 |███████-------------| 36.0% train_global_loss: 1443265.0000; train_optim_loss: 1443265.0000
# Epoch 46/125 |███████-------------| 36.8% train_global_loss: 1439415.7500; train_optim_loss: 1439415.7500
# Epoch 47/125 |███████-------------| 37.6% train_global_loss: 1435588.8750; train_optim_loss: 1435588.8750
# Epoch 48/125 |███████-------------| 38.4% train_global_loss: 1431780.2500; train_optim_loss: 1431780.2500
# Epoch 49/125 |███████-------------| 39.2% train_global_loss: 1427946.6250; train_optim_loss: 1427946.6250
# Epoch 50/125 |████████------------| 40.0% train_global_loss: 1424092.3750; train_optim_loss: 1424092.3750
# Epoch 51/125 |████████------------| 40.8% train_global_loss: 1420332.1250; train_optim_loss: 1420332.1250
# Epoch 52/125 |████████------------| 41.6% train_global_loss: 1416500.7500; train_optim_loss: 1416500.7500
# Epoch 53/125 |████████------------| 42.4% train_global_loss: 1412667.2500; train_optim_loss: 1412667.2500
# Epoch 54/125 |████████------------| 43.2% train_global_loss: 1408851.2500; train_optim_loss: 1408851.2500
# Epoch 55/125 |████████------------| 44.0% train_global_loss: 1405121.8750; train_optim_loss: 1405121.8750
# Epoch 56/125 |████████------------| 44.8% train_global_loss: 1401386.8750; train_optim_loss: 1401386.8750
# Epoch 57/125 |█████████-----------| 45.6% train_global_loss: 1397644.0000; train_optim_loss: 1397644.0000
# Epoch 58/125 |█████████-----------| 46.4% train_global_loss: 1393944.5000; train_optim_loss: 1393944.5000
# Epoch 59/125 |█████████-----------| 47.2% train_global_loss: 1390288.0000; train_optim_loss: 1390288.0000
# Epoch 60/125 |█████████-----------| 48.0% train_global_loss: 1386616.7500; train_optim_loss: 1386616.7500
# Epoch 61/125 |█████████-----------| 48.8% train_global_loss: 1382994.6250; train_optim_loss: 1382994.6250
# Epoch 62/125 |█████████-----------| 49.6% train_global_loss: 1379393.2500; train_optim_loss: 1379393.2500
# Epoch 63/125 |██████████----------| 50.4% train_global_loss: 1375836.7500; train_optim_loss: 1375836.7500
# Epoch 64/125 |██████████----------| 51.2% train_global_loss: 1372394.8750; train_optim_loss: 1372394.8750
# Epoch 65/125 |██████████----------| 52.0% train_global_loss: 1368847.0000; train_optim_loss: 1368847.0000
# Epoch 66/125 |██████████----------| 52.8% train_global_loss: 1365522.7500; train_optim_loss: 1365522.7500
# Epoch 67/125 |██████████----------| 53.6% train_global_loss: 1362138.1250; train_optim_loss: 1362138.1250
# Epoch 68/125 |██████████----------| 54.4% train_global_loss: 1358755.5000; train_optim_loss: 1358755.5000
# Epoch 69/125 |███████████---------| 55.2% train_global_loss: 1355466.0000; train_optim_loss: 1355466.0000
# Epoch 70/125 |███████████---------| 56.0% train_global_loss: 1352155.5000; train_optim_loss: 1352155.5000
# Epoch 71/125 |███████████---------| 56.8% train_global_loss: 1348945.0000; train_optim_loss: 1348945.0000
# Epoch 72/125 |███████████---------| 57.6% train_global_loss: 1345757.1250; train_optim_loss: 1345757.1250
# Epoch 73/125 |███████████---------| 58.4% train_global_loss: 1342625.2500; train_optim_loss: 1342625.2500
# Epoch 74/125 |███████████---------| 59.2% train_global_loss: 1339503.0000; train_optim_loss: 1339503.0000
# Epoch 75/125 |████████████--------| 60.0% train_global_loss: 1336514.6250; train_optim_loss: 1336514.6250
# Epoch 76/125 |████████████--------| 60.8% train_global_loss: 1333489.0000; train_optim_loss: 1333489.0000
# Epoch 77/125 |████████████--------| 61.6% train_global_loss: 1330444.8750; train_optim_loss: 1330444.8750
# Epoch 78/125 |████████████--------| 62.4% train_global_loss: 1327211.7500; train_optim_loss: 1327211.7500
# Epoch 79/125 |████████████--------| 63.2% train_global_loss: 1324257.5000; train_optim_loss: 1324257.5000
# Epoch 80/125 |████████████--------| 64.0% train_global_loss: 1321493.6250; train_optim_loss: 1321493.6250
# Epoch 81/125 |████████████--------| 64.8% train_global_loss: 1318750.7500; train_optim_loss: 1318750.7500
# Epoch 82/125 |█████████████-------| 65.6% train_global_loss: 1315955.2500; train_optim_loss: 1315955.2500
# Epoch 83/125 |█████████████-------| 66.4% train_global_loss: 1313245.0000; train_optim_loss: 1313245.0000
# Epoch 84/125 |█████████████-------| 67.2% train_global_loss: 1310640.5000; train_optim_loss: 1310640.5000
# Epoch 85/125 |█████████████-------| 68.0% train_global_loss: 1308137.8750; train_optim_loss: 1308137.8750
# Epoch 86/125 |█████████████-------| 68.8% train_global_loss: 1305600.0000; train_optim_loss: 1305600.0000
# Epoch 87/125 |█████████████-------| 69.6% train_global_loss: 1303044.5000; train_optim_loss: 1303044.5000
# Epoch 88/125 |██████████████------| 70.4% train_global_loss: 1300626.2500; train_optim_loss: 1300626.2500
# Epoch 89/125 |██████████████------| 71.2% train_global_loss: 1298089.5000; train_optim_loss: 1298089.5000
# Epoch 90/125 |██████████████------| 72.0% train_global_loss: 1295741.7500; train_optim_loss: 1295741.7500
# Epoch 91/125 |██████████████------| 72.8% train_global_loss: 1293201.6250; train_optim_loss: 1293201.6250
# Epoch 92/125 |██████████████------| 73.6% train_global_loss: 1290943.5000; train_optim_loss: 1290943.5000
# Epoch 93/125 |██████████████------| 74.4% train_global_loss: 1288688.0000; train_optim_loss: 1288688.0000
# Epoch 94/125 |███████████████-----| 75.2% train_global_loss: 1286415.7500; train_optim_loss: 1286415.7500
# Epoch 95/125 |███████████████-----| 76.0% train_global_loss: 1284253.5000; train_optim_loss: 1284253.5000
# Epoch 96/125 |███████████████-----| 76.8% train_global_loss: 1281880.7500; train_optim_loss: 1281880.7500
# Epoch 97/125 |███████████████-----| 77.6% train_global_loss: 1279760.5000; train_optim_loss: 1279760.5000
# Epoch 98/125 |███████████████-----| 78.4% train_global_loss: 1277567.8750; train_optim_loss: 1277567.8750
# Epoch 99/125 |███████████████-----| 79.2% train_global_loss: 1275481.5000; train_optim_loss: 1275481.5000
# Epoch 100/125 |████████████████----| 80.0% train_global_loss: 1273404.8750; train_optim_loss: 1273404.8750
# Epoch 101/125 |████████████████----| 80.8% train_global_loss: 1271456.5000; train_optim_loss: 1271456.5000
# Epoch 102/125 |████████████████----| 81.6% train_global_loss: 1269425.0000; train_optim_loss: 1269425.0000
# Epoch 103/125 |████████████████----| 82.4% train_global_loss: 1267476.7500; train_optim_loss: 1267476.7500
# Epoch 104/125 |████████████████----| 83.2% train_global_loss: 1265458.8750; train_optim_loss: 1265458.8750
# Epoch 105/125 |████████████████----| 84.0% train_global_loss: 1263422.7500; train_optim_loss: 1263422.7500
# Epoch 106/125 |████████████████----| 84.8% train_global_loss: 1261672.7500; train_optim_loss: 1261672.7500
# Epoch 107/125 |█████████████████---| 85.6% train_global_loss: 1259761.5000; train_optim_loss: 1259761.5000
# Epoch 108/125 |█████████████████---| 86.4% train_global_loss: 1257977.7500; train_optim_loss: 1257977.7500
# Epoch 109/125 |█████████████████---| 87.2% train_global_loss: 1256059.0000; train_optim_loss: 1256059.0000
# Epoch 110/125 |█████████████████---| 88.0% train_global_loss: 1254361.0000; train_optim_loss: 1254361.0000
# Epoch 111/125 |█████████████████---| 88.8% train_global_loss: 1252551.3750; train_optim_loss: 1252551.3750
# Epoch 112/125 |█████████████████---| 89.6% train_global_loss: 1250831.2500; train_optim_loss: 1250831.2500
# Epoch 113/125 |██████████████████--| 90.4% train_global_loss: 1249046.3750; train_optim_loss: 1249046.3750
# Epoch 114/125 |██████████████████--| 91.2% train_global_loss: 1247154.7500; train_optim_loss: 1247154.7500
# Epoch 115/125 |██████████████████--| 92.0% train_global_loss: 1245365.3750; train_optim_loss: 1245365.3750
# Epoch 116/125 |██████████████████--| 92.8% train_global_loss: 1243676.5000; train_optim_loss: 1243676.5000
# Epoch 117/125 |██████████████████--| 93.6% train_global_loss: 1242049.5000; train_optim_loss: 1242049.5000
# Epoch 118/125 |██████████████████--| 94.4% train_global_loss: 1240373.5000; train_optim_loss: 1240373.5000
# Epoch 119/125 |███████████████████-| 95.2% train_global_loss: 1238795.3750; train_optim_loss: 1238795.3750
# Epoch 120/125 |███████████████████-| 96.0% train_global_loss: 1237176.2500; train_optim_loss: 1237176.2500
# Epoch 121/125 |███████████████████-| 96.8% train_global_loss: 1235585.5000; train_optim_loss: 1235585.5000
# Epoch 122/125 |███████████████████-| 97.6% train_global_loss: 1233959.0000; train_optim_loss: 1233959.0000
# Epoch 123/125 |███████████████████-| 98.4% train_global_loss: 1232391.2500; train_optim_loss: 1232391.2500
# Epoch 124/125 |███████████████████-| 99.2% train_global_loss: 1230780.5000; train_optim_loss: 1230780.5000
# Epoch 125/125 |████████████████████| 100.0% train_global_loss: 1229316.7500; train_optim_loss: 1229316.7500
#
# Model training finished after 1 min 18 sec.
# Using best model state, which was in epoch 125.
# ✅ n_sampled_neighbors = 2 | ARI = 0.5919 | valid spots = 2052
#
# ================================================================================
# 🚀 开始参数实验: n_sampled_neighbors = 4
# ================================================================================
# --- INITIALIZING NEW NETWORK MODULE: VARIATIONAL GENE PROGRAM GRAPH AUTOENCODER ---
# LOSS -> include_edge_recon_loss: True, include_gene_expr_recon_loss: True, rna_recon_loss: nb
# NODE LABEL METHOD -> one-hop-norm
# ACTIVE GP THRESHOLD RATIO -> 0.01
# LOG VARIATIONAL -> True
# ONE HOP GCN NORM RNA NODE LABEL AGGREGATOR
# ENCODER -> n_input: 3045, n_cat_covariates_embed_input: 0, n_hidden: 1325, n_latent: 1225, n_addon_latent: 100, n_fc_layers: 1, n_layers: 1, conv_layer: gcnconv, n_attention_heads: 0, dropout_rate: 0.0,
# COSINE SIM GRAPH DECODER -> dropout_rate: 0.0
# MASKED TARGET RNA DECODER -> n_prior_gp_input: 1225, n_addon_gp_input: 100, n_cat_covariates_embed_input: 0, n_output: 3045
# MASKED SOURCE RNA DECODER -> n_prior_gp_input: 1225, n_addon_gp_input: 100, n_cat_covariates_embed_input: 0, n_output: 3045
#   全量 nodes: 2052
#   全量 edges: 16416
#
# --- INITIALIZING TRAINER ---
# Number of training nodes: 2052
# Number of validation nodes: 0
# Number of training edges: 8204
# Number of validation edges: 0
# Edge batch size: 16416
# Node batch size: 2052
#
# --- MODEL TRAINING ---
# Epoch 1/125 |--------------------| 0.8% train_global_loss: 1673634.7500; train_optim_loss: 1673634.7500
# Epoch 2/125 |--------------------| 1.6% train_global_loss: 1644393.7500; train_optim_loss: 1644393.7500
# Epoch 3/125 |--------------------| 2.4% train_global_loss: 1624427.0000; train_optim_loss: 1624427.0000
# Epoch 4/125 |--------------------| 3.2% train_global_loss: 1609567.7500; train_optim_loss: 1609567.7500
# Epoch 5/125 |--------------------| 4.0% train_global_loss: 1598093.1250; train_optim_loss: 1598093.1250
# Epoch 6/125 |--------------------| 4.8% train_global_loss: 1589431.0000; train_optim_loss: 1589431.0000
# Epoch 7/125 |█-------------------| 5.6% train_global_loss: 1582748.5000; train_optim_loss: 1582748.5000
# Epoch 8/125 |█-------------------| 6.4% train_global_loss: 1577598.6250; train_optim_loss: 1577598.6250
# Epoch 9/125 |█-------------------| 7.2% train_global_loss: 1572978.7500; train_optim_loss: 1572978.7500
# Epoch 10/125 |█-------------------| 8.0% train_global_loss: 1568915.5000; train_optim_loss: 1568915.5000
# Epoch 11/125 |█-------------------| 8.8% train_global_loss: 1565156.2500; train_optim_loss: 1565156.2500
# Epoch 12/125 |█-------------------| 9.6% train_global_loss: 1561309.0000; train_optim_loss: 1561309.0000
# Epoch 13/125 |██------------------| 10.4% train_global_loss: 1557387.5000; train_optim_loss: 1557387.5000
# Epoch 14/125 |██------------------| 11.2% train_global_loss: 1553708.2500; train_optim_loss: 1553708.2500
# Epoch 15/125 |██------------------| 12.0% train_global_loss: 1550018.0000; train_optim_loss: 1550018.0000
# Epoch 16/125 |██------------------| 12.8% train_global_loss: 1546496.8750; train_optim_loss: 1546496.8750
# Epoch 17/125 |██------------------| 13.6% train_global_loss: 1543000.2500; train_optim_loss: 1543000.2500
# Epoch 18/125 |██------------------| 14.4% train_global_loss: 1539619.2500; train_optim_loss: 1539619.2500
# Epoch 19/125 |███-----------------| 15.2% train_global_loss: 1536357.7500; train_optim_loss: 1536357.7500
# Epoch 20/125 |███-----------------| 16.0% train_global_loss: 1533108.7500; train_optim_loss: 1533108.7500
# Epoch 21/125 |███-----------------| 16.8% train_global_loss: 1529742.1250; train_optim_loss: 1529742.1250
# Epoch 22/125 |███-----------------| 17.6% train_global_loss: 1526393.7500; train_optim_loss: 1526393.7500
# Epoch 23/125 |███-----------------| 18.4% train_global_loss: 1523007.2500; train_optim_loss: 1523007.2500
# Epoch 24/125 |███-----------------| 19.2% train_global_loss: 1519625.3750; train_optim_loss: 1519625.3750
# Epoch 25/125 |████----------------| 20.0% train_global_loss: 1516199.2500; train_optim_loss: 1516199.2500
# Epoch 26/125 |████----------------| 20.8% train_global_loss: 1512766.6250; train_optim_loss: 1512766.6250
# Epoch 27/125 |████----------------| 21.6% train_global_loss: 1509325.3750; train_optim_loss: 1509325.3750
# Epoch 28/125 |████----------------| 22.4% train_global_loss: 1505892.6250; train_optim_loss: 1505892.6250
# Epoch 29/125 |████----------------| 23.2% train_global_loss: 1502408.7500; train_optim_loss: 1502408.7500
# Epoch 30/125 |████----------------| 24.0% train_global_loss: 1498908.0000; train_optim_loss: 1498908.0000
# Epoch 31/125 |████----------------| 24.8% train_global_loss: 1495364.2500; train_optim_loss: 1495364.2500
# Epoch 32/125 |█████---------------| 25.6% train_global_loss: 1491838.2500; train_optim_loss: 1491838.2500
# Epoch 33/125 |█████---------------| 26.4% train_global_loss: 1488235.7500; train_optim_loss: 1488235.7500
# Epoch 34/125 |█████---------------| 27.2% train_global_loss: 1484581.2500; train_optim_loss: 1484581.2500
# Epoch 35/125 |█████---------------| 28.0% train_global_loss: 1480867.2500; train_optim_loss: 1480867.2500
# Epoch 36/125 |█████---------------| 28.8% train_global_loss: 1477240.5000; train_optim_loss: 1477240.5000
# Epoch 37/125 |█████---------------| 29.6% train_global_loss: 1473552.0000; train_optim_loss: 1473552.0000
# Epoch 38/125 |██████--------------| 30.4% train_global_loss: 1469795.0000; train_optim_loss: 1469795.0000
# Epoch 39/125 |██████--------------| 31.2% train_global_loss: 1466028.0000; train_optim_loss: 1466028.0000
# Epoch 40/125 |██████--------------| 32.0% train_global_loss: 1462273.0000; train_optim_loss: 1462273.0000
# Epoch 41/125 |██████--------------| 32.8% train_global_loss: 1458493.5000; train_optim_loss: 1458493.5000
# Epoch 42/125 |██████--------------| 33.6% train_global_loss: 1454694.0000; train_optim_loss: 1454694.0000
# Epoch 43/125 |██████--------------| 34.4% train_global_loss: 1450900.7500; train_optim_loss: 1450900.7500
# Epoch 44/125 |███████-------------| 35.2% train_global_loss: 1447074.2500; train_optim_loss: 1447074.2500
# Epoch 45/125 |███████-------------| 36.0% train_global_loss: 1443300.0000; train_optim_loss: 1443300.0000
# Epoch 46/125 |███████-------------| 36.8% train_global_loss: 1439441.1250; train_optim_loss: 1439441.1250
# Epoch 47/125 |███████-------------| 37.6% train_global_loss: 1435574.5000; train_optim_loss: 1435574.5000
# Epoch 48/125 |███████-------------| 38.4% train_global_loss: 1431799.2500; train_optim_loss: 1431799.2500
# Epoch 49/125 |███████-------------| 39.2% train_global_loss: 1427917.7500; train_optim_loss: 1427917.7500
# Epoch 50/125 |████████------------| 40.0% train_global_loss: 1424110.7500; train_optim_loss: 1424110.7500
# Epoch 51/125 |████████------------| 40.8% train_global_loss: 1420284.2500; train_optim_loss: 1420284.2500
# Epoch 52/125 |████████------------| 41.6% train_global_loss: 1416502.0000; train_optim_loss: 1416502.0000
# Epoch 53/125 |████████------------| 42.4% train_global_loss: 1412736.8750; train_optim_loss: 1412736.8750
# Epoch 54/125 |████████------------| 43.2% train_global_loss: 1408947.5000; train_optim_loss: 1408947.5000
# Epoch 55/125 |████████------------| 44.0% train_global_loss: 1405153.0000; train_optim_loss: 1405153.0000
# Epoch 56/125 |████████------------| 44.8% train_global_loss: 1401423.2500; train_optim_loss: 1401423.2500
# Epoch 57/125 |█████████-----------| 45.6% train_global_loss: 1397717.7500; train_optim_loss: 1397717.7500
# Epoch 58/125 |█████████-----------| 46.4% train_global_loss: 1394022.0000; train_optim_loss: 1394022.0000
# Epoch 59/125 |█████████-----------| 47.2% train_global_loss: 1390336.0000; train_optim_loss: 1390336.0000
# Epoch 60/125 |█████████-----------| 48.0% train_global_loss: 1386732.2500; train_optim_loss: 1386732.2500
# Epoch 61/125 |█████████-----------| 48.8% train_global_loss: 1383155.0000; train_optim_loss: 1383155.0000
# Epoch 62/125 |█████████-----------| 49.6% train_global_loss: 1379519.0000; train_optim_loss: 1379519.0000
# Epoch 63/125 |██████████----------| 50.4% train_global_loss: 1375968.0000; train_optim_loss: 1375968.0000
# Epoch 64/125 |██████████----------| 51.2% train_global_loss: 1372515.2500; train_optim_loss: 1372515.2500
# Epoch 65/125 |██████████----------| 52.0% train_global_loss: 1368986.5000; train_optim_loss: 1368986.5000
# Epoch 66/125 |██████████----------| 52.8% train_global_loss: 1365647.3750; train_optim_loss: 1365647.3750
# Epoch 67/125 |██████████----------| 53.6% train_global_loss: 1362169.7500; train_optim_loss: 1362169.7500
# Epoch 68/125 |██████████----------| 54.4% train_global_loss: 1358687.0000; train_optim_loss: 1358687.0000
# Epoch 69/125 |███████████---------| 55.2% train_global_loss: 1355415.0000; train_optim_loss: 1355415.0000
# Epoch 70/125 |███████████---------| 56.0% train_global_loss: 1351925.5000; train_optim_loss: 1351925.5000
# Epoch 71/125 |███████████---------| 56.8% train_global_loss: 1348765.3750; train_optim_loss: 1348765.3750
# Epoch 72/125 |███████████---------| 57.6% train_global_loss: 1345488.8750; train_optim_loss: 1345488.8750
# Epoch 73/125 |███████████---------| 58.4% train_global_loss: 1342399.2500; train_optim_loss: 1342399.2500
# Epoch 74/125 |███████████---------| 59.2% train_global_loss: 1339298.8750; train_optim_loss: 1339298.8750
# Epoch 75/125 |████████████--------| 60.0% train_global_loss: 1336276.5000; train_optim_loss: 1336276.5000
# Epoch 76/125 |████████████--------| 60.8% train_global_loss: 1333139.5000; train_optim_loss: 1333139.5000
# Epoch 77/125 |████████████--------| 61.6% train_global_loss: 1330200.3750; train_optim_loss: 1330200.3750
# Epoch 78/125 |████████████--------| 62.4% train_global_loss: 1327289.2500; train_optim_loss: 1327289.2500
# Epoch 79/125 |████████████--------| 63.2% train_global_loss: 1324396.7500; train_optim_loss: 1324396.7500
# Epoch 80/125 |████████████--------| 64.0% train_global_loss: 1321470.7500; train_optim_loss: 1321470.7500
# Epoch 81/125 |████████████--------| 64.8% train_global_loss: 1318744.0000; train_optim_loss: 1318744.0000
# Epoch 82/125 |█████████████-------| 65.6% train_global_loss: 1315935.5000; train_optim_loss: 1315935.5000
# Epoch 83/125 |█████████████-------| 66.4% train_global_loss: 1313317.7500; train_optim_loss: 1313317.7500
# Epoch 84/125 |█████████████-------| 67.2% train_global_loss: 1310687.5000; train_optim_loss: 1310687.5000
# Epoch 85/125 |█████████████-------| 68.0% train_global_loss: 1308142.7500; train_optim_loss: 1308142.7500
# Epoch 86/125 |█████████████-------| 68.8% train_global_loss: 1305642.2500; train_optim_loss: 1305642.2500
# Epoch 87/125 |█████████████-------| 69.6% train_global_loss: 1303097.0000; train_optim_loss: 1303097.0000
# Epoch 88/125 |██████████████------| 70.4% train_global_loss: 1300648.6250; train_optim_loss: 1300648.6250
# Epoch 89/125 |██████████████------| 71.2% train_global_loss: 1298301.7500; train_optim_loss: 1298301.7500
# Epoch 90/125 |██████████████------| 72.0% train_global_loss: 1295956.5000; train_optim_loss: 1295956.5000
# Epoch 91/125 |██████████████------| 72.8% train_global_loss: 1293562.7500; train_optim_loss: 1293562.7500
# Epoch 92/125 |██████████████------| 73.6% train_global_loss: 1291286.5000; train_optim_loss: 1291286.5000
# Epoch 93/125 |██████████████------| 74.4% train_global_loss: 1289074.7500; train_optim_loss: 1289074.7500
# Epoch 94/125 |███████████████-----| 75.2% train_global_loss: 1286738.7500; train_optim_loss: 1286738.7500
# Epoch 95/125 |███████████████-----| 76.0% train_global_loss: 1284554.1250; train_optim_loss: 1284554.1250
# Epoch 96/125 |███████████████-----| 76.8% train_global_loss: 1282360.6250; train_optim_loss: 1282360.6250
# Epoch 97/125 |███████████████-----| 77.6% train_global_loss: 1280221.6250; train_optim_loss: 1280221.6250
# Epoch 98/125 |███████████████-----| 78.4% train_global_loss: 1278091.0000; train_optim_loss: 1278091.0000
# Epoch 99/125 |███████████████-----| 79.2% train_global_loss: 1276079.3750; train_optim_loss: 1276079.3750
# Epoch 100/125 |████████████████----| 80.0% train_global_loss: 1274078.2500; train_optim_loss: 1274078.2500
# Epoch 101/125 |████████████████----| 80.8% train_global_loss: 1272049.7500; train_optim_loss: 1272049.7500
# Epoch 102/125 |████████████████----| 81.6% train_global_loss: 1270024.5000; train_optim_loss: 1270024.5000
# Epoch 103/125 |████████████████----| 82.4% train_global_loss: 1268004.1250; train_optim_loss: 1268004.1250
# Epoch 104/125 |████████████████----| 83.2% train_global_loss: 1266050.8750; train_optim_loss: 1266050.8750
# Epoch 105/125 |████████████████----| 84.0% train_global_loss: 1264119.8750; train_optim_loss: 1264119.8750
# Epoch 106/125 |████████████████----| 84.8% train_global_loss: 1262212.7500; train_optim_loss: 1262212.7500
# Epoch 107/125 |█████████████████---| 85.6% train_global_loss: 1260327.3750; train_optim_loss: 1260327.3750
# Epoch 108/125 |█████████████████---| 86.4% train_global_loss: 1258531.2500; train_optim_loss: 1258531.2500
# Epoch 109/125 |█████████████████---| 87.2% train_global_loss: 1256547.6250; train_optim_loss: 1256547.6250
# Epoch 110/125 |█████████████████---| 88.0% train_global_loss: 1254724.7500; train_optim_loss: 1254724.7500
# Epoch 111/125 |█████████████████---| 88.8% train_global_loss: 1252948.5000; train_optim_loss: 1252948.5000
# Epoch 112/125 |█████████████████---| 89.6% train_global_loss: 1251205.0000; train_optim_loss: 1251205.0000
# Epoch 113/125 |██████████████████--| 90.4% train_global_loss: 1249449.7500; train_optim_loss: 1249449.7500
# Epoch 114/125 |██████████████████--| 91.2% train_global_loss: 1247708.2500; train_optim_loss: 1247708.2500
# Epoch 115/125 |██████████████████--| 92.0% train_global_loss: 1245961.2500; train_optim_loss: 1245961.2500
# Epoch 116/125 |██████████████████--| 92.8% train_global_loss: 1244316.3750; train_optim_loss: 1244316.3750
# Epoch 117/125 |██████████████████--| 93.6% train_global_loss: 1242629.0000; train_optim_loss: 1242629.0000
# Epoch 118/125 |██████████████████--| 94.4% train_global_loss: 1241012.8750; train_optim_loss: 1241012.8750
# Epoch 119/125 |███████████████████-| 95.2% train_global_loss: 1239404.5000; train_optim_loss: 1239404.5000
# Epoch 120/125 |███████████████████-| 96.0% train_global_loss: 1237786.2500; train_optim_loss: 1237786.2500
# Epoch 121/125 |███████████████████-| 96.8% train_global_loss: 1236170.3750; train_optim_loss: 1236170.3750
# Epoch 122/125 |███████████████████-| 97.6% train_global_loss: 1234613.3750; train_optim_loss: 1234613.3750
# Epoch 123/125 |███████████████████-| 98.4% train_global_loss: 1232957.7500; train_optim_loss: 1232957.7500
# Epoch 124/125 |███████████████████-| 99.2% train_global_loss: 1231521.7500; train_optim_loss: 1231521.7500
# Epoch 125/125 |████████████████████| 100.0% train_global_loss: 1229941.7500; train_optim_loss: 1229941.7500
#
# Model training finished after 2 min 14 sec.
# Using best model state, which was in epoch 125.
# ✅ n_sampled_neighbors = 4 | ARI = 0.5995 | valid spots = 2052
#
# ================================================================================
# 🚀 开始参数实验: n_sampled_neighbors = 6
# ================================================================================
# --- INITIALIZING NEW NETWORK MODULE: VARIATIONAL GENE PROGRAM GRAPH AUTOENCODER ---
# LOSS -> include_edge_recon_loss: True, include_gene_expr_recon_loss: True, rna_recon_loss: nb
# NODE LABEL METHOD -> one-hop-norm
# ACTIVE GP THRESHOLD RATIO -> 0.01
# LOG VARIATIONAL -> True
# ONE HOP GCN NORM RNA NODE LABEL AGGREGATOR
# ENCODER -> n_input: 3045, n_cat_covariates_embed_input: 0, n_hidden: 1325, n_latent: 1225, n_addon_latent: 100, n_fc_layers: 1, n_layers: 1, conv_layer: gcnconv, n_attention_heads: 0, dropout_rate: 0.0,
# COSINE SIM GRAPH DECODER -> dropout_rate: 0.0
# MASKED TARGET RNA DECODER -> n_prior_gp_input: 1225, n_addon_gp_input: 100, n_cat_covariates_embed_input: 0, n_output: 3045
# MASKED SOURCE RNA DECODER -> n_prior_gp_input: 1225, n_addon_gp_input: 100, n_cat_covariates_embed_input: 0, n_output: 3045
#   全量 nodes: 2052
#   全量 edges: 16416
#
# --- INITIALIZING TRAINER ---
# Number of training nodes: 2052
# Number of validation nodes: 0
# Number of training edges: 8204
# Number of validation edges: 0
# Edge batch size: 16416
# Node batch size: 2052
#
# --- MODEL TRAINING ---
# Epoch 1/125 |--------------------| 0.8% train_global_loss: 1673879.5000; train_optim_loss: 1673879.5000
# Epoch 2/125 |--------------------| 1.6% train_global_loss: 1644101.2500; train_optim_loss: 1644101.2500
# Epoch 3/125 |--------------------| 2.4% train_global_loss: 1624184.5000; train_optim_loss: 1624184.5000
# Epoch 4/125 |--------------------| 3.2% train_global_loss: 1609643.5000; train_optim_loss: 1609643.5000
# Epoch 5/125 |--------------------| 4.0% train_global_loss: 1598003.0000; train_optim_loss: 1598003.0000
# Epoch 6/125 |--------------------| 4.8% train_global_loss: 1589354.5000; train_optim_loss: 1589354.5000
# Epoch 7/125 |█-------------------| 5.6% train_global_loss: 1582850.3750; train_optim_loss: 1582850.3750
# Epoch 8/125 |█-------------------| 6.4% train_global_loss: 1577391.2500; train_optim_loss: 1577391.2500
# Epoch 9/125 |█-------------------| 7.2% train_global_loss: 1572838.1250; train_optim_loss: 1572838.1250
# Epoch 10/125 |█-------------------| 8.0% train_global_loss: 1568846.5000; train_optim_loss: 1568846.5000
# Epoch 11/125 |█-------------------| 8.8% train_global_loss: 1565055.0000; train_optim_loss: 1565055.0000
# Epoch 12/125 |█-------------------| 9.6% train_global_loss: 1561222.2500; train_optim_loss: 1561222.2500
# Epoch 13/125 |██------------------| 10.4% train_global_loss: 1557378.0000; train_optim_loss: 1557378.0000
# Epoch 14/125 |██------------------| 11.2% train_global_loss: 1553634.5000; train_optim_loss: 1553634.5000
# Epoch 15/125 |██------------------| 12.0% train_global_loss: 1550058.2500; train_optim_loss: 1550058.2500
# Epoch 16/125 |██------------------| 12.8% train_global_loss: 1546523.5000; train_optim_loss: 1546523.5000
# Epoch 17/125 |██------------------| 13.6% train_global_loss: 1542997.5000; train_optim_loss: 1542997.5000
# Epoch 18/125 |██------------------| 14.4% train_global_loss: 1539639.7500; train_optim_loss: 1539639.7500
# Epoch 19/125 |███-----------------| 15.2% train_global_loss: 1536336.2500; train_optim_loss: 1536336.2500
# Epoch 20/125 |███-----------------| 16.0% train_global_loss: 1533031.5000; train_optim_loss: 1533031.5000
# Epoch 21/125 |███-----------------| 16.8% train_global_loss: 1529684.2500; train_optim_loss: 1529684.2500
# Epoch 22/125 |███-----------------| 17.6% train_global_loss: 1526328.5000; train_optim_loss: 1526328.5000
# Epoch 23/125 |███-----------------| 18.4% train_global_loss: 1522999.5000; train_optim_loss: 1522999.5000
# Epoch 24/125 |███-----------------| 19.2% train_global_loss: 1519594.2500; train_optim_loss: 1519594.2500
# Epoch 25/125 |████----------------| 20.0% train_global_loss: 1516161.0000; train_optim_loss: 1516161.0000
# Epoch 26/125 |████----------------| 20.8% train_global_loss: 1512754.2500; train_optim_loss: 1512754.2500
# Epoch 27/125 |████----------------| 21.6% train_global_loss: 1509340.2500; train_optim_loss: 1509340.2500
# Epoch 28/125 |████----------------| 22.4% train_global_loss: 1505862.1250; train_optim_loss: 1505862.1250
# Epoch 29/125 |████----------------| 23.2% train_global_loss: 1502397.8750; train_optim_loss: 1502397.8750
# Epoch 30/125 |████----------------| 24.0% train_global_loss: 1498916.7500; train_optim_loss: 1498916.7500
# Epoch 31/125 |████----------------| 24.8% train_global_loss: 1495297.2500; train_optim_loss: 1495297.2500
# Epoch 32/125 |█████---------------| 25.6% train_global_loss: 1491748.8750; train_optim_loss: 1491748.8750
# Epoch 33/125 |█████---------------| 26.4% train_global_loss: 1488130.5000; train_optim_loss: 1488130.5000
# Epoch 34/125 |█████---------------| 27.2% train_global_loss: 1484552.8750; train_optim_loss: 1484552.8750
# Epoch 35/125 |█████---------------| 28.0% train_global_loss: 1480885.0000; train_optim_loss: 1480885.0000
# Epoch 36/125 |█████---------------| 28.8% train_global_loss: 1477199.3750; train_optim_loss: 1477199.3750
# Epoch 37/125 |█████---------------| 29.6% train_global_loss: 1473471.2500; train_optim_loss: 1473471.2500
# Epoch 38/125 |██████--------------| 30.4% train_global_loss: 1469748.8750; train_optim_loss: 1469748.8750
# Epoch 39/125 |██████--------------| 31.2% train_global_loss: 1466012.6250; train_optim_loss: 1466012.6250
# Epoch 40/125 |██████--------------| 32.0% train_global_loss: 1462260.0000; train_optim_loss: 1462260.0000
# Epoch 41/125 |██████--------------| 32.8% train_global_loss: 1458475.0000; train_optim_loss: 1458475.0000
# Epoch 42/125 |██████--------------| 33.6% train_global_loss: 1454631.2500; train_optim_loss: 1454631.2500
# Epoch 43/125 |██████--------------| 34.4% train_global_loss: 1450862.5000; train_optim_loss: 1450862.5000
# Epoch 44/125 |███████-------------| 35.2% train_global_loss: 1447044.5000; train_optim_loss: 1447044.5000
# Epoch 45/125 |███████-------------| 36.0% train_global_loss: 1443226.2500; train_optim_loss: 1443226.2500
# Epoch 46/125 |███████-------------| 36.8% train_global_loss: 1439430.2500; train_optim_loss: 1439430.2500
# Epoch 47/125 |███████-------------| 37.6% train_global_loss: 1435556.5000; train_optim_loss: 1435556.5000
# Epoch 48/125 |███████-------------| 38.4% train_global_loss: 1431710.7500; train_optim_loss: 1431710.7500
# Epoch 49/125 |███████-------------| 39.2% train_global_loss: 1427875.1250; train_optim_loss: 1427875.1250
# Epoch 50/125 |████████------------| 40.0% train_global_loss: 1424055.0000; train_optim_loss: 1424055.0000
# Epoch 51/125 |████████------------| 40.8% train_global_loss: 1420248.2500; train_optim_loss: 1420248.2500
# Epoch 52/125 |████████------------| 41.6% train_global_loss: 1416434.2500; train_optim_loss: 1416434.2500
# Epoch 53/125 |████████------------| 42.4% train_global_loss: 1412613.5000; train_optim_loss: 1412613.5000
# Epoch 54/125 |████████------------| 43.2% train_global_loss: 1408839.2500; train_optim_loss: 1408839.2500
# Epoch 55/125 |████████------------| 44.0% train_global_loss: 1405076.0000; train_optim_loss: 1405076.0000
# Epoch 56/125 |████████------------| 44.8% train_global_loss: 1401354.6250; train_optim_loss: 1401354.6250
# Epoch 57/125 |█████████-----------| 45.6% train_global_loss: 1397596.7500; train_optim_loss: 1397596.7500
# Epoch 58/125 |█████████-----------| 46.4% train_global_loss: 1393899.3750; train_optim_loss: 1393899.3750
# Epoch 59/125 |█████████-----------| 47.2% train_global_loss: 1390261.2500; train_optim_loss: 1390261.2500
# Epoch 60/125 |█████████-----------| 48.0% train_global_loss: 1386573.2500; train_optim_loss: 1386573.2500
# Epoch 61/125 |█████████-----------| 48.8% train_global_loss: 1383004.2500; train_optim_loss: 1383004.2500
# Epoch 62/125 |█████████-----------| 49.6% train_global_loss: 1379419.7500; train_optim_loss: 1379419.7500
# Epoch 63/125 |██████████----------| 50.4% train_global_loss: 1375848.2500; train_optim_loss: 1375848.2500
# Epoch 64/125 |██████████----------| 51.2% train_global_loss: 1372354.6250; train_optim_loss: 1372354.6250
# Epoch 65/125 |██████████----------| 52.0% train_global_loss: 1368652.7500; train_optim_loss: 1368652.7500
# Epoch 66/125 |██████████----------| 52.8% train_global_loss: 1365187.7500; train_optim_loss: 1365187.7500
# Epoch 67/125 |██████████----------| 53.6% train_global_loss: 1361770.6250; train_optim_loss: 1361770.6250
# Epoch 68/125 |██████████----------| 54.4% train_global_loss: 1358467.0000; train_optim_loss: 1358467.0000
# Epoch 69/125 |███████████---------| 55.2% train_global_loss: 1355181.5000; train_optim_loss: 1355181.5000
# Epoch 70/125 |███████████---------| 56.0% train_global_loss: 1351902.2500; train_optim_loss: 1351902.2500
# Epoch 71/125 |███████████---------| 56.8% train_global_loss: 1348546.0000; train_optim_loss: 1348546.0000
# Epoch 72/125 |███████████---------| 57.6% train_global_loss: 1345443.1250; train_optim_loss: 1345443.1250
# Epoch 73/125 |███████████---------| 58.4% train_global_loss: 1342313.0000; train_optim_loss: 1342313.0000
# Epoch 74/125 |███████████---------| 59.2% train_global_loss: 1339292.7500; train_optim_loss: 1339292.7500
# Epoch 75/125 |████████████--------| 60.0% train_global_loss: 1336218.2500; train_optim_loss: 1336218.2500
# Epoch 76/125 |████████████--------| 60.8% train_global_loss: 1332938.2500; train_optim_loss: 1332938.2500
# Epoch 77/125 |████████████--------| 61.6% train_global_loss: 1329973.3750; train_optim_loss: 1329973.3750
# Epoch 78/125 |████████████--------| 62.4% train_global_loss: 1326778.2500; train_optim_loss: 1326778.2500
# Epoch 79/125 |████████████--------| 63.2% train_global_loss: 1323850.3750; train_optim_loss: 1323850.3750
# Epoch 80/125 |████████████--------| 64.0% train_global_loss: 1321117.6250; train_optim_loss: 1321117.6250
# Epoch 81/125 |████████████--------| 64.8% train_global_loss: 1318344.5000; train_optim_loss: 1318344.5000
# Epoch 82/125 |█████████████-------| 65.6% train_global_loss: 1315709.7500; train_optim_loss: 1315709.7500
# Epoch 83/125 |█████████████-------| 66.4% train_global_loss: 1312941.2500; train_optim_loss: 1312941.2500
# Epoch 84/125 |█████████████-------| 67.2% train_global_loss: 1310329.2500; train_optim_loss: 1310329.2500
# Epoch 85/125 |█████████████-------| 68.0% train_global_loss: 1307803.0000; train_optim_loss: 1307803.0000
# Epoch 86/125 |█████████████-------| 68.8% train_global_loss: 1305170.6250; train_optim_loss: 1305170.6250
# Epoch 87/125 |█████████████-------| 69.6% train_global_loss: 1302714.3750; train_optim_loss: 1302714.3750
# Epoch 88/125 |██████████████------| 70.4% train_global_loss: 1300249.0000; train_optim_loss: 1300249.0000
# Epoch 89/125 |██████████████------| 71.2% train_global_loss: 1297872.7500; train_optim_loss: 1297872.7500
# Epoch 90/125 |██████████████------| 72.0% train_global_loss: 1295487.7500; train_optim_loss: 1295487.7500
# Epoch 91/125 |██████████████------| 72.8% train_global_loss: 1293199.3750; train_optim_loss: 1293199.3750
# Epoch 92/125 |██████████████------| 73.6% train_global_loss: 1290876.5000; train_optim_loss: 1290876.5000
# Epoch 93/125 |██████████████------| 74.4% train_global_loss: 1288600.7500; train_optim_loss: 1288600.7500
# Epoch 94/125 |███████████████-----| 75.2% train_global_loss: 1286229.7500; train_optim_loss: 1286229.7500
# Epoch 95/125 |███████████████-----| 76.0% train_global_loss: 1283929.2500; train_optim_loss: 1283929.2500
# Epoch 96/125 |███████████████-----| 76.8% train_global_loss: 1281777.2500; train_optim_loss: 1281777.2500
# Epoch 97/125 |███████████████-----| 77.6% train_global_loss: 1279606.0000; train_optim_loss: 1279606.0000
# Epoch 98/125 |███████████████-----| 78.4% train_global_loss: 1277570.5000; train_optim_loss: 1277570.5000
# Epoch 99/125 |███████████████-----| 79.2% train_global_loss: 1275456.5000; train_optim_loss: 1275456.5000
# Epoch 100/125 |████████████████----| 80.0% train_global_loss: 1273457.0000; train_optim_loss: 1273457.0000
# Epoch 101/125 |████████████████----| 80.8% train_global_loss: 1271390.7500; train_optim_loss: 1271390.7500
# Epoch 102/125 |████████████████----| 81.6% train_global_loss: 1269363.8750; train_optim_loss: 1269363.8750
# Epoch 103/125 |████████████████----| 82.4% train_global_loss: 1267245.8750; train_optim_loss: 1267245.8750
# Epoch 104/125 |████████████████----| 83.2% train_global_loss: 1265302.1250; train_optim_loss: 1265302.1250
# Epoch 105/125 |████████████████----| 84.0% train_global_loss: 1263184.7500; train_optim_loss: 1263184.7500
# Epoch 106/125 |████████████████----| 84.8% train_global_loss: 1261347.0000; train_optim_loss: 1261347.0000
# Epoch 107/125 |█████████████████---| 85.6% train_global_loss: 1259477.2500; train_optim_loss: 1259477.2500
# Epoch 108/125 |█████████████████---| 86.4% train_global_loss: 1257647.5000; train_optim_loss: 1257647.5000
# Epoch 109/125 |█████████████████---| 87.2% train_global_loss: 1255841.2500; train_optim_loss: 1255841.2500
# Epoch 110/125 |█████████████████---| 88.0% train_global_loss: 1254035.6250; train_optim_loss: 1254035.6250
# Epoch 111/125 |█████████████████---| 88.8% train_global_loss: 1252308.6250; train_optim_loss: 1252308.6250
# Epoch 112/125 |█████████████████---| 89.6% train_global_loss: 1250597.3750; train_optim_loss: 1250597.3750
# Epoch 113/125 |██████████████████--| 90.4% train_global_loss: 1248885.3750; train_optim_loss: 1248885.3750
# Epoch 114/125 |██████████████████--| 91.2% train_global_loss: 1247220.1250; train_optim_loss: 1247220.1250
# Epoch 115/125 |██████████████████--| 92.0% train_global_loss: 1245473.5000; train_optim_loss: 1245473.5000
# Epoch 116/125 |██████████████████--| 92.8% train_global_loss: 1243746.0000; train_optim_loss: 1243746.0000
# Epoch 117/125 |██████████████████--| 93.6% train_global_loss: 1242221.2500; train_optim_loss: 1242221.2500
# Epoch 118/125 |██████████████████--| 94.4% train_global_loss: 1240515.1250; train_optim_loss: 1240515.1250
# Epoch 119/125 |███████████████████-| 95.2% train_global_loss: 1238822.7500; train_optim_loss: 1238822.7500
# Epoch 120/125 |███████████████████-| 96.0% train_global_loss: 1237262.2500; train_optim_loss: 1237262.2500
# Epoch 121/125 |███████████████████-| 96.8% train_global_loss: 1235649.2500; train_optim_loss: 1235649.2500
# Epoch 122/125 |███████████████████-| 97.6% train_global_loss: 1234063.6250; train_optim_loss: 1234063.6250
# Epoch 123/125 |███████████████████-| 98.4% train_global_loss: 1232509.5000; train_optim_loss: 1232509.5000
# Epoch 124/125 |███████████████████-| 99.2% train_global_loss: 1230948.2500; train_optim_loss: 1230948.2500
# Epoch 125/125 |████████████████████| 100.0% train_global_loss: 1229331.6250; train_optim_loss: 1229331.6250
#
# Model training finished after 5 min 59 sec.
# Using best model state, which was in epoch 125.
# ✅ n_sampled_neighbors = 6 | ARI = 0.5890 | valid spots = 2052
#
# ================================================================================
# 🚀 开始参数实验: n_sampled_neighbors = 8
# ================================================================================
# --- INITIALIZING NEW NETWORK MODULE: VARIATIONAL GENE PROGRAM GRAPH AUTOENCODER ---
# LOSS -> include_edge_recon_loss: True, include_gene_expr_recon_loss: True, rna_recon_loss: nb
# NODE LABEL METHOD -> one-hop-norm
# ACTIVE GP THRESHOLD RATIO -> 0.01
# LOG VARIATIONAL -> True
# ONE HOP GCN NORM RNA NODE LABEL AGGREGATOR
# ENCODER -> n_input: 3045, n_cat_covariates_embed_input: 0, n_hidden: 1325, n_latent: 1225, n_addon_latent: 100, n_fc_layers: 1, n_layers: 1, conv_layer: gcnconv, n_attention_heads: 0, dropout_rate: 0.0,
# COSINE SIM GRAPH DECODER -> dropout_rate: 0.0
# MASKED TARGET RNA DECODER -> n_prior_gp_input: 1225, n_addon_gp_input: 100, n_cat_covariates_embed_input: 0, n_output: 3045
# MASKED SOURCE RNA DECODER -> n_prior_gp_input: 1225, n_addon_gp_input: 100, n_cat_covariates_embed_input: 0, n_output: 3045
#   全量 nodes: 2052
#   全量 edges: 16416
#
# --- INITIALIZING TRAINER ---
# Number of training nodes: 2052
# Number of validation nodes: 0
# Number of training edges: 8204
# Number of validation edges: 0
# Edge batch size: 16416
# Node batch size: 2052
#
# --- MODEL TRAINING ---
# Epoch 1/125 |--------------------| 0.8% train_global_loss: 1673408.0000; train_optim_loss: 1673408.0000
# Epoch 2/125 |--------------------| 1.6% train_global_loss: 1644345.3750; train_optim_loss: 1644345.3750
# Epoch 3/125 |--------------------| 2.4% train_global_loss: 1624210.7500; train_optim_loss: 1624210.7500
# Epoch 4/125 |--------------------| 3.2% train_global_loss: 1609560.5000; train_optim_loss: 1609560.5000
# Epoch 5/125 |--------------------| 4.0% train_global_loss: 1598238.6250; train_optim_loss: 1598238.6250
# Epoch 6/125 |--------------------| 4.8% train_global_loss: 1589477.0000; train_optim_loss: 1589477.0000
# Epoch 7/125 |█-------------------| 5.6% train_global_loss: 1582777.2500; train_optim_loss: 1582777.2500
# Epoch 8/125 |█-------------------| 6.4% train_global_loss: 1577402.0000; train_optim_loss: 1577402.0000
# Epoch 9/125 |█-------------------| 7.2% train_global_loss: 1572866.5000; train_optim_loss: 1572866.5000
# Epoch 10/125 |█-------------------| 8.0% train_global_loss: 1568888.1250; train_optim_loss: 1568888.1250
# Epoch 11/125 |█-------------------| 8.8% train_global_loss: 1565082.5000; train_optim_loss: 1565082.5000
# Epoch 12/125 |█-------------------| 9.6% train_global_loss: 1561225.2500; train_optim_loss: 1561225.2500
# Epoch 13/125 |██------------------| 10.4% train_global_loss: 1557332.2500; train_optim_loss: 1557332.2500
# Epoch 14/125 |██------------------| 11.2% train_global_loss: 1553617.8750; train_optim_loss: 1553617.8750
# Epoch 15/125 |██------------------| 12.0% train_global_loss: 1549931.5000; train_optim_loss: 1549931.5000
# Epoch 16/125 |██------------------| 12.8% train_global_loss: 1546456.5000; train_optim_loss: 1546456.5000
# Epoch 17/125 |██------------------| 13.6% train_global_loss: 1543018.0000; train_optim_loss: 1543018.0000
# Epoch 18/125 |██------------------| 14.4% train_global_loss: 1539600.1250; train_optim_loss: 1539600.1250
# Epoch 19/125 |███-----------------| 15.2% train_global_loss: 1536355.0000; train_optim_loss: 1536355.0000
# Epoch 20/125 |███-----------------| 16.0% train_global_loss: 1533010.3750; train_optim_loss: 1533010.3750
# Epoch 21/125 |███-----------------| 16.8% train_global_loss: 1529708.0000; train_optim_loss: 1529708.0000
# Epoch 22/125 |███-----------------| 17.6% train_global_loss: 1526380.2500; train_optim_loss: 1526380.2500
# ...
# --- INITIALIZING NEW NETWORK MODULE: VARIATIONAL GENE PROGRAM GRAPH AUTOENCODER ---
# LOSS -> include_edge_recon_loss: True, include_gene_expr_recon_loss: True, rna_recon_loss: nb
# NODE LABEL METHOD -> one-hop-norm
# ACTIVE GP THRESHOLD RATIO -> 0.01
# LOG VARIATIONAL -> True
# ONE HOP GCN NORM RNA NODE LABEL AGGREGATOR
# ENCODER -> n_input: 3045, n_cat_covariates_embed_input: 0, n_hidden: 1325, n_latent: 1225, n_addon_latent: 100, n_fc_layers: 1, n_layers: 1, conv_layer: gcnconv, n_attention_heads: 0, dropout_rate: 0.0,
# COSINE SIM GRAPH DECODER -> dropout_rate: 0.0
# MASKED TARGET RNA DECODER -> n_prior_gp_input: 1225, n_addon_gp_input: 100, n_cat_covariates_embed_input: 0, n_output: 3045
# MASKED SOURCE RNA DECODER -> n_prior_gp_input: 1225, n_addon_gp_input: 100, n_cat_covariates_embed_input: 0, n_output: 3045
#   全量 nodes: 2052
#   全量 edges: 16416
#
# --- INITIALIZING TRAINER ---
# Number of training nodes: 2052
# Number of validation nodes: 0
# Number of training edges: 8204
# Number of validation edges: 0
# Edge batch size: 16416
# Node batch size: 2052
#
# --- MODEL TRAINING ---
# Epoch 1/125 |--------------------| 0.8% train_global_loss: 1674041.6250; train_optim_loss: 1674041.6250
# Epoch 2/125 |--------------------| 1.6% train_global_loss: 1644285.7500; train_optim_loss: 1644285.7500
# Epoch 3/125 |--------------------| 2.4% train_global_loss: 1624563.5000; train_optim_loss: 1624563.5000
# Epoch 4/125 |--------------------| 3.2% train_global_loss: 1609820.2500; train_optim_loss: 1609820.2500
# Epoch 5/125 |--------------------| 4.0% train_global_loss: 1598201.5000; train_optim_loss: 1598201.5000
# Epoch 6/125 |--------------------| 4.8% train_global_loss: 1589454.2500; train_optim_loss: 1589454.2500
# Epoch 7/125 |█-------------------| 5.6% train_global_loss: 1582905.7500; train_optim_loss: 1582905.7500
# Epoch 8/125 |█-------------------| 6.4% train_global_loss: 1577373.7500; train_optim_loss: 1577373.7500
# Epoch 9/125 |█-------------------| 7.2% train_global_loss: 1572970.3750; train_optim_loss: 1572970.3750
# Epoch 10/125 |█-------------------| 8.0% train_global_loss: 1568941.0000; train_optim_loss: 1568941.0000
# Epoch 11/125 |█-------------------| 8.8% train_global_loss: 1565098.8750; train_optim_loss: 1565098.8750
# Epoch 12/125 |█-------------------| 9.6% train_global_loss: 1561315.7500; train_optim_loss: 1561315.7500
# Epoch 13/125 |██------------------| 10.4% train_global_loss: 1557410.8750; train_optim_loss: 1557410.8750
# Epoch 14/125 |██------------------| 11.2% train_global_loss: 1553770.8750; train_optim_loss: 1553770.8750
# Epoch 15/125 |██------------------| 12.0% train_global_loss: 1550094.0000; train_optim_loss: 1550094.0000
# Epoch 16/125 |██------------------| 12.8% train_global_loss: 1546571.7500; train_optim_loss: 1546571.7500
# Epoch 17/125 |██------------------| 13.6% train_global_loss: 1543106.0000; train_optim_loss: 1543106.0000
# Epoch 18/125 |██------------------| 14.4% train_global_loss: 1539744.7500; train_optim_loss: 1539744.7500
# Epoch 19/125 |███-----------------| 15.2% train_global_loss: 1536361.6250; train_optim_loss: 1536361.6250
# Epoch 20/125 |███-----------------| 16.0% train_global_loss: 1533046.8750; train_optim_loss: 1533046.8750
# Epoch 21/125 |███-----------------| 16.8% train_global_loss: 1529760.7500; train_optim_loss: 1529760.7500
# Epoch 22/125 |███-----------------| 17.6% train_global_loss: 1526352.0000; train_optim_loss: 1526352.0000
# Epoch 23/125 |███-----------------| 18.4% train_global_loss: 1522975.5000; train_optim_loss: 1522975.5000
# Epoch 24/125 |███-----------------| 19.2% train_global_loss: 1519614.1250; train_optim_loss: 1519614.1250
# Epoch 25/125 |████----------------| 20.0% train_global_loss: 1516156.7500; train_optim_loss: 1516156.7500
# Epoch 26/125 |████----------------| 20.8% train_global_loss: 1512785.8750; train_optim_loss: 1512785.8750
# Epoch 27/125 |████----------------| 21.6% train_global_loss: 1509388.0000; train_optim_loss: 1509388.0000
# Epoch 28/125 |████----------------| 22.4% train_global_loss: 1505940.0000; train_optim_loss: 1505940.0000
# Epoch 29/125 |████----------------| 23.2% train_global_loss: 1502426.0000; train_optim_loss: 1502426.0000
# Epoch 30/125 |████----------------| 24.0% train_global_loss: 1498942.5000; train_optim_loss: 1498942.5000
# Epoch 31/125 |████----------------| 24.8% train_global_loss: 1495350.2500; train_optim_loss: 1495350.2500
# Epoch 32/125 |█████---------------| 25.6% train_global_loss: 1491781.2500; train_optim_loss: 1491781.2500
# Epoch 33/125 |█████---------------| 26.4% train_global_loss: 1488209.5000; train_optim_loss: 1488209.5000
# Epoch 34/125 |█████---------------| 27.2% train_global_loss: 1484605.8750; train_optim_loss: 1484605.8750
# Epoch 35/125 |█████---------------| 28.0% train_global_loss: 1480910.1250; train_optim_loss: 1480910.1250
# Epoch 36/125 |█████---------------| 28.8% train_global_loss: 1477230.7500; train_optim_loss: 1477230.7500
# Epoch 37/125 |█████---------------| 29.6% train_global_loss: 1473546.2500; train_optim_loss: 1473546.2500
# Epoch 38/125 |██████--------------| 30.4% train_global_loss: 1469792.5000; train_optim_loss: 1469792.5000
# Epoch 39/125 |██████--------------| 31.2% train_global_loss: 1466065.0000; train_optim_loss: 1466065.0000
# Epoch 40/125 |██████--------------| 32.0% train_global_loss: 1462306.1250; train_optim_loss: 1462306.1250
# Epoch 41/125 |██████--------------| 32.8% train_global_loss: 1458487.3750; train_optim_loss: 1458487.3750
# Epoch 42/125 |██████--------------| 33.6% train_global_loss: 1454712.0000; train_optim_loss: 1454712.0000
# Epoch 43/125 |██████--------------| 34.4% train_global_loss: 1450912.7500; train_optim_loss: 1450912.7500
# Epoch 44/125 |███████-------------| 35.2% train_global_loss: 1447082.7500; train_optim_loss: 1447082.7500
# Epoch 45/125 |███████-------------| 36.0% train_global_loss: 1443250.0000; train_optim_loss: 1443250.0000
# Epoch 46/125 |███████-------------| 36.8% train_global_loss: 1439464.6250; train_optim_loss: 1439464.6250
# Epoch 47/125 |███████-------------| 37.6% train_global_loss: 1435589.3750; train_optim_loss: 1435589.3750
# Epoch 48/125 |███████-------------| 38.4% train_global_loss: 1431757.0000; train_optim_loss: 1431757.0000
# Epoch 49/125 |███████-------------| 39.2% train_global_loss: 1427881.6250; train_optim_loss: 1427881.6250
# Epoch 50/125 |████████------------| 40.0% train_global_loss: 1424083.1250; train_optim_loss: 1424083.1250
# Epoch 51/125 |████████------------| 40.8% train_global_loss: 1420292.3750; train_optim_loss: 1420292.3750
# Epoch 52/125 |████████------------| 41.6% train_global_loss: 1416500.0000; train_optim_loss: 1416500.0000
# Epoch 53/125 |████████------------| 42.4% train_global_loss: 1412670.7500; train_optim_loss: 1412670.7500
# Epoch 54/125 |████████------------| 43.2% train_global_loss: 1408875.2500; train_optim_loss: 1408875.2500
# Epoch 55/125 |████████------------| 44.0% train_global_loss: 1405137.2500; train_optim_loss: 1405137.2500
# Epoch 56/125 |████████------------| 44.8% train_global_loss: 1401348.0000; train_optim_loss: 1401348.0000
# Epoch 57/125 |█████████-----------| 45.6% train_global_loss: 1397615.5000; train_optim_loss: 1397615.5000
# Epoch 58/125 |█████████-----------| 46.4% train_global_loss: 1393944.1250; train_optim_loss: 1393944.1250
# Epoch 59/125 |█████████-----------| 47.2% train_global_loss: 1390258.2500; train_optim_loss: 1390258.2500
# Epoch 60/125 |█████████-----------| 48.0% train_global_loss: 1386644.0000; train_optim_loss: 1386644.0000
# Epoch 61/125 |█████████-----------| 48.8% train_global_loss: 1382998.5000; train_optim_loss: 1382998.5000
# Epoch 62/125 |█████████-----------| 49.6% train_global_loss: 1379453.3750; train_optim_loss: 1379453.3750
# Epoch 63/125 |██████████----------| 50.4% train_global_loss: 1375893.2500; train_optim_loss: 1375893.2500
# Epoch 64/125 |██████████----------| 51.2% train_global_loss: 1372422.6250; train_optim_loss: 1372422.6250
# Epoch 65/125 |██████████----------| 52.0% train_global_loss: 1368892.2500; train_optim_loss: 1368892.2500
# Epoch 66/125 |██████████----------| 52.8% train_global_loss: 1365508.1250; train_optim_loss: 1365508.1250
# Epoch 67/125 |██████████----------| 53.6% train_global_loss: 1362132.6250; train_optim_loss: 1362132.6250
# Epoch 68/125 |██████████----------| 54.4% train_global_loss: 1358697.7500; train_optim_loss: 1358697.7500
# Epoch 69/125 |███████████---------| 55.2% train_global_loss: 1355409.5000; train_optim_loss: 1355409.5000
# Epoch 70/125 |███████████---------| 56.0% train_global_loss: 1352147.2500; train_optim_loss: 1352147.2500
# Epoch 71/125 |███████████---------| 56.8% train_global_loss: 1348941.0000; train_optim_loss: 1348941.0000
# Epoch 72/125 |███████████---------| 57.6% train_global_loss: 1345656.8750; train_optim_loss: 1345656.8750
# Epoch 73/125 |███████████---------| 58.4% train_global_loss: 1342524.5000; train_optim_loss: 1342524.5000
# Epoch 74/125 |███████████---------| 59.2% train_global_loss: 1339401.1250; train_optim_loss: 1339401.1250
# Epoch 75/125 |████████████--------| 60.0% train_global_loss: 1336315.2500; train_optim_loss: 1336315.2500
# Epoch 76/125 |████████████--------| 60.8% train_global_loss: 1333341.7500; train_optim_loss: 1333341.7500
# Epoch 77/125 |████████████--------| 61.6% train_global_loss: 1330022.2500; train_optim_loss: 1330022.2500
# Epoch 78/125 |████████████--------| 62.4% train_global_loss: 1327165.5000; train_optim_loss: 1327165.5000
# Epoch 79/125 |████████████--------| 63.2% train_global_loss: 1324298.7500; train_optim_loss: 1324298.7500
# Epoch 80/125 |████████████--------| 64.0% train_global_loss: 1321549.7500; train_optim_loss: 1321549.7500
# Epoch 81/125 |████████████--------| 64.8% train_global_loss: 1318725.2500; train_optim_loss: 1318725.2500
# Epoch 82/125 |█████████████-------| 65.6% train_global_loss: 1315996.7500; train_optim_loss: 1315996.7500
# Epoch 83/125 |█████████████-------| 66.4% train_global_loss: 1313305.6250; train_optim_loss: 1313305.6250
# Epoch 84/125 |█████████████-------| 67.2% train_global_loss: 1310656.7500; train_optim_loss: 1310656.7500
# Epoch 85/125 |█████████████-------| 68.0% train_global_loss: 1308213.2500; train_optim_loss: 1308213.2500
# Epoch 86/125 |█████████████-------| 68.8% train_global_loss: 1305651.7500; train_optim_loss: 1305651.7500
# Epoch 87/125 |█████████████-------| 69.6% train_global_loss: 1303164.7500; train_optim_loss: 1303164.7500
# Epoch 88/125 |██████████████------| 70.4% train_global_loss: 1300739.5000; train_optim_loss: 1300739.5000
# Epoch 89/125 |██████████████------| 71.2% train_global_loss: 1298324.0000; train_optim_loss: 1298324.0000
# Epoch 90/125 |██████████████------| 72.0% train_global_loss: 1295846.7500; train_optim_loss: 1295846.7500
# Epoch 91/125 |██████████████------| 72.8% train_global_loss: 1293368.5000; train_optim_loss: 1293368.5000
# Epoch 92/125 |██████████████------| 73.6% train_global_loss: 1291038.5000; train_optim_loss: 1291038.5000
# Epoch 93/125 |██████████████------| 74.4% train_global_loss: 1288827.5000; train_optim_loss: 1288827.5000
# Epoch 94/125 |███████████████-----| 75.2% train_global_loss: 1286551.2500; train_optim_loss: 1286551.2500
# Epoch 95/125 |███████████████-----| 76.0% train_global_loss: 1284435.2500; train_optim_loss: 1284435.2500
# Epoch 96/125 |███████████████-----| 76.8% train_global_loss: 1282218.5000; train_optim_loss: 1282218.5000
# Epoch 97/125 |███████████████-----| 77.6% train_global_loss: 1280126.5000; train_optim_loss: 1280126.5000
# Epoch 98/125 |███████████████-----| 78.4% train_global_loss: 1278061.5000; train_optim_loss: 1278061.5000
# Epoch 99/125 |███████████████-----| 79.2% train_global_loss: 1275995.0000; train_optim_loss: 1275995.0000
# Epoch 100/125 |████████████████----| 80.0% train_global_loss: 1273955.2500; train_optim_loss: 1273955.2500
# Epoch 101/125 |████████████████----| 80.8% train_global_loss: 1271928.0000; train_optim_loss: 1271928.0000
# Epoch 102/125 |████████████████----| 81.6% train_global_loss: 1269940.8750; train_optim_loss: 1269940.8750
# Epoch 103/125 |████████████████----| 82.4% train_global_loss: 1267821.1250; train_optim_loss: 1267821.1250
# Epoch 104/125 |████████████████----| 83.2% train_global_loss: 1265702.7500; train_optim_loss: 1265702.7500
# Epoch 105/125 |████████████████----| 84.0% train_global_loss: 1263776.8750; train_optim_loss: 1263776.8750
# Epoch 106/125 |████████████████----| 84.8% train_global_loss: 1261955.6250; train_optim_loss: 1261955.6250
# Epoch 107/125 |█████████████████---| 85.6% train_global_loss: 1260040.5000; train_optim_loss: 1260040.5000
# Epoch 108/125 |█████████████████---| 86.4% train_global_loss: 1258216.7500; train_optim_loss: 1258216.7500
# Epoch 109/125 |█████████████████---| 87.2% train_global_loss: 1256330.5000; train_optim_loss: 1256330.5000
# Epoch 110/125 |█████████████████---| 88.0% train_global_loss: 1254612.2500; train_optim_loss: 1254612.2500
# Epoch 111/125 |█████████████████---| 88.8% train_global_loss: 1252835.5000; train_optim_loss: 1252835.5000
# Epoch 112/125 |█████████████████---| 89.6% train_global_loss: 1250937.3750; train_optim_loss: 1250937.3750
# Epoch 113/125 |██████████████████--| 90.4% train_global_loss: 1249224.7500; train_optim_loss: 1249224.7500
# Epoch 114/125 |██████████████████--| 91.2% train_global_loss: 1247495.5000; train_optim_loss: 1247495.5000
# Epoch 115/125 |██████████████████--| 92.0% train_global_loss: 1245777.7500; train_optim_loss: 1245777.7500
# Epoch 116/125 |██████████████████--| 92.8% train_global_loss: 1244182.5000; train_optim_loss: 1244182.5000
# Epoch 117/125 |██████████████████--| 93.6% train_global_loss: 1242401.7500; train_optim_loss: 1242401.7500
# Epoch 118/125 |██████████████████--| 94.4% train_global_loss: 1240805.0000; train_optim_loss: 1240805.0000
# Epoch 119/125 |███████████████████-| 95.2% train_global_loss: 1239221.5000; train_optim_loss: 1239221.5000
# Epoch 120/125 |███████████████████-| 96.0% train_global_loss: 1237575.8750; train_optim_loss: 1237575.8750
# Epoch 121/125 |███████████████████-| 96.8% train_global_loss: 1236186.5000; train_optim_loss: 1236186.5000
# Epoch 122/125 |███████████████████-| 97.6% train_global_loss: 1234417.7500; train_optim_loss: 1234417.7500
# Epoch 123/125 |███████████████████-| 98.4% train_global_loss: 1232785.2500; train_optim_loss: 1232785.2500
# Epoch 124/125 |███████████████████-| 99.2% train_global_loss: 1231224.7500; train_optim_loss: 1231224.7500
# Epoch 125/125 |████████████████████| 100.0% train_global_loss: 1229716.7500; train_optim_loss: 1229716.7500
#
# Model training finished after 0 min 26 sec.
# Using best model state, which was in epoch 125.
# ✅ n_sampled_neighbors = 12 | ARI = 0.5890 | valid spots = 2052
#
# ================================================================================
# 🎉 n_sampled_neighbors 参数敏感性分析完成！
# ✅ 结果 CSV 已保存至: /home/zhangjunyi/xiangmu/nichecompass-main/outputs/case/parameter_analysis/n_sampled_neighbors/SN048_A121573_Rep1/parameter_sensitivity_n_sampled_neighbors_ARI.csv
# ================================================================================
#              parameter  n_sampled_neighbors       ARI  valid_spots_for_ARI  \
# 0  n_sampled_neighbors                    2  0.591926                 2052
# 1  n_sampled_neighbors                    4  0.599547                 2052
# 2  n_sampled_neighbors                    6  0.588969                 2052
# 3  n_sampled_neighbors                    8  0.587475                 2052
# 4  n_sampled_neighbors                   10  0.590465                 2052
# 5  n_sampled_neighbors                   12  0.588969                 2052
#
#        pathology_column                                          h5ad_path
# 0  pathology_annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 1  pathology_annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 2  pathology_annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 3  pathology_annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 4  pathology_annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 5  pathology_annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...

# %%
# =========================================================
# Cell 4: 读取结果 CSV 并绘制 n_sampled_neighbors - ARI 曲线
# =========================================================

import os
import pandas as pd
import matplotlib.pyplot as plt

csv_path = os.path.join(
    CONFIG["save_root"],
    "parameter_sensitivity_n_sampled_neighbors_ARI.csv"
)

results_df = pd.read_csv(csv_path)

display(results_df)

plt.figure(figsize=(7, 5))

plt.plot(
    results_df["n_sampled_neighbors"],
    results_df["ARI"],
    marker="o"
)

plt.xlabel("n_sampled_neighbors")
plt.ylabel("ARI")
plt.title(
    f"Sensitivity Analysis: n_sampled_neighbors vs ARI\n"
    f"{CONFIG['dataset_name']}"
)

plt.grid(True, alpha=0.3)
plt.tight_layout()

fig_path = os.path.join(
    CONFIG["save_root"],
    "ARI_curve_n_sampled_neighbors.png"
)

plt.savefig(
    fig_path,
    dpi=300,
    bbox_inches="tight"
)

plt.show()

print(f"✅ ARI 曲线图已保存至: {fig_path}")
# Out:
#              parameter  n_sampled_neighbors       ARI  valid_spots_for_ARI  \
# 0  n_sampled_neighbors                    2  0.591926                 2052
# 1  n_sampled_neighbors                    4  0.599547                 2052
# 2  n_sampled_neighbors                    6  0.588969                 2052
# 3  n_sampled_neighbors                    8  0.587475                 2052
# 4  n_sampled_neighbors                   10  0.590465                 2052
# 5  n_sampled_neighbors                   12  0.588969                 2052
#
#        pathology_column                                          h5ad_path
# 0  pathology_annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 1  pathology_annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 2  pathology_annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 3  pathology_annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 4  pathology_annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 5  pathology_annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# ✅ ARI 曲线图已保存至: /home/zhangjunyi/xiangmu/nichecompass-main/outputs/case/parameter_analysis/n_sampled_neighbors/SN048_A121573_Rep1/ARI_curve_n_sampled_neighbors.png
