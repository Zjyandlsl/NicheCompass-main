# %%
# =========================================================
# 指定使用物理 GPU 1
# 注意：必须放在 import torch 之前；如果 torch 已经导入，需要重启 kernel 后重新运行
# =========================================================
import os

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
# =========================================================
# Cell 1: import、随机种子、全局配置 CONFIG
# 参数组合热图分析: lambda_edge_recon_AND_lambda_gene_expr_recon
# =========================================================

import os
import sys
import gc
import random
import warnings

import numpy as np
import pandas as pd
import scipy.sparse as sp
import matplotlib.pyplot as plt

import anndata as ad
import scanpy as sc
import squidpy as sq
import decoupler as dc

from IPython.display import display
from sklearn.preprocessing import MinMaxScaler
from sklearn.mixture import GaussianMixture
from sklearn.metrics import adjusted_rand_score
from scipy.stats import hypergeom
from statsmodels.stats.multitest import multipletests

warnings.filterwarnings("ignore")

# --------------------------
# 0. 当前数据集与参数分析配置
# --------------------------
CONFIG = {'dataset_name': 'Human_Prostate_Cancer',
 'input_h5ad': '/home/zhangjunyi/xiangmu/nichecompass-main/datasets/Human_Prostate_Cancer/Human_Prostate_Cancer_annotated.h5ad',
 'gmm_threshold_csv_candidates': ['/home/zhangjunyi/xiangmu/nichecompass-main/outputs/test/Human_Prostate_Cancer/SpaCET/GMM_Optimal_Threshold_Result.csv',
                                  '/home/zhangjunyi/xiangmu/nichecompass-main/outputs/Human_Prostate_Cancer/SpaCET/GMM_Optimal_Threshold_Result.csv'],
 'save_root': '/home/zhangjunyi/xiangmu/nichecompass-main/outputs/case/parameter_analysis/edge_recon_And_gene_expr_recon/Human_Prostate_Cancer',
 'file_prefix': 'Human_Prostate_Cancer',
 'pathology_col_candidates': ['Pathology_Annotation', 'pathology_annotation'],
 'gt_map': 'prostate_dynamic',
 'n_epochs': 30,
 'seed': 42,
 'local_src': '/home/zhangjunyi/xiangmu/nichecompass-main/src',
 'nichenet_cache_dir': '/home/zhangjunyi/xiangmu/nichecompass-main/cache_nichenet',
 'n_top_hvg': 3000,
 'spatial_graph_n_neighs': 8,
 'latent_key': 'nichecompass_latent',
 'native_cluster_key': 'latent_leiden_0.6',
 'leiden_resolution': 0.6,
 'latent_node_batch_size': 128,
 'low_malig_offset': 0.2,
 'MIN_FC': 1.3,
 'MIN_ACTIVE_SPOTS': 10,
 'MIN_INTENSITY_RATIO': 1.2,
 'QUIESCENT_COLD_AXIS_NUM': 6,
 'tmcn_file_path': '/home/zhangjunyi/xiangmu/nichecompass-main/data/pre_data/siyuanzu/my_metabolite_network.csv',
 'analysis_name': 'lambda_edge_recon_AND_lambda_gene_expr_recon',
 'x_param_name': 'lambda_gene_expr_recon',
 'y_param_name': 'lambda_edge_recon',
'lambda_edge_recon_range': [1e3, 1e4, 1e5, 1e6, 1e7],
'lambda_gene_expr_recon_range': [25.0, 50.0, 100.0, 150.0,200.0,250.0, 400.0],
 'fixed_n_sampled_neighbors': 4,
 'fixed_lr': 0.0001,
 'fixed_lambda_edge_recon': 100000.0,
 'fixed_lambda_gene_expr_recon': 100.0}

os.makedirs(CONFIG["save_root"], exist_ok=True)

# --------------------------
# 1. 固定随机种子
# --------------------------
def set_seed(seed=42):
    os.environ["PYTHONHASHSEED"] = str(seed)
    os.environ["OMP_NUM_THREADS"] = "1"
    os.environ["MKL_NUM_THREADS"] = "1"
    os.environ["OPENBLAS_NUM_THREADS"] = "1"
    os.environ["NUMEXPR_NUM_THREADS"] = "1"
    os.environ["CUBLAS_WORKSPACE_CONFIG"] = ":4096:8"

    random.seed(seed)
    np.random.seed(seed)

    import torch
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    try:
        torch.use_deterministic_algorithms(True, warn_only=True)
    except Exception as e:
        print("deterministic warn_only 模式未完全启用：", e)
    torch.set_num_threads(1)

set_seed(CONFIG["seed"])

# --------------------------
# 2. 导入 NicheCompass
# --------------------------
LOCAL_SRC = CONFIG["local_src"]
if LOCAL_SRC not in sys.path:
    sys.path.insert(0, LOCAL_SRC)

import nichecompass as nc
import torch

print("✅ CUDA 可用状态:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("✅ 当前使用 GPU:", torch.cuda.get_device_name(0))
print("✅ NicheCompass 路径:", nc.__file__)
print("✅ 数据集:", CONFIG["dataset_name"])
print("✅ 参数分析:", CONFIG["analysis_name"])
print("✅ 输出目录:", CONFIG["save_root"])
# Out:
# ✅ CUDA 可用状态: True
# ✅ 当前使用 GPU: A100 80GB PCIe
# ✅ NicheCompass 路径: /home/zhangjunyi/xiangmu/nichecompass-main/src/nichecompass/__init__.py
# ✅ 数据集: Human_Prostate_Cancer
# ✅ 参数分析: lambda_edge_recon_AND_lambda_gene_expr_recon
# ✅ 输出目录: /home/zhangjunyi/xiangmu/nichecompass-main/outputs/case/parameter_analysis/edge_recon_And_gene_expr_recon/Human_Prostate_Cancer

# %%
# =========================================================
# Cell 2: 工具函数：知识库、Sender/Receiver、训练、生态位判定、ARI
# =========================================================

# --------------------------
# 3. TMCN 代谢通讯轴知识库
# 从外部四元组 CSV 文件读取
# --------------------------

tmcn_file_path = CONFIG["tmcn_file_path"]

if not os.path.exists(tmcn_file_path):
    raise FileNotFoundError(f"❌ 未找到四元组文件: {tmcn_file_path}")

axis_table = pd.read_csv(tmcn_file_path, encoding="utf-8-sig")

required_cols = [
    "TMCN_Name",
    "Source_Pathways",
    "Source_Genes",
    "Target_Genes",
    "Biologic_Meaning"
]

missing_cols = [c for c in required_cols if c not in axis_table.columns]
if len(missing_cols) > 0:
    raise ValueError(
        f"❌ 四元组文件缺少必要列: {missing_cols}\n"
        f"当前文件列名为: {axis_table.columns.tolist()}"
    )

axis_table["TMCN_Name"] = axis_table["TMCN_Name"].astype(str).str.strip()

AXES = [
    x.replace("TMCN_", "").replace("_Axis", "")
    for x in axis_table["TMCN_Name"]
]

print("✅ 已从外部 CSV 文件加载 TMCN 四元组知识库")
print(f"📄 文件路径: {tmcn_file_path}")
print(f"✅ 共加载 {len(axis_table)} 条代谢通讯轴")
print(f"✅ AXES = {AXES}")

display(axis_table)

def split_items(x):
    return [i.strip() for i in str(x).split(",") if i.strip()]


def get_valid_genes(adata_obj, genes):
    return [g for g in genes if g in adata_obj.var_names]


def read_gmm_threshold():
    for p in CONFIG["gmm_threshold_csv_candidates"]:
        if os.path.exists(p):
            gmm_df = pd.read_csv(p)
            val = float(gmm_df.loc[gmm_df["Metric"] == "Optimal_GMM_Threshold", "Value"].iloc[0])
            print(f"✅ 读取 GMM 阈值: {val:.4f} | {p}")
            return val
    raise FileNotFoundError("❌ 未找到 GMM_Optimal_Threshold_Result.csv，请检查 CONFIG['gmm_threshold_csv_candidates']。")


def find_malig_col(adata_obj):
    for c in ["Malignant", "malignant", "Tumor", "tumor", "Cancer", "cancer"]:
        if c in adata_obj.obs.columns:
            return c
    raise KeyError("❌ 未找到 SpaCET 恶性分数字段，如 Malignant。")


def find_pathology_col(adata_obj):
    for c in CONFIG["pathology_col_candidates"]:
        if c in adata_obj.obs.columns:
            return c
    raise KeyError(f"❌ 未找到病理注释列。候选列: {CONFIG['pathology_col_candidates']}\n当前列: {adata_obj.obs.columns.tolist()}")


# =========================================================
# A. 只计算一次：Sender / Receiver 分数
# =========================================================
def compute_sender_receiver_scores():
    print("\n=== A. 加载数据并计算 Sender / Receiver 分数 ===")
    adata_raw = sc.read_h5ad(CONFIG["input_h5ad"])
    print(f"✅ 数据加载成功: {adata_raw.n_obs} spots, {adata_raw.n_vars} genes")

    # PROGENy pathway score
    print("--> 计算 Pathway_score (PROGENy)...")
    net_progeny = dc.get_progeny(organism="human", top=500)
    dc.run_mlm(
        mat=adata_raw,
        net=net_progeny,
        source="source",
        target="target",
        weight="weight",
        verbose=False,
        use_raw=False
    )
    df_pathway = dc.get_acts(adata_raw, obsm_key="mlm_estimate").to_df()
    df_pathway.columns = [c.strip().replace("-", "_").replace(" ", "_") for c in df_pathway.columns]

    # AUCell enzyme score
    print("--> 计算 Enzyme_score (AUCell)...")
    enzyme_records = []
    for _, row in axis_table.iterrows():
        ax = row["TMCN_Name"].replace("TMCN_", "").replace("_Axis", "")
        for g in split_items(row["Source_Genes"]):
            if g in adata_raw.var_names:
                enzyme_records.append({"source": ax, "target": g})

    if len(enzyme_records) == 0:
        raise ValueError("❌ 当前数据中没有任何 TMCN Source_Genes，可检查基因名是否为 Gene Symbol。")

    dc.run_aucell(
        mat=adata_raw,
        net=pd.DataFrame(enzyme_records),
        source="source",
        target="target",
        min_n=1,
        verbose=False,
        use_raw=False
    )
    df_enzyme = dc.get_acts(adata_raw, obsm_key="aucell_estimate").to_df()

    scaler = MinMaxScaler()
    df_pathway_scaled = pd.DataFrame(
        scaler.fit_transform(df_pathway),
        index=df_pathway.index,
        columns=df_pathway.columns
    )
    df_enzyme_scaled = pd.DataFrame(
        scaler.fit_transform(df_enzyme),
        index=df_enzyme.index,
        columns=df_enzyme.columns
    )

    def calc_receptor_score(genes):
        valid = get_valid_genes(adata_raw, genes)
        if not valid:
            return np.zeros(adata_raw.n_obs)
        X_sub = adata_raw[:, valid].X
        if sp.issparse(X_sub):
            mean_exp = np.asarray(X_sub.mean(axis=1)).reshape(-1)
        else:
            mean_exp = np.asarray(X_sub).mean(axis=1).reshape(-1)
        return scaler.fit_transform(mean_exp.reshape(-1, 1)).flatten()

    print("--> 计算 Sender_score 与 Receiver_score...")
    for _, row in axis_table.iterrows():
        ax = row["TMCN_Name"].replace("TMCN_", "").replace("_Axis", "")
        pathways = [p.strip().replace("-", "_").replace(" ", "_") for p in split_items(row["Source_Pathways"])]
        target_genes = split_items(row["Target_Genes"])

        valid_paths = [p for p in pathways if p in df_pathway_scaled.columns]
        if len(valid_paths) > 0:
            p_score = df_pathway_scaled[valid_paths].mean(axis=1).values
        else:
            p_score = np.zeros(adata_raw.n_obs)

        if ax in df_enzyme_scaled.columns:
            e_score = df_enzyme_scaled[ax].values
        else:
            e_score = np.zeros(adata_raw.n_obs)

        adata_raw.obs[f"{ax}_Sender_Score"] = p_score * e_score
        adata_raw.obs[f"{ax}_Receiver_Score"] = calc_receptor_score(target_genes)

    print("✅ Sender / Receiver 分数计算完成。")
    return adata_raw


# =========================================================
# B. 每个参数值重新构建 adata_model 并训练
# =========================================================
def prepare_adata_model(adata_scored):
    adata_model = adata_scored.copy()

    sc.pp.filter_genes(adata_model, min_cells=10)
    sc.pp.highly_variable_genes(
        adata_model,
        n_top_genes=CONFIG["n_top_hvg"],
        flavor="seurat_v3",
        subset=False
    )

    tmcn_gene_set = set()
    for _, row in axis_table.iterrows():
        tmcn_gene_set.update(split_items(row["Source_Genes"]))
        tmcn_gene_set.update(split_items(row["Target_Genes"]))
    tmcn_gene_set = {g for g in tmcn_gene_set if g in adata_model.var_names}

    keep_mask = adata_model.var["highly_variable"].values | adata_model.var_names.isin(list(tmcn_gene_set))
    adata_model = adata_model[:, keep_mask].copy()

    counts_key = "counts" if "counts" in adata_model.layers else None
    x_for_lib = adata_model.layers[counts_key] if counts_key is not None else adata_model.X
    lib_size = np.asarray(x_for_lib.sum(axis=1)).reshape(-1)
    valid_spot_mask = np.isfinite(lib_size) & (lib_size > 0)
    adata_model = adata_model[valid_spot_mask].copy()

    mat = adata_model.layers.get(counts_key) if counts_key else adata_model.X
    if sp.issparse(mat):
        mat = mat.copy()
        mat.data = np.nan_to_num(mat.data, nan=0.0, posinf=0.0, neginf=0.0)
        mat.data = np.clip(mat.data, a_min=0, a_max=None)
    else:
        mat = np.nan_to_num(mat, nan=0.0, posinf=0.0, neginf=0.0)
        mat = np.clip(mat, a_min=0, a_max=None)

    if counts_key:
        adata_model.layers[counts_key] = mat
    else:
        adata_model.X = mat

    sq.gr.spatial_neighbors(
        adata_model,
        coord_type="generic",
        spatial_key="spatial",
        n_neighs=CONFIG["spatial_graph_n_neighs"]
    )

    cache_dir = CONFIG["nichenet_cache_dir"]
    gp_dict = nc.utils.extract_gp_dict_from_nichenet_lrt_interactions(
        species="human",
        version="v2",
        keep_target_genes_ratio=0.25,
        max_n_target_genes_per_gp=50,
        load_from_disk=True,
        lr_network_file_path=f"{cache_dir}/nichenet_lr_network.csv",
        ligand_target_matrix_file_path=f"{cache_dir}/nichenet_ligand_target_matrix.csv"
    )
    nc.utils.add_gps_from_gp_dict_to_adata(gp_dict=gp_dict, adata=adata_model)

    return adata_model, counts_key


def train_nichecompass(adata_model, counts_key, lambda_edge_recon, lambda_gene_expr_recon):
    """训练 NicheCompass：本组只改变 lambda_edge_recon 和 lambda_gene_expr_recon。"""
    latent_key = CONFIG["latent_key"]
    adj_key = "spatial_connectivities"

    model = nc.models.NicheCompass(
        adata_model,
        counts_key=counts_key,
        adj_key=adj_key,
        gp_names_key="nichecompass_gp_names",
        active_gp_names_key="nichecompass_active_gp_names",
        gp_targets_mask_key="nichecompass_gp_targets",
        gp_targets_categories_mask_key="nichecompass_gp_targets_categories",
        gp_sources_mask_key="nichecompass_gp_sources",
        gp_sources_categories_mask_key="nichecompass_gp_sources_categories",
        latent_key=latent_key,
        conv_layer_encoder="gcnconv",
        active_gp_thresh_ratio=0.01,
    )

    full_node_batch_size = adata_model.n_obs
    full_edge_batch_size = int(adata_model.obsp["spatial_connectivities"].nnz)

    print(f"  全量 nodes: {full_node_batch_size}")
    print(f"  全量 edges: {full_edge_batch_size}")
    print(f"  lambda_edge_recon = {lambda_edge_recon}")
    print(f"  lambda_gene_expr_recon = {lambda_gene_expr_recon}")

    model.train(
        n_epochs=CONFIG["n_epochs"],
        n_epochs_all_gps=10,
        lr=CONFIG["fixed_lr"],
        lambda_edge_recon=lambda_edge_recon,
        lambda_gene_expr_recon=lambda_gene_expr_recon,
        lambda_l1_masked=0.0,
        edge_batch_size=full_edge_batch_size,
        node_batch_size=full_node_batch_size,
        n_sampled_neighbors=CONFIG["fixed_n_sampled_neighbors"],
        edge_val_ratio=0.0,
        node_val_ratio=0.0,
        use_cuda_if_available=True,
        verbose=False
    )

    adata_model.obsm[latent_key] = model.get_latent_representation(
        adata=adata_model,
        counts_key=counts_key,
        adj_key=adj_key,
        node_batch_size=CONFIG["latent_node_batch_size"],
    )

    sc.pp.neighbors(
        adata_model,
        use_rep=latent_key,
        key_added=latent_key,
        random_state=CONFIG["seed"]
    )
    sc.tl.umap(
        adata_model,
        neighbors_key=latent_key,
        random_state=CONFIG["seed"]
    )
    sc.tl.leiden(
        adata_model,
        neighbors_key=latent_key,
        key_added=CONFIG["native_cluster_key"],
        resolution=CONFIG["leiden_resolution"],
        random_state=CONFIG["seed"]
    )

    return adata_model, model

# =========================================================
# C. TMCN 生态位判定：复刻 Cell 7 核心逻辑
# =========================================================
def annotate_tmcn_niches(adata_model, hard_tumor_threshold):
    native_cluster_key = CONFIG["native_cluster_key"]
    adj_matrix = adata_model.obsp["spatial_connectivities"]

    # 1. Coupling Score
    for k in AXES:
        sender_scores = adata_model.obs[f"{k}_Sender_Score"].values
        receiver_scores = adata_model.obs[f"{k}_Receiver_Score"].values
        neighbor_receiver_sum = adj_matrix.dot(receiver_scores)
        raw_coupling = sender_scores * neighbor_receiver_sum
        adata_model.obs[f"Coupling_{k}"] = np.log1p(raw_coupling)

    # 2. 每条轴自适应阈值
    thresholds_dict = {}
    for k in AXES:
        scores = adata_model.obs[f"Coupling_{k}"].values
        scores_clean = scores[~np.isnan(scores) & (scores > 0)].reshape(-1, 1)
        t_high, t_quiet = None, None
        method_used = "Robust Dynamic Fallback"

        if len(scores_clean) > 50:
            try:
                gmm = GaussianMixture(n_components=2, random_state=CONFIG["seed"])
                labels = gmm.fit_predict(scores_clean)
                m0, m1 = gmm.means_[0][0], gmm.means_[1][0]
                s0 = np.sqrt(gmm.covariances_[0][0][0])
                s1 = np.sqrt(gmm.covariances_[1][0][0])
                if abs(m0 - m1) > 0.8 * np.std(scores_clean):
                    if m0 > m1:
                        t_high = np.min(scores_clean[labels == 0])
                        t_quiet = m1 + s1
                    else:
                        t_high = np.min(scores_clean[labels == 1])
                        t_quiet = m0 + s0
                    method_used = "GMM (2-Components)"
            except Exception:
                pass

        if t_high is None:
            mean_val = np.mean(scores)
            std_val = np.std(scores)
            t_high_candidate_1 = mean_val + 1.5 * std_val
            t_high_candidate_2 = np.quantile(scores, 0.95)
            t_high = max(t_high_candidate_1, t_high_candidate_2)
            t_quiet = mean_val

        if t_high < 0.15:
            t_high = np.inf

        thresholds_dict[k] = {"T_high": t_high, "T_quiet": t_quiet, "Method": method_used}
        adata_model.obs[f"Active_{k}"] = (scores >= t_high).astype(int)
        adata_model.obs[f"Quiet_{k}"] = (scores <= t_quiet).astype(int)

    # 3. low_malig_gate
    malig_col = find_malig_col(adata_model)
    low_malig_gate = max(0.0, hard_tumor_threshold - CONFIG["low_malig_offset"])
    adata_model.obs["Keep_By_LowMalig"] = (adata_model.obs[malig_col].astype(float).values >= low_malig_gate).astype(int)

    # 4. cluster 级统计富集
    M_global = adata_model.n_obs
    bg_active_counts = {k: int(adata_model.obs[f"Active_{k}"].sum()) for k in AXES}
    bg_quiet_counts = {k: int(adata_model.obs[f"Quiet_{k}"].sum()) for k in AXES}
    bg_active_fracs = {k: bg_active_counts[k] / M_global for k in AXES}
    bg_quiet_fracs = {k: bg_quiet_counts[k] / M_global for k in AXES}
    global_mean_scores = {k: adata_model.obs[f"Coupling_{k}"].mean() for k in AXES}

    native_clusters = sorted(adata_model.obs[native_cluster_key].astype(str).unique())
    pvals_active_dict = {k: [] for k in AXES}
    pvals_quiet_dict = {k: [] for k in AXES}

    for k in AXES:
        adata_model.obs[f"{k}_Cluster_Active_Frac"] = 0.0

    for c in native_clusters:
        c_mask = adata_model.obs[native_cluster_key].astype(str) == str(c)
        N_cluster = int(c_mask.sum())
        for k in AXES:
            k_obs_act = int(adata_model.obs.loc[c_mask, f"Active_{k}"].sum())
            k_obs_qui = int(adata_model.obs.loc[c_mask, f"Quiet_{k}"].sum())
            act_frac = k_obs_act / N_cluster if N_cluster > 0 else 0.0
            adata_model.obs.loc[c_mask, f"{k}_Cluster_Active_Frac"] = act_frac
            pval_a = hypergeom.sf(k_obs_act - 1, M_global, bg_active_counts[k], N_cluster) if k_obs_act > 0 else 1.0
            pval_q = hypergeom.sf(k_obs_qui - 1, M_global, bg_quiet_counts[k], N_cluster) if k_obs_qui > 0 else 1.0
            pvals_active_dict[k].append(pval_a)
            pvals_quiet_dict[k].append(pval_q)

    fdr_active_dict = {}
    for k in AXES:
        _, fdr_a, _, _ = multipletests(pvals_active_dict[k], method="fdr_bh")
        fdr_active_dict[k] = fdr_a

    cluster_annotations = {}
    cluster_stats = []
    for idx, c in enumerate(native_clusters):
        c_mask = adata_model.obs[native_cluster_key].astype(str) == str(c)
        N_cluster = int(c_mask.sum())
        sig_active_axes = []
        cold_axes = []

        for k in AXES:
            act_frac = float(adata_model.obs.loc[c_mask, f"{k}_Cluster_Active_Frac"].iloc[0]) if N_cluster > 0 else 0.0
            qui_frac = float(adata_model.obs.loc[c_mask, f"Quiet_{k}"].sum() / N_cluster) if N_cluster > 0 else 0.0
            k_obs_act = int(adata_model.obs.loc[c_mask, f"Active_{k}"].sum())
            cluster_mean_score = float(adata_model.obs.loc[c_mask, f"Coupling_{k}"].mean()) if N_cluster > 0 else 0.0
            fc_act = act_frac / (bg_active_fracs[k] + 1e-9)
            fdr_a = float(fdr_active_dict[k][idx])
            intensity_ratio = cluster_mean_score / (global_mean_scores[k] + 1e-9)

            if (fc_act >= CONFIG["MIN_FC"] and
                k_obs_act >= CONFIG["MIN_ACTIVE_SPOTS"] and
                intensity_ratio >= CONFIG["MIN_INTENSITY_RATIO"] and
                fdr_a < 0.05):
                sig_active_axes.append(k)

            if qui_frac > bg_quiet_fracs[k] or fc_act < 0.5:
                cold_axes.append(k)

        if len(sig_active_axes) == 0 and len(cold_axes) >= CONFIG["QUIESCENT_COLD_AXIS_NUM"]:
            c_label = "Quiescent (Background)"
        elif len(sig_active_axes) == 1:
            c_label = f"Single-axis: {sig_active_axes[0]}"
        elif len(sig_active_axes) >= 2:
            c_label = f"Multi-axis: {'_'.join(sig_active_axes)}"
        else:
            c_label = "Transitional"

        cluster_annotations[c] = c_label
        cluster_stats.append({
            "Cluster_ID": c,
            "Spot_Count": N_cluster,
            "Sig_Active_Axes": ",".join(sig_active_axes) if sig_active_axes else "None",
            "Cold_Axis_Count": len(cold_axes),
            "Initial_Label": c_label
        })

    adata_model.obs["Niche_Annotation_PreFilter"] = adata_model.obs[native_cluster_key].astype(str).map(cluster_annotations).astype(str)
    adata_model.obs["Niche_Annotation"] = adata_model.obs["Niche_Annotation_PreFilter"].astype(str)

    # 5. spot 级 low_malig_gate 过滤
    is_active_niche = adata_model.obs["Niche_Annotation"].str.startswith("Single-axis") | adata_model.obs["Niche_Annotation"].str.startswith("Multi-axis")
    low_malig_fail = adata_model.obs["Keep_By_LowMalig"].astype(int).values == 0
    adata_model.obs.loc[is_active_niche & low_malig_fail, "Niche_Annotation"] = "Transitional"

    # 6. 标准化成 Final_Niche_Type
    def standardize_label(x):
        x = str(x)
        if x.startswith("Single-axis:"):
            ax = x.split(":", 1)[1].strip()
            return f"TMCN_{ax}_Axis"
        if x.startswith("Multi-axis:"):
            axes = x.split(":", 1)[1].strip()
            return f"Multi_Axis_{axes}"
        if x.startswith("Quiescent"):
            return "TMCN_Quiescent"
        return "TMCN_Transitional"

    adata_model.obs["Final_Niche_Type"] = adata_model.obs["Niche_Annotation"].map(standardize_label).astype("category")

    cluster_stats_df = pd.DataFrame(cluster_stats)
    return adata_model, pd.DataFrame(thresholds_dict).T, cluster_stats_df


# =========================================================
# D. Cell 10 核心：生成 Level1 / Level2
# =========================================================
def build_level1_level2(adata_model, hard_tumor_threshold):
    malig_col = find_malig_col(adata_model)
    final_niche_str = adata_model.obs["Final_Niche_Type"].astype(str)

    is_spacet_tumor = adata_model.obs[malig_col].astype(float).values > hard_tumor_threshold
    is_quiescent = final_niche_str == "TMCN_Quiescent"
    is_transitional = final_niche_str == "TMCN_Transitional"
    is_quiescent_or_transitional = is_quiescent | is_transitional

    adata_model.obs["Level1_Macro_Region"] = "Healthy_Region"
    adata_model.obs["Level2_Micro_Niche"] = "Healthy_Region"

    tumor_mask = is_spacet_tumor | (~is_quiescent_or_transitional)
    adata_model.obs.loc[tumor_mask, "Level1_Macro_Region"] = "Tumor_Region"

    active_niche_mask = ~is_quiescent_or_transitional
    adata_model.obs.loc[active_niche_mask, "Level2_Micro_Niche"] = final_niche_str[active_niche_mask]

    target_tumor_quiescent_mask = is_spacet_tumor & is_quiescent_or_transitional
    adata_model.obs.loc[target_tumor_quiescent_mask, "Level2_Micro_Niche"] = "TMCN_Quiescent"

    adata_model.obs["Level1_Macro_Region"] = adata_model.obs["Level1_Macro_Region"].astype("category")
    adata_model.obs["Level2_Micro_Niche"] = adata_model.obs["Level2_Micro_Niche"].astype("category")
    return adata_model


# =========================================================
# E. 计算 ARI
# =========================================================
def calculate_level1_ari(adata_model):
    pathology_col = find_pathology_col(adata_model)
    patho = adata_model.obs[pathology_col].astype(str).str.strip()

    if CONFIG["gt_map"] == "prostate_dynamic":
        gt_raw = patho.map(lambda x: 1 if x == "Invasive carcinoma" else 0).astype(float).values
    else:
        gt_raw = patho.map(CONFIG["gt_map"]).astype(float).values

    pred_map = {
        "Healthy_Region": 0,
        "Tumor_Region": 1
    }
    pred_raw = adata_model.obs["Level1_Macro_Region"].astype(str).map(pred_map).astype(float).values

    valid_mask = (~np.isnan(gt_raw)) & (~np.isnan(pred_raw))
    y_true = gt_raw[valid_mask]
    y_pred = pred_raw[valid_mask]

    if len(y_true) == 0:
        raise ValueError(
            f"❌ ARI 有效 spot 数为 0。请检查病理列 {pathology_col} 和 gt_map。\n"
            f"当前病理标签: {patho.unique().tolist()}"
        )

    ari = adjusted_rand_score(y_true, y_pred)
    return float(ari), int(len(y_true)), pathology_col
# Out:
# ✅ 已从外部 CSV 文件加载 TMCN 四元组知识库
# 📄 文件路径: /home/zhangjunyi/xiangmu/nichecompass-main/data/pre_data/siyuanzu/my_metabolite_network.csv
# ✅ 共加载 10 条代谢通讯轴
# ✅ AXES = ['Lactate', 'Adenosine', 'PGE2', 'Glutamine', 'Succinate', 'Kynurenine', 'ATP', 'S1P', 'LPA', 'Glutamate']
#               TMCN_Name                  Source_Pathways  \
# 0     TMCN_Lactate_Axis           Hypoxia,EGFR,PI3K,MAPK
# 1   TMCN_Adenosine_Axis           Hypoxia,TGFb,NFkB,MAPK
# 2        TMCN_PGE2_Axis  NFkB,JAK-STAT,Hypoxia,MAPK,TNFa
# 3   TMCN_Glutamine_Axis      PI3K,MAPK,JAK-STAT,TGFb,WNT
# 4   TMCN_Succinate_Axis                Hypoxia,NFkB,TNFa
# 5  TMCN_Kynurenine_Axis               JAK-STAT,NFkB,TGFb
# 6         TMCN_ATP_Axis                 Hypoxia,p53,TNFa
# 7         TMCN_S1P_Axis                   NFkB,PI3K,MAPK
# 8         TMCN_LPA_Axis                   PI3K,MAPK,TGFb
# 9   TMCN_Glutamate_Axis                PI3K,MAPK,Hypoxia
#
#                           Source_Genes  \
# 0     SLC2A1,HK2,PKM,LDHA,LDHB,SLC16A3
# 1  ENTPD1,ENTPD2,NT5E,CD38,ENPP1,NT5C2
# 2    PLA2G4A,PTGS2,PTGES,ABCC4,SLCO2A1
# 3         GLUL,SLC38A1,SLC38A3,SLC38A5
# 4             SLC13A2,SLC13A3,SLC25A10
# 5                IDO1,TDO2,KYNU,SLC7A5
# 6                        PANX1,SLC17A9
# 7                    SPHK1,SPHK2,SPNS2
# 8                 ENPP2,PLA2G4A,LPCAT1
# 9                   GLS,SLC1A5,SLC7A11
#
#                                     Target_Genes              Biologic_Meaning
# 0                    SLC16A1,SLC16A7,HCAR1,HCAR2         乳酸_肿瘤酸化瓦伯格效应与基质反向代谢共生
# 1  ADORA1,ADORA2A,ADORA2B,ADORA3,SLC29A1,SLC29A2      腺苷_ATP水解级联驱动的强效免疫抑制与M2极化
# 2                    PTGER1,PTGER2,PTGER3,PTGER4      前列腺素E2_成纤维细胞激活与促癌炎症微环境重塑
# 3                SLC1A5,SLC7A5,SLC38A2,GLS,GLUD1       谷氨酰胺_基质向肿瘤供能的代谢寄生与大分子合成
# 4                                         SUCNR1    琥珀酸_缺血坏死区释放驱动的TAM致瘤极化与血管生成
# 5                                            AHR      犬尿氨酸_色氨酸剥夺与AHR介导的效应T细胞耗竭
# 6                             P2RX7,P2RY2,P2RY11  胞外ATP_坏死边缘释放的促炎性危险信号(DAMP)传导
# 7                              S1PR1,S1PR2,S1PR3   鞘氨醇-1-磷酸_脂质信号驱动的内皮血管生成与免疫趋化
# 8                        LPAR1,LPAR2,LPAR3,LPAR5        溶血磷脂酸_成纤维细胞基质重塑与肿瘤高侵袭性
# 9                                GRM3,GRM5,GRIN1          谷氨酸_突触样代谢通讯与微环境神经可塑性

# %%
# =========================================================
# Cell 3: 主循环：lambda_edge_recon × lambda_gene_expr_recon 参数组合热图实验
# =========================================================

def format_param_value(v):
    """把 1e5 / 100.0 这类值转成适合文件夹名的字符串。"""
    if isinstance(v, (int, np.integer)):
        return str(int(v))
    if isinstance(v, (float, np.floating)):
        if abs(v) >= 1000 or (abs(v) > 0 and abs(v) < 0.001):
            return f"{v:.0e}".replace("+", "")
        return str(v).replace(".", "p")
    return str(v).replace(".", "p")


def run_parameter_grid_analysis():
    os.makedirs(CONFIG["save_root"], exist_ok=True)

    hard_tumor_threshold = read_gmm_threshold()
    adata_scored = compute_sender_receiver_scores()

    all_results = []

    y_values = CONFIG["lambda_edge_recon_range"]
    x_values = CONFIG["lambda_gene_expr_recon_range"]

    total_runs = len(y_values) * len(x_values)
    run_idx = 0

    for lambda_edge_recon in y_values:
        for lambda_gene_expr_recon in x_values:
            run_idx += 1
            print("\n" + "=" * 90)
            print(
                f"🚀 [{run_idx}/{total_runs}] 参数组合: "
                f"lambda_edge_recon={lambda_edge_recon}, "
                f"lambda_gene_expr_recon={lambda_gene_expr_recon}"
            )
            print("=" * 90)

            set_seed(CONFIG["seed"])

            run_dir = os.path.join(
                CONFIG["save_root"],
                f"lambda_edge_recon_{format_param_value(lambda_edge_recon)}__"
                f"lambda_gene_expr_recon_{format_param_value(lambda_gene_expr_recon)}"
            )
            os.makedirs(run_dir, exist_ok=True)

            adata_model, counts_key = prepare_adata_model(adata_scored)

            adata_model, model = train_nichecompass(
                adata_model=adata_model,
                counts_key=counts_key,
                lambda_edge_recon=lambda_edge_recon,
                lambda_gene_expr_recon=lambda_gene_expr_recon
            )

            adata_model, thresholds_df, cluster_stats_df = annotate_tmcn_niches(
                adata_model=adata_model,
                hard_tumor_threshold=hard_tumor_threshold
            )

            adata_model = build_level1_level2(
                adata_model=adata_model,
                hard_tumor_threshold=hard_tumor_threshold
            )

            ari, n_valid, pathology_col = calculate_level1_ari(adata_model)

            print(
                f"✅ lambda_edge_recon={lambda_edge_recon} | "
                f"lambda_gene_expr_recon={lambda_gene_expr_recon} | "
                f"ARI={ari:.4f} | valid spots={n_valid}"
            )

            h5ad_path = os.path.join(
                run_dir,
                f"{CONFIG['file_prefix']}_edge_{format_param_value(lambda_edge_recon)}_"
                f"gene_{format_param_value(lambda_gene_expr_recon)}.h5ad"
            )
            adata_model.write_h5ad(h5ad_path)

            thresholds_df.to_csv(
                os.path.join(run_dir, "TMCN_thresholds.csv"),
                encoding="utf-8-sig"
            )

            cluster_stats_df.to_csv(
                os.path.join(run_dir, "TMCN_cluster_stats.csv"),
                index=False,
                encoding="utf-8-sig"
            )

            all_results.append({
                "lambda_edge_recon": lambda_edge_recon,
                "lambda_gene_expr_recon": lambda_gene_expr_recon,
                "ARI": round(ari, 6),
                "valid_spots_for_ARI": n_valid,
                "pathology_column": pathology_col,
                "h5ad_path": h5ad_path
            })

            try:
                del model
            except Exception:
                pass
            del adata_model
            gc.collect()
            if torch.cuda.is_available():
                torch.cuda.empty_cache()

    results_df = pd.DataFrame(all_results)

    csv_path = os.path.join(
        CONFIG["save_root"],
        "parameter_sensitivity_lambda_edge_recon_AND_lambda_gene_expr_recon_ARI.csv"
    )
    results_df.to_csv(csv_path, index=False, encoding="utf-8-sig")

    matrix_df = results_df.pivot(
        index="lambda_edge_recon",
        columns="lambda_gene_expr_recon",
        values="ARI"
    )
    matrix_csv_path = os.path.join(
        CONFIG["save_root"],
        "ARI_heatmap_matrix_lambda_edge_recon_AND_lambda_gene_expr_recon.csv"
    )
    matrix_df.to_csv(matrix_csv_path, encoding="utf-8-sig")

    print("\n" + "=" * 90)
    print("🎉 lambda_edge_recon × lambda_gene_expr_recon 参数组合分析完成！")
    print(f"✅ 长表 CSV: {csv_path}")
    print(f"✅ 热图矩阵 CSV: {matrix_csv_path}")
    print("=" * 90)

    display(results_df)
    display(matrix_df)

    return results_df, matrix_df


results_df, matrix_df = run_parameter_grid_analysis()
# Out:
# ✅ 读取 GMM 阈值: 0.7166 | /home/zhangjunyi/xiangmu/nichecompass-main/outputs/test/Human_Prostate_Cancer/SpaCET/GMM_Optimal_Threshold_Result.csv
#
# === A. 加载数据并计算 Sender / Receiver 分数 ===
# ✅ 数据加载成功: 4371 spots, 17943 genes
# --> 计算 Pathway_score (PROGENy)...
# --> 计算 Enzyme_score (AUCell)...
# --> 计算 Sender_score 与 Receiver_score...
# ✅ Sender / Receiver 分数计算完成。
#
# ==========================================================================================
# 🚀 [1/35] 参数组合: lambda_edge_recon=1000.0, lambda_gene_expr_recon=25.0
# ==========================================================================================
# --- INITIALIZING NEW NETWORK MODULE: VARIATIONAL GENE PROGRAM GRAPH AUTOENCODER ---
# LOSS -> include_edge_recon_loss: True, include_gene_expr_recon_loss: True, rna_recon_loss: nb
# NODE LABEL METHOD -> one-hop-norm
# ACTIVE GP THRESHOLD RATIO -> 0.01
# LOG VARIATIONAL -> True
# ONE HOP GCN NORM RNA NODE LABEL AGGREGATOR
# ENCODER -> n_input: 3047, n_cat_covariates_embed_input: 0, n_hidden: 1325, n_latent: 1225, n_addon_latent: 100, n_fc_layers: 1, n_layers: 1, conv_layer: gcnconv, n_attention_heads: 0, dropout_rate: 0.0,
# COSINE SIM GRAPH DECODER -> dropout_rate: 0.0
# MASKED TARGET RNA DECODER -> n_prior_gp_input: 1225, n_addon_gp_input: 100, n_cat_covariates_embed_input: 0, n_output: 3047
# MASKED SOURCE RNA DECODER -> n_prior_gp_input: 1225, n_addon_gp_input: 100, n_cat_covariates_embed_input: 0, n_output: 3047
#   全量 nodes: 4371
#   全量 edges: 34968
#   lambda_edge_recon = 1000.0
#   lambda_gene_expr_recon = 25.0
#
# --- INITIALIZING TRAINER ---
# Number of training nodes: 4371
# Number of validation nodes: 0
# Number of training edges: 17477
# Number of validation edges: 0
# Edge batch size: 34968
# Node batch size: 4371
#
# --- MODEL TRAINING ---
# Epoch 1/30 |--------------------| 3.3% train_global_loss: 930094.3125; train_optim_loss: 930094.3125
# Epoch 2/30 |█-------------------| 6.7% train_global_loss: 920486.5000; train_optim_loss: 920486.5000
# Epoch 3/30 |██------------------| 10.0% train_global_loss: 915132.7500; train_optim_loss: 915132.7500
# Epoch 4/30 |██------------------| 13.3% train_global_loss: 911767.6250; train_optim_loss: 911767.6250
# Epoch 5/30 |███-----------------| 16.7% train_global_loss: 909324.0625; train_optim_loss: 909324.0625
# Epoch 6/30 |████----------------| 20.0% train_global_loss: 907294.2500; train_optim_loss: 907294.2500
# Epoch 7/30 |████----------------| 23.3% train_global_loss: 905416.6250; train_optim_loss: 905416.6250
# Epoch 8/30 |█████---------------| 26.7% train_global_loss: 903631.8125; train_optim_loss: 903631.8125
# Epoch 9/30 |██████--------------| 30.0% train_global_loss: 901897.0625; train_optim_loss: 901897.0625
# Epoch 10/30 |██████--------------| 33.3% train_global_loss: 900204.6250; train_optim_loss: 900204.6250
# Epoch 11/30 |███████-------------| 36.7% train_global_loss: 898594.8125; train_optim_loss: 898594.8125
# Epoch 12/30 |████████------------| 40.0% train_global_loss: 897044.2500; train_optim_loss: 897044.2500
# Epoch 13/30 |████████------------| 43.3% train_global_loss: 895527.3750; train_optim_loss: 895527.3750
# Epoch 14/30 |█████████-----------| 46.7% train_global_loss: 894050.4375; train_optim_loss: 894050.4375
# Epoch 15/30 |██████████----------| 50.0% train_global_loss: 892561.0000; train_optim_loss: 892561.0000
# Epoch 16/30 |██████████----------| 53.3% train_global_loss: 891072.2500; train_optim_loss: 891072.2500
# Epoch 17/30 |███████████---------| 56.7% train_global_loss: 889568.6250; train_optim_loss: 889568.6250
# Epoch 18/30 |████████████--------| 60.0% train_global_loss: 888070.3750; train_optim_loss: 888070.3750
# Epoch 19/30 |████████████--------| 63.3% train_global_loss: 886589.4375; train_optim_loss: 886589.4375
# Epoch 20/30 |█████████████-------| 66.7% train_global_loss: 885135.1250; train_optim_loss: 885135.1250
# Epoch 21/30 |██████████████------| 70.0% train_global_loss: 883701.9375; train_optim_loss: 883701.9375
# Epoch 22/30 |██████████████------| 73.3% train_global_loss: 882277.6875; train_optim_loss: 882277.6875
# Epoch 23/30 |███████████████-----| 76.7% train_global_loss: 880851.1250; train_optim_loss: 880851.1250
# Epoch 24/30 |████████████████----| 80.0% train_global_loss: 879425.1250; train_optim_loss: 879425.1250
# Epoch 25/30 |████████████████----| 83.3% train_global_loss: 878012.0000; train_optim_loss: 878012.0000
# Epoch 26/30 |█████████████████---| 86.7% train_global_loss: 876600.2500; train_optim_loss: 876600.2500
# Epoch 27/30 |██████████████████--| 90.0% train_global_loss: 875184.1250; train_optim_loss: 875184.1250
# Epoch 28/30 |██████████████████--| 93.3% train_global_loss: 873774.0625; train_optim_loss: 873774.0625
# Epoch 29/30 |███████████████████-| 96.7% train_global_loss: 872356.8750; train_optim_loss: 872356.8750
# Epoch 30/30 |████████████████████| 100.0% train_global_loss: 870957.8750; train_optim_loss: 870957.8750
#
# Model training finished after 0 min 15 sec.
# Using best model state, which was in epoch 30.
# ✅ lambda_edge_recon=1000.0 | lambda_gene_expr_recon=25.0 | ARI=0.4879 | valid spots=4371
#
# ==========================================================================================
# 🚀 [2/35] 参数组合: lambda_edge_recon=1000.0, lambda_gene_expr_recon=50.0
# ==========================================================================================
# --- INITIALIZING NEW NETWORK MODULE: VARIATIONAL GENE PROGRAM GRAPH AUTOENCODER ---
# LOSS -> include_edge_recon_loss: True, include_gene_expr_recon_loss: True, rna_recon_loss: nb
# NODE LABEL METHOD -> one-hop-norm
# ACTIVE GP THRESHOLD RATIO -> 0.01
# LOG VARIATIONAL -> True
# ONE HOP GCN NORM RNA NODE LABEL AGGREGATOR
# ENCODER -> n_input: 3047, n_cat_covariates_embed_input: 0, n_hidden: 1325, n_latent: 1225, n_addon_latent: 100, n_fc_layers: 1, n_layers: 1, conv_layer: gcnconv, n_attention_heads: 0, dropout_rate: 0.0,
# COSINE SIM GRAPH DECODER -> dropout_rate: 0.0
# MASKED TARGET RNA DECODER -> n_prior_gp_input: 1225, n_addon_gp_input: 100, n_cat_covariates_embed_input: 0, n_output: 3047
# MASKED SOURCE RNA DECODER -> n_prior_gp_input: 1225, n_addon_gp_input: 100, n_cat_covariates_embed_input: 0, n_output: 3047
#   全量 nodes: 4371
#   全量 edges: 34968
#   lambda_edge_recon = 1000.0
#   lambda_gene_expr_recon = 50.0
#
# --- INITIALIZING TRAINER ---
# Number of training nodes: 4371
# Number of validation nodes: 0
# Number of training edges: 17477
# Number of validation edges: 0
# Edge batch size: 34968
# Node batch size: 4371
#
# --- MODEL TRAINING ---
# Epoch 1/30 |--------------------| 3.3% train_global_loss: 1166623.6250; train_optim_loss: 1166623.6250
# Epoch 2/30 |█-------------------| 6.7% train_global_loss: 1148837.5000; train_optim_loss: 1148837.5000
# Epoch 3/30 |██------------------| 10.0% train_global_loss: 1139500.8750; train_optim_loss: 1139500.8750
# Epoch 4/30 |██------------------| 13.3% train_global_loss: 1134098.8750; train_optim_loss: 1134098.8750
# Epoch 5/30 |███-----------------| 16.7% train_global_loss: 1130516.1250; train_optim_loss: 1130516.1250
# Epoch 6/30 |████----------------| 20.0% train_global_loss: 1127747.5000; train_optim_loss: 1127747.5000
# Epoch 7/30 |████----------------| 23.3% train_global_loss: 1125279.7500; train_optim_loss: 1125279.7500
# Epoch 8/30 |█████---------------| 26.7% train_global_loss: 1123002.2500; train_optim_loss: 1123002.2500
# Epoch 9/30 |██████--------------| 30.0% train_global_loss: 1120836.2500; train_optim_loss: 1120836.2500
# Epoch 10/30 |██████--------------| 33.3% train_global_loss: 1118768.3750; train_optim_loss: 1118768.3750
# Epoch 11/30 |███████-------------| 36.7% train_global_loss: 1116875.5000; train_optim_loss: 1116875.5000
# Epoch 12/30 |████████------------| 40.0% train_global_loss: 1115112.5000; train_optim_loss: 1115112.5000
# Epoch 13/30 |████████------------| 43.3% train_global_loss: 1113422.8750; train_optim_loss: 1113422.8750
# Epoch 14/30 |█████████-----------| 46.7% train_global_loss: 1111808.1250; train_optim_loss: 1111808.1250
# Epoch 15/30 |██████████----------| 50.0% train_global_loss: 1110166.2500; train_optim_loss: 1110166.2500
# Epoch 16/30 |██████████----------| 53.3% train_global_loss: 1108517.3750; train_optim_loss: 1108517.3750
# Epoch 17/30 |███████████---------| 56.7% train_global_loss: 1106830.8750; train_optim_loss: 1106830.8750
# Epoch 18/30 |████████████--------| 60.0% train_global_loss: 1105147.2500; train_optim_loss: 1105147.2500
# Epoch 19/30 |████████████--------| 63.3% train_global_loss: 1103492.2500; train_optim_loss: 1103492.2500
# Epoch 20/30 |█████████████-------| 66.7% train_global_loss: 1101881.2500; train_optim_loss: 1101881.2500
# Epoch 21/30 |██████████████------| 70.0% train_global_loss: 1100305.3750; train_optim_loss: 1100305.3750
# Epoch 22/30 |██████████████------| 73.3% train_global_loss: 1098739.7500; train_optim_loss: 1098739.7500
# Epoch 23/30 |███████████████-----| 76.7% train_global_loss: 1097164.5000; train_optim_loss: 1097164.5000
# Epoch 24/30 |████████████████----| 80.0% train_global_loss: 1095584.5000; train_optim_loss: 1095584.5000
# Epoch 25/30 |████████████████----| 83.3% train_global_loss: 1094022.7500; train_optim_loss: 1094022.7500
# Epoch 26/30 |█████████████████---| 86.7% train_global_loss: 1092461.5000; train_optim_loss: 1092461.5000
# Epoch 27/30 |██████████████████--| 90.0% train_global_loss: 1090890.6250; train_optim_loss: 1090890.6250
# Epoch 28/30 |██████████████████--| 93.3% train_global_loss: 1089325.6250; train_optim_loss: 1089325.6250
# Epoch 29/30 |███████████████████-| 96.7% train_global_loss: 1087746.5000; train_optim_loss: 1087746.5000
# Epoch 30/30 |████████████████████| 100.0% train_global_loss: 1086197.5000; train_optim_loss: 1086197.5000
#
# Model training finished after 0 min 13 sec.
# Using best model state, which was in epoch 30.
# ✅ lambda_edge_recon=1000.0 | lambda_gene_expr_recon=50.0 | ARI=0.5101 | valid spots=4371
#
# ==========================================================================================
# 🚀 [3/35] 参数组合: lambda_edge_recon=1000.0, lambda_gene_expr_recon=100.0
# ==========================================================================================
# --- INITIALIZING NEW NETWORK MODULE: VARIATIONAL GENE PROGRAM GRAPH AUTOENCODER ---
# LOSS -> include_edge_recon_loss: True, include_gene_expr_recon_loss: True, rna_recon_loss: nb
# NODE LABEL METHOD -> one-hop-norm
# ACTIVE GP THRESHOLD RATIO -> 0.01
# LOG VARIATIONAL -> True
# ONE HOP GCN NORM RNA NODE LABEL AGGREGATOR
# ENCODER -> n_input: 3047, n_cat_covariates_embed_input: 0, n_hidden: 1325, n_latent: 1225, n_addon_latent: 100, n_fc_layers: 1, n_layers: 1, conv_layer: gcnconv, n_attention_heads: 0, dropout_rate: 0.0,
# COSINE SIM GRAPH DECODER -> dropout_rate: 0.0
# MASKED TARGET RNA DECODER -> n_prior_gp_input: 1225, n_addon_gp_input: 100, n_cat_covariates_embed_input: 0, n_output: 3047
# MASKED SOURCE RNA DECODER -> n_prior_gp_input: 1225, n_addon_gp_input: 100, n_cat_covariates_embed_input: 0, n_output: 3047
#   全量 nodes: 4371
#   全量 edges: 34968
#   lambda_edge_recon = 1000.0
#   lambda_gene_expr_recon = 100.0
#
# --- INITIALIZING TRAINER ---
# Number of training nodes: 4371
# Number of validation nodes: 0
# Number of training edges: 17477
# Number of validation edges: 0
# Edge batch size: 34968
# Node batch size: 4371
#
# --- MODEL TRAINING ---
# Epoch 1/30 |--------------------| 3.3% train_global_loss: 1639682.0000; train_optim_loss: 1639682.0000
# Epoch 2/30 |█-------------------| 6.7% train_global_loss: 1605509.2500; train_optim_loss: 1605509.2500
# Epoch 3/30 |██------------------| 10.0% train_global_loss: 1588215.7500; train_optim_loss: 1588215.7500
# Epoch 4/30 |██------------------| 13.3% train_global_loss: 1578747.0000; train_optim_loss: 1578747.0000
# Epoch 5/30 |███-----------------| 16.7% train_global_loss: 1572868.8750; train_optim_loss: 1572868.8750
# Epoch 6/30 |████----------------| 20.0% train_global_loss: 1568568.2500; train_optim_loss: 1568568.2500
# Epoch 7/30 |████----------------| 23.3% train_global_loss: 1564841.2500; train_optim_loss: 1564841.2500
# Epoch 8/30 |█████---------------| 26.7% train_global_loss: 1561491.0000; train_optim_loss: 1561491.0000
# Epoch 9/30 |██████--------------| 30.0% train_global_loss: 1558378.7500; train_optim_loss: 1558378.7500
# Epoch 10/30 |██████--------------| 33.3% train_global_loss: 1555471.6250; train_optim_loss: 1555471.6250
# Epoch 11/30 |███████-------------| 36.7% train_global_loss: 1552919.8750; train_optim_loss: 1552919.8750
# Epoch 12/30 |████████------------| 40.0% train_global_loss: 1550631.2500; train_optim_loss: 1550631.2500
# Epoch 13/30 |████████------------| 43.3% train_global_loss: 1548484.5000; train_optim_loss: 1548484.5000
# Epoch 14/30 |█████████-----------| 46.7% train_global_loss: 1546470.1250; train_optim_loss: 1546470.1250
# Epoch 15/30 |██████████----------| 50.0% train_global_loss: 1544387.1250; train_optim_loss: 1544387.1250
# Epoch 16/30 |██████████----------| 53.3% train_global_loss: 1542276.5000; train_optim_loss: 1542276.5000
# Epoch 17/30 |███████████---------| 56.7% train_global_loss: 1540083.5000; train_optim_loss: 1540083.5000
# Epoch 18/30 |████████████--------| 60.0% train_global_loss: 1537890.0000; train_optim_loss: 1537890.0000
# Epoch 19/30 |████████████--------| 63.3% train_global_loss: 1535745.5000; train_optim_loss: 1535745.5000
# Epoch 20/30 |█████████████-------| 66.7% train_global_loss: 1533671.5000; train_optim_loss: 1533671.5000
# Epoch 21/30 |██████████████------| 70.0% train_global_loss: 1531645.2500; train_optim_loss: 1531645.2500
# Epoch 22/30 |██████████████------| 73.3% train_global_loss: 1529617.0000; train_optim_loss: 1529617.0000
# Epoch 23/30 |███████████████-----| 76.7% train_global_loss: 1527556.2500; train_optim_loss: 1527556.2500
# Epoch 24/30 |████████████████----| 80.0% train_global_loss: 1525469.7500; train_optim_loss: 1525469.7500
# Epoch 25/30 |████████████████----| 83.3% train_global_loss: 1523397.0000; train_optim_loss: 1523397.0000
# Epoch 26/30 |█████████████████---| 86.7% train_global_loss: 1521312.1250; train_optim_loss: 1521312.1250
# Epoch 27/30 |██████████████████--| 90.0% train_global_loss: 1519195.5000; train_optim_loss: 1519195.5000
# Epoch 28/30 |██████████████████--| 93.3% train_global_loss: 1517073.2500; train_optim_loss: 1517073.2500
# Epoch 29/30 |███████████████████-| 96.7% train_global_loss: 1514912.6250; train_optim_loss: 1514912.6250
# Epoch 30/30 |████████████████████| 100.0% train_global_loss: 1512794.0000; train_optim_loss: 1512794.0000
#
# Model training finished after 0 min 13 sec.
# Using best model state, which was in epoch 30.
# ✅ lambda_edge_recon=1000.0 | lambda_gene_expr_recon=100.0 | ARI=0.4958 | valid spots=4371
#
# ==========================================================================================
# 🚀 [4/35] 参数组合: lambda_edge_recon=1000.0, lambda_gene_expr_recon=150.0
# ==========================================================================================
# --- INITIALIZING NEW NETWORK MODULE: VARIATIONAL GENE PROGRAM GRAPH AUTOENCODER ---
# LOSS -> include_edge_recon_loss: True, include_gene_expr_recon_loss: True, rna_recon_loss: nb
# NODE LABEL METHOD -> one-hop-norm
# ACTIVE GP THRESHOLD RATIO -> 0.01
# LOG VARIATIONAL -> True
# ONE HOP GCN NORM RNA NODE LABEL AGGREGATOR
# ENCODER -> n_input: 3047, n_cat_covariates_embed_input: 0, n_hidden: 1325, n_latent: 1225, n_addon_latent: 100, n_fc_layers: 1, n_layers: 1, conv_layer: gcnconv, n_attention_heads: 0, dropout_rate: 0.0,
# COSINE SIM GRAPH DECODER -> dropout_rate: 0.0
# MASKED TARGET RNA DECODER -> n_prior_gp_input: 1225, n_addon_gp_input: 100, n_cat_covariates_embed_input: 0, n_output: 3047
# MASKED SOURCE RNA DECODER -> n_prior_gp_input: 1225, n_addon_gp_input: 100, n_cat_covariates_embed_input: 0, n_output: 3047
#   全量 nodes: 4371
#   全量 edges: 34968
#   lambda_edge_recon = 1000.0
#   lambda_gene_expr_recon = 150.0
#
# --- INITIALIZING TRAINER ---
# Number of training nodes: 4371
# Number of validation nodes: 0
# Number of training edges: 17477
# Number of validation edges: 0
# Edge batch size: 34968
# Node batch size: 4371
#
# --- MODEL TRAINING ---
# Epoch 1/30 |--------------------| 3.3% train_global_loss: 2112740.5000; train_optim_loss: 2112740.5000
# Epoch 2/30 |█-------------------| 6.7% train_global_loss: 2062139.6250; train_optim_loss: 2062139.6250
# Epoch 3/30 |██------------------| 10.0% train_global_loss: 2036871.8750; train_optim_loss: 2036871.8750
# Epoch 4/30 |██------------------| 13.3% train_global_loss: 2023321.0000; train_optim_loss: 2023321.0000
# Epoch 5/30 |███-----------------| 16.7% train_global_loss: 2015118.0000; train_optim_loss: 2015118.0000
# Epoch 6/30 |████----------------| 20.0% train_global_loss: 2009232.2500; train_optim_loss: 2009232.2500
# Epoch 7/30 |████----------------| 23.3% train_global_loss: 2004176.7500; train_optim_loss: 2004176.7500
# Epoch 8/30 |█████---------------| 26.7% train_global_loss: 1999679.8750; train_optim_loss: 1999679.8750
# Epoch 9/30 |██████--------------| 30.0% train_global_loss: 1995545.2500; train_optim_loss: 1995545.2500
# Epoch 10/30 |██████--------------| 33.3% train_global_loss: 1991714.7500; train_optim_loss: 1991714.7500
# Epoch 11/30 |███████-------------| 36.7% train_global_loss: 1988413.5000; train_optim_loss: 1988413.5000
# Epoch 12/30 |████████------------| 40.0% train_global_loss: 1985499.2500; train_optim_loss: 1985499.2500
# Epoch 13/30 |████████------------| 43.3% train_global_loss: 1982785.7500; train_optim_loss: 1982785.7500
# Epoch 14/30 |█████████-----------| 46.7% train_global_loss: 1980248.3750; train_optim_loss: 1980248.3750
# Epoch 15/30 |██████████----------| 50.0% train_global_loss: 1977591.7500; train_optim_loss: 1977591.7500
# Epoch 16/30 |██████████----------| 53.3% train_global_loss: 1974881.7500; train_optim_loss: 1974881.7500
# Epoch 17/30 |███████████---------| 56.7% train_global_loss: 1972044.2500; train_optim_loss: 1972044.2500
# Epoch 18/30 |████████████--------| 60.0% train_global_loss: 1969198.3750; train_optim_loss: 1969198.3750
# Epoch 19/30 |████████████--------| 63.3% train_global_loss: 1966414.8750; train_optim_loss: 1966414.8750
# Epoch 20/30 |█████████████-------| 66.7% train_global_loss: 1963719.0000; train_optim_loss: 1963719.0000
# Epoch 21/30 |██████████████------| 70.0% train_global_loss: 1961073.0000; train_optim_loss: 1961073.0000
# Epoch 22/30 |██████████████------| 73.3% train_global_loss: 1958405.5000; train_optim_loss: 1958405.5000
# Epoch 23/30 |███████████████-----| 76.7% train_global_loss: 1955668.8750; train_optim_loss: 1955668.8750
# Epoch 24/30 |████████████████----| 80.0% train_global_loss: 1952882.1250; train_optim_loss: 1952882.1250
# Epoch 25/30 |████████████████----| 83.3% train_global_loss: 1950096.7500; train_optim_loss: 1950096.7500
# Epoch 26/30 |█████████████████---| 86.7% train_global_loss: 1947275.7500; train_optim_loss: 1947275.7500
# Epoch 27/30 |██████████████████--| 90.0% train_global_loss: 1944392.8750; train_optim_loss: 1944392.8750
# Epoch 28/30 |██████████████████--| 93.3% train_global_loss: 1941486.7500; train_optim_loss: 1941486.7500
# Epoch 29/30 |███████████████████-| 96.7% train_global_loss: 1938514.2500; train_optim_loss: 1938514.2500
# Epoch 30/30 |████████████████████| 100.0% train_global_loss: 1935588.0000; train_optim_loss: 1935588.0000
#
# Model training finished after 0 min 13 sec.
# Using best model state, which was in epoch 30.
# ✅ lambda_edge_recon=1000.0 | lambda_gene_expr_recon=150.0 | ARI=0.5107 | valid spots=4371
#
# ==========================================================================================
# 🚀 [5/35] 参数组合: lambda_edge_recon=1000.0, lambda_gene_expr_recon=200.0
# ==========================================================================================
# --- INITIALIZING NEW NETWORK MODULE: VARIATIONAL GENE PROGRAM GRAPH AUTOENCODER ---
# LOSS -> include_edge_recon_loss: True, include_gene_expr_recon_loss: True, rna_recon_loss: nb
# NODE LABEL METHOD -> one-hop-norm
# ACTIVE GP THRESHOLD RATIO -> 0.01
# LOG VARIATIONAL -> True
# ONE HOP GCN NORM RNA NODE LABEL AGGREGATOR
# ENCODER -> n_input: 3047, n_cat_covariates_embed_input: 0, n_hidden: 1325, n_latent: 1225, n_addon_latent: 100, n_fc_layers: 1, n_layers: 1, conv_layer: gcnconv, n_attention_heads: 0, dropout_rate: 0.0,
# COSINE SIM GRAPH DECODER -> dropout_rate: 0.0
# MASKED TARGET RNA DECODER -> n_prior_gp_input: 1225, n_addon_gp_input: 100, n_cat_covariates_embed_input: 0, n_output: 3047
# MASKED SOURCE RNA DECODER -> n_prior_gp_input: 1225, n_addon_gp_input: 100, n_cat_covariates_embed_input: 0, n_output: 3047
#   全量 nodes: 4371
#   全量 edges: 34968
#   lambda_edge_recon = 1000.0
#   lambda_gene_expr_recon = 200.0
#
# --- INITIALIZING TRAINER ---
# Number of training nodes: 4371
# Number of validation nodes: 0
# Number of training edges: 17477
# Number of validation edges: 0
# Edge batch size: 34968
# Node batch size: 4371
#
# --- MODEL TRAINING ---
# Epoch 1/30 |--------------------| 3.3% train_global_loss: 2585799.0000; train_optim_loss: 2585799.0000
# Epoch 2/30 |█-------------------| 6.7% train_global_loss: 2518738.5000; train_optim_loss: 2518738.5000
# Epoch 3/30 |██------------------| 10.0% train_global_loss: 2485474.5000; train_optim_loss: 2485474.5000
# Epoch 4/30 |██------------------| 13.3% train_global_loss: 2467821.2500; train_optim_loss: 2467821.2500
# Epoch 5/30 |███-----------------| 16.7% train_global_loss: 2457263.0000; train_optim_loss: 2457263.0000
# Epoch 6/30 |████----------------| 20.0% train_global_loss: 2449752.7500; train_optim_loss: 2449752.7500
# Epoch 7/30 |████----------------| 23.3% train_global_loss: 2443323.2500; train_optim_loss: 2443323.2500
# Epoch 8/30 |█████---------------| 26.7% train_global_loss: 2437633.5000; train_optim_loss: 2437633.5000
# Epoch 9/30 |██████--------------| 30.0% train_global_loss: 2432428.5000; train_optim_loss: 2432428.5000
# Epoch 10/30 |██████--------------| 33.3% train_global_loss: 2427624.0000; train_optim_loss: 2427624.0000
# Epoch 11/30 |███████-------------| 36.7% train_global_loss: 2423517.0000; train_optim_loss: 2423517.0000
# Epoch 12/30 |████████------------| 40.0% train_global_loss: 2419916.5000; train_optim_loss: 2419916.5000
# Epoch 13/30 |████████------------| 43.3% train_global_loss: 2416569.0000; train_optim_loss: 2416569.0000
# Epoch 14/30 |█████████-----------| 46.7% train_global_loss: 2413435.0000; train_optim_loss: 2413435.0000
# Epoch 15/30 |██████████----------| 50.0% train_global_loss: 2410127.5000; train_optim_loss: 2410127.5000
# Epoch 16/30 |██████████----------| 53.3% train_global_loss: 2406740.5000; train_optim_loss: 2406740.5000
# Epoch 17/30 |███████████---------| 56.7% train_global_loss: 2403181.0000; train_optim_loss: 2403181.0000
# Epoch 18/30 |████████████--------| 60.0% train_global_loss: 2399603.2500; train_optim_loss: 2399603.2500
# Epoch 19/30 |████████████--------| 63.3% train_global_loss: 2396096.5000; train_optim_loss: 2396096.5000
# Epoch 20/30 |█████████████-------| 66.7% train_global_loss: 2392690.0000; train_optim_loss: 2392690.0000
# Epoch 21/30 |██████████████------| 70.0% train_global_loss: 2389331.0000; train_optim_loss: 2389331.0000
# Epoch 22/30 |██████████████------| 73.3% train_global_loss: 2385927.7500; train_optim_loss: 2385927.7500
# Epoch 23/30 |███████████████-----| 76.7% train_global_loss: 2382415.0000; train_optim_loss: 2382415.0000
# Epoch 24/30 |████████████████----| 80.0% train_global_loss: 2378826.7500; train_optim_loss: 2378826.7500
# Epoch 25/30 |████████████████----| 83.3% train_global_loss: 2375223.0000; train_optim_loss: 2375223.0000
# Epoch 26/30 |█████████████████---| 86.7% train_global_loss: 2371559.2500; train_optim_loss: 2371559.2500
# Epoch 27/30 |██████████████████--| 90.0% train_global_loss: 2367801.5000; train_optim_loss: 2367801.5000
# Epoch 28/30 |██████████████████--| 93.3% train_global_loss: 2364003.5000; train_optim_loss: 2364003.5000
# Epoch 29/30 |███████████████████-| 96.7% train_global_loss: 2360111.0000; train_optim_loss: 2360111.0000
# Epoch 30/30 |████████████████████| 100.0% train_global_loss: 2356264.2500; train_optim_loss: 2356264.2500
#
# Model training finished after 0 min 11 sec.
# Using best model state, which was in epoch 30.
# ✅ lambda_edge_recon=1000.0 | lambda_gene_expr_recon=200.0 | ARI=0.4932 | valid spots=4371
#
# ==========================================================================================
# 🚀 [6/35] 参数组合: lambda_edge_recon=1000.0, lambda_gene_expr_recon=250.0
# ==========================================================================================
# --- INITIALIZING NEW NETWORK MODULE: VARIATIONAL GENE PROGRAM GRAPH AUTOENCODER ---
# LOSS -> include_edge_recon_loss: True, include_gene_expr_recon_loss: True, rna_recon_loss: nb
# NODE LABEL METHOD -> one-hop-norm
# ACTIVE GP THRESHOLD RATIO -> 0.01
# LOG VARIATIONAL -> True
# ONE HOP GCN NORM RNA NODE LABEL AGGREGATOR
# ENCODER -> n_input: 3047, n_cat_covariates_embed_input: 0, n_hidden: 1325, n_latent: 1225, n_addon_latent: 100, n_fc_layers: 1, n_layers: 1, conv_layer: gcnconv, n_attention_heads: 0, dropout_rate: 0.0,
# COSINE SIM GRAPH DECODER -> dropout_rate: 0.0
# MASKED TARGET RNA DECODER -> n_prior_gp_input: 1225, n_addon_gp_input: 100, n_cat_covariates_embed_input: 0, n_output: 3047
# MASKED SOURCE RNA DECODER -> n_prior_gp_input: 1225, n_addon_gp_input: 100, n_cat_covariates_embed_input: 0, n_output: 3047
#   全量 nodes: 4371
#   全量 edges: 34968
#   lambda_edge_recon = 1000.0
#   lambda_gene_expr_recon = 250.0
#
# --- INITIALIZING TRAINER ---
# Number of training nodes: 4371
# Number of validation nodes: 0
# Number of training edges: 17477
# Number of validation edges: 0
# Edge batch size: 34968
# Node batch size: 4371
#
# --- MODEL TRAINING ---
# Epoch 1/30 |--------------------| 3.3% train_global_loss: 3058857.7500; train_optim_loss: 3058857.7500
# Epoch 2/30 |█-------------------| 6.7% train_global_loss: 2975319.0000; train_optim_loss: 2975319.0000
# Epoch 3/30 |██------------------| 10.0% train_global_loss: 2934040.0000; train_optim_loss: 2934040.0000
# Epoch 4/30 |██------------------| 13.3% train_global_loss: 2912264.5000; train_optim_loss: 2912264.5000
# Epoch 5/30 |███-----------------| 16.7% train_global_loss: 2899327.2500; train_optim_loss: 2899327.2500
# Epoch 6/30 |████----------------| 20.0% train_global_loss: 2890165.0000; train_optim_loss: 2890165.0000
# Epoch 7/30 |████----------------| 23.3% train_global_loss: 2882332.2500; train_optim_loss: 2882332.2500
# Epoch 8/30 |█████---------------| 26.7% train_global_loss: 2875421.5000; train_optim_loss: 2875421.5000
# Epoch 9/30 |██████--------------| 30.0% train_global_loss: 2869117.0000; train_optim_loss: 2869117.0000
# Epoch 10/30 |██████--------------| 33.3% train_global_loss: 2863307.5000; train_optim_loss: 2863307.5000
# Epoch 11/30 |███████-------------| 36.7% train_global_loss: 2858360.5000; train_optim_loss: 2858360.5000
# Epoch 12/30 |████████------------| 40.0% train_global_loss: 2854036.7500; train_optim_loss: 2854036.7500
# Epoch 13/30 |████████------------| 43.3% train_global_loss: 2850015.7500; train_optim_loss: 2850015.7500
# Epoch 14/30 |█████████-----------| 46.7% train_global_loss: 2846243.7500; train_optim_loss: 2846243.7500
# Epoch 15/30 |██████████----------| 50.0% train_global_loss: 2842244.7500; train_optim_loss: 2842244.7500
# Epoch 16/30 |██████████----------| 53.3% train_global_loss: 2838139.5000; train_optim_loss: 2838139.5000
# Epoch 17/30 |███████████---------| 56.7% train_global_loss: 2833815.7500; train_optim_loss: 2833815.7500
# Epoch 18/30 |████████████--------| 60.0% train_global_loss: 2829462.0000; train_optim_loss: 2829462.0000
# Epoch 19/30 |████████████--------| 63.3% train_global_loss: 2825186.5000; train_optim_loss: 2825186.5000
# Epoch 20/30 |█████████████-------| 66.7% train_global_loss: 2821023.2500; train_optim_loss: 2821023.2500
# Epoch 21/30 |██████████████------| 70.0% train_global_loss: 2816904.7500; train_optim_loss: 2816904.7500
# Epoch 22/30 |██████████████------| 73.3% train_global_loss: 2812718.2500; train_optim_loss: 2812718.2500
# Epoch 23/30 |███████████████-----| 76.7% train_global_loss: 2808381.7500; train_optim_loss: 2808381.7500
# Epoch 24/30 |████████████████----| 80.0% train_global_loss: 2803942.5000; train_optim_loss: 2803942.5000
# Epoch 25/30 |████████████████----| 83.3% train_global_loss: 2799469.7500; train_optim_loss: 2799469.7500
# Epoch 26/30 |█████████████████---| 86.7% train_global_loss: 2794912.7500; train_optim_loss: 2794912.7500
# Epoch 27/30 |██████████████████--| 90.0% train_global_loss: 2790230.5000; train_optim_loss: 2790230.5000
# Epoch 28/30 |██████████████████--| 93.3% train_global_loss: 2785492.0000; train_optim_loss: 2785492.0000
# Epoch 29/30 |███████████████████-| 96.7% train_global_loss: 2780630.0000; train_optim_loss: 2780630.0000
# Epoch 30/30 |████████████████████| 100.0% train_global_loss: 2775812.5000; train_optim_loss: 2775812.5000
#
# Model training finished after 0 min 12 sec.
# Using best model state, which was in epoch 30.
# ✅ lambda_edge_recon=1000.0 | lambda_gene_expr_recon=250.0 | ARI=0.5035 | valid spots=4371
#
# ==========================================================================================
# 🚀 [7/35] 参数组合: lambda_edge_recon=1000.0, lambda_gene_expr_recon=400.0
# ==========================================================================================
# --- INITIALIZING NEW NETWORK MODULE: VARIATIONAL GENE PROGRAM GRAPH AUTOENCODER ---
# LOSS -> include_edge_recon_loss: True, include_gene_expr_recon_loss: True, rna_recon_loss: nb
# NODE LABEL METHOD -> one-hop-norm
# ACTIVE GP THRESHOLD RATIO -> 0.01
# LOG VARIATIONAL -> True
# ONE HOP GCN NORM RNA NODE LABEL AGGREGATOR
# ENCODER -> n_input: 3047, n_cat_covariates_embed_input: 0, n_hidden: 1325, n_latent: 1225, n_addon_latent: 100, n_fc_layers: 1, n_layers: 1, conv_layer: gcnconv, n_attention_heads: 0, dropout_rate: 0.0,
# COSINE SIM GRAPH DECODER -> dropout_rate: 0.0
# MASKED TARGET RNA DECODER -> n_prior_gp_input: 1225, n_addon_gp_input: 100, n_cat_covariates_embed_input: 0, n_output: 3047
# MASKED SOURCE RNA DECODER -> n_prior_gp_input: 1225, n_addon_gp_input: 100, n_cat_covariates_embed_input: 0, n_output: 3047
#   全量 nodes: 4371
#   全量 edges: 34968
#   lambda_edge_recon = 1000.0
#   lambda_gene_expr_recon = 400.0
#
# --- INITIALIZING TRAINER ---
# Number of training nodes: 4371
# Number of validation nodes: 0
# Number of training edges: 17477
# Number of validation edges: 0
# Edge batch size: 34968
# Node batch size: 4371
#
# --- MODEL TRAINING ---
# Epoch 1/30 |--------------------| 3.3% train_global_loss: 4478033.0000; train_optim_loss: 4478033.0000
# Epoch 2/30 |█-------------------| 6.7% train_global_loss: 4344995.0000; train_optim_loss: 4344995.0000
# Epoch 3/30 |██------------------| 10.0% train_global_loss: 4279611.0000; train_optim_loss: 4279611.0000
# Epoch 4/30 |██------------------| 13.3% train_global_loss: 4245411.5000; train_optim_loss: 4245411.5000
# Epoch 5/30 |███-----------------| 16.7% train_global_loss: 4225263.5000; train_optim_loss: 4225263.5000
# Epoch 6/30 |████----------------| 20.0% train_global_loss: 4211056.0000; train_optim_loss: 4211056.0000
# Epoch 7/30 |████----------------| 23.3% train_global_loss: 4198918.5000; train_optim_loss: 4198918.5000
# Epoch 8/30 |█████---------------| 26.7% train_global_loss: 4188247.7500; train_optim_loss: 4188247.7500
# Epoch 9/30 |██████--------------| 30.0% train_global_loss: 4178551.7500; train_optim_loss: 4178551.7500
# Epoch 10/30 |██████--------------| 33.3% train_global_loss: 4169630.0000; train_optim_loss: 4169630.0000
# Epoch 11/30 |███████-------------| 36.7% train_global_loss: 4162063.0000; train_optim_loss: 4162063.0000
# Epoch 12/30 |████████------------| 40.0% train_global_loss: 4155467.5000; train_optim_loss: 4155467.5000
# Epoch 13/30 |████████------------| 43.3% train_global_loss: 4149317.7500; train_optim_loss: 4149317.7500
# Epoch 14/30 |█████████-----------| 46.7% train_global_loss: 4143521.0000; train_optim_loss: 4143521.0000
# Epoch 15/30 |██████████----------| 50.0% train_global_loss: 4137331.5000; train_optim_loss: 4137331.5000
# Epoch 16/30 |██████████----------| 53.3% train_global_loss: 4130960.5000; train_optim_loss: 4130960.5000
# Epoch 17/30 |███████████---------| 56.7% train_global_loss: 4124233.0000; train_optim_loss: 4124233.0000
# Epoch 18/30 |████████████--------| 60.0% train_global_loss: 4117442.7500; train_optim_loss: 4117442.7500
# Epoch 19/30 |████████████--------| 63.3% train_global_loss: 4110747.0000; train_optim_loss: 4110747.0000
# Epoch 20/30 |█████████████-------| 66.7% train_global_loss: 4104202.2500; train_optim_loss: 4104202.2500
# Epoch 21/30 |██████████████------| 70.0% train_global_loss: 4097691.5000; train_optim_loss: 4097691.5000
# Epoch 22/30 |██████████████------| 73.3% train_global_loss: 4091041.2500; train_optim_loss: 4091041.2500
# Epoch 23/30 |███████████████-----| 76.7% train_global_loss: 4084112.0000; train_optim_loss: 4084112.0000
# Epoch 24/30 |████████████████----| 80.0% train_global_loss: 4077004.7500; train_optim_loss: 4077004.7500
# Epoch 25/30 |████████████████----| 83.3% train_global_loss: 4069807.5000; train_optim_loss: 4069807.5000
# Epoch 26/30 |█████████████████---| 86.7% train_global_loss: 4062449.5000; train_optim_loss: 4062449.5000
# Epoch 27/30 |██████████████████--| 90.0% train_global_loss: 4054875.0000; train_optim_loss: 4054875.0000
# Epoch 28/30 |██████████████████--| 93.3% train_global_loss: 4047203.0000; train_optim_loss: 4047203.0000
# Epoch 29/30 |███████████████████-| 96.7% train_global_loss: 4039321.5000; train_optim_loss: 4039321.5000
# Epoch 30/30 |████████████████████| 100.0% train_global_loss: 4031468.5000; train_optim_loss: 4031468.5000
#
# Model training finished after 0 min 11 sec.
# Using best model state, which was in epoch 30.
# ✅ lambda_edge_recon=1000.0 | lambda_gene_expr_recon=400.0 | ARI=0.4978 | valid spots=4371
#
# ==========================================================================================
# 🚀 [8/35] 参数组合: lambda_edge_recon=10000.0, lambda_gene_expr_recon=25.0
# ==========================================================================================
# --- INITIALIZING NEW NETWORK MODULE: VARIATIONAL GENE PROGRAM GRAPH AUTOENCODER ---
# LOSS -> include_edge_recon_loss: True, include_gene_expr_recon_loss: True, rna_recon_loss: nb
# NODE LABEL METHOD -> one-hop-norm
# ACTIVE GP THRESHOLD RATIO -> 0.01
# LOG VARIATIONAL -> True
# ONE HOP GCN NORM RNA NODE LABEL AGGREGATOR
# ENCODER -> n_input: 3047, n_cat_covariates_embed_input: 0, n_hidden: 1325, n_latent: 1225, n_addon_latent: 100, n_fc_layers: 1, n_layers: 1, conv_layer: gcnconv, n_attention_heads: 0, dropout_rate: 0.0,
# COSINE SIM GRAPH DECODER -> dropout_rate: 0.0
# MASKED TARGET RNA DECODER -> n_prior_gp_input: 1225, n_addon_gp_input: 100, n_cat_covariates_embed_input: 0, n_output: 3047
# MASKED SOURCE RNA DECODER -> n_prior_gp_input: 1225, n_addon_gp_input: 100, n_cat_covariates_embed_input: 0, n_output: 3047
#   全量 nodes: 4371
#   全量 edges: 34968
#   lambda_edge_recon = 10000.0
#   lambda_gene_expr_recon = 25.0
#
# --- INITIALIZING TRAINER ---
# Number of training nodes: 4371
# Number of validation nodes: 0
# Number of training edges: 17477
# Number of validation edges: 0
# Edge batch size: 34968
# Node batch size: 4371
#
# --- MODEL TRAINING ---
# Epoch 1/30 |--------------------| 3.3% train_global_loss: 936319.6875; train_optim_loss: 936319.6875
# Epoch 2/30 |█-------------------| 6.7% train_global_loss: 926710.2500; train_optim_loss: 926710.2500
# Epoch 3/30 |██------------------| 10.0% train_global_loss: 921353.6875; train_optim_loss: 921353.6875
# Epoch 4/30 |██------------------| 13.3% train_global_loss: 917989.4375; train_optim_loss: 917989.4375
# Epoch 5/30 |███-----------------| 16.7% train_global_loss: 915546.1875; train_optim_loss: 915546.1875
# Epoch 6/30 |████----------------| 20.0% train_global_loss: 913517.7500; train_optim_loss: 913517.7500
# Epoch 7/30 |████----------------| 23.3% train_global_loss: 911640.3125; train_optim_loss: 911640.3125
# Epoch 8/30 |█████---------------| 26.7% train_global_loss: 909856.6250; train_optim_loss: 909856.6250
# Epoch 9/30 |██████--------------| 30.0% train_global_loss: 908124.0000; train_optim_loss: 908124.0000
# Epoch 10/30 |██████--------------| 33.3% train_global_loss: 906428.7500; train_optim_loss: 906428.7500
# Epoch 11/30 |███████-------------| 36.7% train_global_loss: 904820.3750; train_optim_loss: 904820.3750
# Epoch 12/30 |████████------------| 40.0% train_global_loss: 903271.2500; train_optim_loss: 903271.2500
# Epoch 13/30 |████████------------| 43.3% train_global_loss: 901753.3125; train_optim_loss: 901753.3125
# Epoch 14/30 |█████████-----------| 46.7% train_global_loss: 900274.8125; train_optim_loss: 900274.8125
# Epoch 15/30 |██████████----------| 50.0% train_global_loss: 898786.1250; train_optim_loss: 898786.1250
# Epoch 16/30 |██████████----------| 53.3% train_global_loss: 897296.4375; train_optim_loss: 897296.4375
# Epoch 17/30 |███████████---------| 56.7% train_global_loss: 895792.5000; train_optim_loss: 895792.5000
# Epoch 18/30 |████████████--------| 60.0% train_global_loss: 894292.1875; train_optim_loss: 894292.1875
# Epoch 19/30 |████████████--------| 63.3% train_global_loss: 892810.6250; train_optim_loss: 892810.6250
# Epoch 20/30 |█████████████-------| 66.7% train_global_loss: 891360.3125; train_optim_loss: 891360.3125
# Epoch 21/30 |██████████████------| 70.0% train_global_loss: 889923.2500; train_optim_loss: 889923.2500
# Epoch 22/30 |██████████████------| 73.3% train_global_loss: 888499.8750; train_optim_loss: 888499.8750
# Epoch 23/30 |███████████████-----| 76.7% train_global_loss: 887074.3750; train_optim_loss: 887074.3750
# Epoch 24/30 |████████████████----| 80.0% train_global_loss: 885648.0625; train_optim_loss: 885648.0625
# Epoch 25/30 |████████████████----| 83.3% train_global_loss: 884237.5000; train_optim_loss: 884237.5000
# Epoch 26/30 |█████████████████---| 86.7% train_global_loss: 882828.0625; train_optim_loss: 882828.0625
# Epoch 27/30 |██████████████████--| 90.0% train_global_loss: 881409.5000; train_optim_loss: 881409.5000
# Epoch 28/30 |██████████████████--| 93.3% train_global_loss: 880003.1250; train_optim_loss: 880003.1250
# Epoch 29/30 |███████████████████-| 96.7% train_global_loss: 878588.8125; train_optim_loss: 878588.8125
# Epoch 30/30 |████████████████████| 100.0% train_global_loss: 877188.8125; train_optim_loss: 877188.8125
#
# Model training finished after 0 min 11 sec.
# Using best model state, which was in epoch 30.
# ✅ lambda_edge_recon=10000.0 | lambda_gene_expr_recon=25.0 | ARI=0.4690 | valid spots=4371
#
# ==========================================================================================
# 🚀 [9/35] 参数组合: lambda_edge_recon=10000.0, lambda_gene_expr_recon=50.0
# ==========================================================================================
# --- INITIALIZING NEW NETWORK MODULE: VARIATIONAL GENE PROGRAM GRAPH AUTOENCODER ---
# LOSS -> include_edge_recon_loss: True, include_gene_expr_recon_loss: True, rna_recon_loss: nb
# NODE LABEL METHOD -> one-hop-norm
# ACTIVE GP THRESHOLD RATIO -> 0.01
# LOG VARIATIONAL -> True
# ONE HOP GCN NORM RNA NODE LABEL AGGREGATOR
# ENCODER -> n_input: 3047, n_cat_covariates_embed_input: 0, n_hidden: 1325, n_latent: 1225, n_addon_latent: 100, n_fc_layers: 1, n_layers: 1, conv_layer: gcnconv, n_attention_heads: 0, dropout_rate: 0.0,
# COSINE SIM GRAPH DECODER -> dropout_rate: 0.0
# MASKED TARGET RNA DECODER -> n_prior_gp_input: 1225, n_addon_gp_input: 100, n_cat_covariates_embed_input: 0, n_output: 3047
# MASKED SOURCE RNA DECODER -> n_prior_gp_input: 1225, n_addon_gp_input: 100, n_cat_covariates_embed_input: 0, n_output: 3047
#   全量 nodes: 4371
#   全量 edges: 34968
#   lambda_edge_recon = 10000.0
#   lambda_gene_expr_recon = 50.0
#
# --- INITIALIZING TRAINER ---
# Number of training nodes: 4371
# Number of validation nodes: 0
# Number of training edges: 17477
# Number of validation edges: 0
# Edge batch size: 34968
# Node batch size: 4371
#
# --- MODEL TRAINING ---
# Epoch 1/30 |--------------------| 3.3% train_global_loss: 1172849.0000; train_optim_loss: 1172849.0000
# Epoch 2/30 |█-------------------| 6.7% train_global_loss: 1155061.1250; train_optim_loss: 1155061.1250
# Epoch 3/30 |██------------------| 10.0% train_global_loss: 1145721.8750; train_optim_loss: 1145721.8750
# Epoch 4/30 |██------------------| 13.3% train_global_loss: 1140321.2500; train_optim_loss: 1140321.2500
# Epoch 5/30 |███-----------------| 16.7% train_global_loss: 1136739.5000; train_optim_loss: 1136739.5000
# Epoch 6/30 |████----------------| 20.0% train_global_loss: 1133973.0000; train_optim_loss: 1133973.0000
# Epoch 7/30 |████----------------| 23.3% train_global_loss: 1131506.5000; train_optim_loss: 1131506.5000
# Epoch 8/30 |█████---------------| 26.7% train_global_loss: 1129231.8750; train_optim_loss: 1129231.8750
# Epoch 9/30 |██████--------------| 30.0% train_global_loss: 1127070.5000; train_optim_loss: 1127070.5000
# Epoch 10/30 |██████--------------| 33.3% train_global_loss: 1125002.1250; train_optim_loss: 1125002.1250
# Epoch 11/30 |███████-------------| 36.7% train_global_loss: 1123114.0000; train_optim_loss: 1123114.0000
# Epoch 12/30 |████████------------| 40.0% train_global_loss: 1121356.2500; train_optim_loss: 1121356.2500
# Epoch 13/30 |████████------------| 43.3% train_global_loss: 1119668.7500; train_optim_loss: 1119668.7500
# Epoch 14/30 |█████████-----------| 46.7% train_global_loss: 1118055.8750; train_optim_loss: 1118055.8750
# Epoch 15/30 |██████████----------| 50.0% train_global_loss: 1116419.6250; train_optim_loss: 1116419.6250
# Epoch 16/30 |██████████----------| 53.3% train_global_loss: 1114773.5000; train_optim_loss: 1114773.5000
# Epoch 17/30 |███████████---------| 56.7% train_global_loss: 1113090.2500; train_optim_loss: 1113090.2500
# Epoch 18/30 |████████████--------| 60.0% train_global_loss: 1111407.7500; train_optim_loss: 1111407.7500
# Epoch 19/30 |████████████--------| 63.3% train_global_loss: 1109756.0000; train_optim_loss: 1109756.0000
# Epoch 20/30 |█████████████-------| 66.7% train_global_loss: 1108154.3750; train_optim_loss: 1108154.3750
# Epoch 21/30 |██████████████------| 70.0% train_global_loss: 1106575.2500; train_optim_loss: 1106575.2500
# Epoch 22/30 |██████████████------| 73.3% train_global_loss: 1105012.5000; train_optim_loss: 1105012.5000
# Epoch 23/30 |███████████████-----| 76.7% train_global_loss: 1103443.2500; train_optim_loss: 1103443.2500
# Epoch 24/30 |████████████████----| 80.0% train_global_loss: 1101865.1250; train_optim_loss: 1101865.1250
# Epoch 25/30 |████████████████----| 83.3% train_global_loss: 1100309.0000; train_optim_loss: 1100309.0000
# Epoch 26/30 |█████████████████---| 86.7% train_global_loss: 1098755.1250; train_optim_loss: 1098755.1250
# Epoch 27/30 |██████████████████--| 90.0% train_global_loss: 1097184.5000; train_optim_loss: 1097184.5000
# Epoch 28/30 |██████████████████--| 93.3% train_global_loss: 1095629.7500; train_optim_loss: 1095629.7500
# Epoch 29/30 |███████████████████-| 96.7% train_global_loss: 1094058.3750; train_optim_loss: 1094058.3750
# Epoch 30/30 |████████████████████| 100.0% train_global_loss: 1092511.7500; train_optim_loss: 1092511.7500
#
# Model training finished after 0 min 12 sec.
# Using best model state, which was in epoch 30.
# ✅ lambda_edge_recon=10000.0 | lambda_gene_expr_recon=50.0 | ARI=0.5030 | valid spots=4371
#
# ==========================================================================================
# 🚀 [10/35] 参数组合: lambda_edge_recon=10000.0, lambda_gene_expr_recon=100.0
# ==========================================================================================
# --- INITIALIZING NEW NETWORK MODULE: VARIATIONAL GENE PROGRAM GRAPH AUTOENCODER ---
# LOSS -> include_edge_recon_loss: True, include_gene_expr_recon_loss: True, rna_recon_loss: nb
# NODE LABEL METHOD -> one-hop-norm
# ACTIVE GP THRESHOLD RATIO -> 0.01
# LOG VARIATIONAL -> True
# ONE HOP GCN NORM RNA NODE LABEL AGGREGATOR
# ENCODER -> n_input: 3047, n_cat_covariates_embed_input: 0, n_hidden: 1325, n_latent: 1225, n_addon_latent: 100, n_fc_layers: 1, n_layers: 1, conv_layer: gcnconv, n_attention_heads: 0, dropout_rate: 0.0,
# COSINE SIM GRAPH DECODER -> dropout_rate: 0.0
# MASKED TARGET RNA DECODER -> n_prior_gp_input: 1225, n_addon_gp_input: 100, n_cat_covariates_embed_input: 0, n_output: 3047
# MASKED SOURCE RNA DECODER -> n_prior_gp_input: 1225, n_addon_gp_input: 100, n_cat_covariates_embed_input: 0, n_output: 3047
#   全量 nodes: 4371
#   全量 edges: 34968
#   lambda_edge_recon = 10000.0
#   lambda_gene_expr_recon = 100.0
#
# --- INITIALIZING TRAINER ---
# Number of training nodes: 4371
# Number of validation nodes: 0
# Number of training edges: 17477
# Number of validation edges: 0
# Edge batch size: 34968
# Node batch size: 4371
#
# --- MODEL TRAINING ---
# Epoch 1/30 |--------------------| 3.3% train_global_loss: 1645907.5000; train_optim_loss: 1645907.5000
# Epoch 2/30 |█-------------------| 6.7% train_global_loss: 1611732.5000; train_optim_loss: 1611732.5000
# Epoch 3/30 |██------------------| 10.0% train_global_loss: 1594436.5000; train_optim_loss: 1594436.5000
# Epoch 4/30 |██------------------| 13.3% train_global_loss: 1584969.7500; train_optim_loss: 1584969.7500
# Epoch 5/30 |███-----------------| 16.7% train_global_loss: 1579093.0000; train_optim_loss: 1579093.0000
# Epoch 6/30 |████----------------| 20.0% train_global_loss: 1574795.2500; train_optim_loss: 1574795.2500
# Epoch 7/30 |████----------------| 23.3% train_global_loss: 1571070.7500; train_optim_loss: 1571070.7500
# Epoch 8/30 |█████---------------| 26.7% train_global_loss: 1567726.0000; train_optim_loss: 1567726.0000
# Epoch 9/30 |██████--------------| 30.0% train_global_loss: 1564621.1250; train_optim_loss: 1564621.1250
# Epoch 10/30 |██████--------------| 33.3% train_global_loss: 1561716.5000; train_optim_loss: 1561716.5000
# Epoch 11/30 |███████-------------| 36.7% train_global_loss: 1559173.5000; train_optim_loss: 1559173.5000
# Epoch 12/30 |████████------------| 40.0% train_global_loss: 1556895.0000; train_optim_loss: 1556895.0000
# Epoch 13/30 |████████------------| 43.3% train_global_loss: 1554756.3750; train_optim_loss: 1554756.3750
# Epoch 14/30 |█████████-----------| 46.7% train_global_loss: 1552749.3750; train_optim_loss: 1552749.3750
# Epoch 15/30 |██████████----------| 50.0% train_global_loss: 1550679.5000; train_optim_loss: 1550679.5000
# Epoch 16/30 |██████████----------| 53.3% train_global_loss: 1548579.0000; train_optim_loss: 1548579.0000
# Epoch 17/30 |███████████---------| 56.7% train_global_loss: 1546396.7500; train_optim_loss: 1546396.7500
# Epoch 18/30 |████████████--------| 60.0% train_global_loss: 1544211.1250; train_optim_loss: 1544211.1250
# Epoch 19/30 |████████████--------| 63.3% train_global_loss: 1542077.7500; train_optim_loss: 1542077.7500
# Epoch 20/30 |█████████████-------| 66.7% train_global_loss: 1540021.7500; train_optim_loss: 1540021.7500
# Epoch 21/30 |██████████████------| 70.0% train_global_loss: 1537998.3750; train_optim_loss: 1537998.3750
# Epoch 22/30 |██████████████------| 73.3% train_global_loss: 1535979.5000; train_optim_loss: 1535979.5000
# Epoch 23/30 |███████████████-----| 76.7% train_global_loss: 1533931.1250; train_optim_loss: 1533931.1250
# Epoch 24/30 |████████████████----| 80.0% train_global_loss: 1531852.8750; train_optim_loss: 1531852.8750
# Epoch 25/30 |████████████████----| 83.3% train_global_loss: 1529792.1250; train_optim_loss: 1529792.1250
# Epoch 26/30 |█████████████████---| 86.7% train_global_loss: 1527722.2500; train_optim_loss: 1527722.2500
# Epoch 27/30 |██████████████████--| 90.0% train_global_loss: 1525610.0000; train_optim_loss: 1525610.0000
# Epoch 28/30 |██████████████████--| 93.3% train_global_loss: 1523505.5000; train_optim_loss: 1523505.5000
# Epoch 29/30 |███████████████████-| 96.7% train_global_loss: 1521359.5000; train_optim_loss: 1521359.5000
# Epoch 30/30 |████████████████████| 100.0% train_global_loss: 1519249.1250; train_optim_loss: 1519249.1250
#
# Model training finished after 0 min 11 sec.
# Using best model state, which was in epoch 30.
# ✅ lambda_edge_recon=10000.0 | lambda_gene_expr_recon=100.0 | ARI=0.4970 | valid spots=4371
#
# ==========================================================================================
# 🚀 [11/35] 参数组合: lambda_edge_recon=10000.0, lambda_gene_expr_recon=150.0
# ==========================================================================================
# --- INITIALIZING NEW NETWORK MODULE: VARIATIONAL GENE PROGRAM GRAPH AUTOENCODER ---
# LOSS -> include_edge_recon_loss: True, include_gene_expr_recon_loss: True, rna_recon_loss: nb
# NODE LABEL METHOD -> one-hop-norm
# ACTIVE GP THRESHOLD RATIO -> 0.01
# LOG VARIATIONAL -> True
# ONE HOP GCN NORM RNA NODE LABEL AGGREGATOR
# ...
# COSINE SIM GRAPH DECODER -> dropout_rate: 0.0
# MASKED TARGET RNA DECODER -> n_prior_gp_input: 1225, n_addon_gp_input: 100, n_cat_covariates_embed_input: 0, n_output: 3047
# MASKED SOURCE RNA DECODER -> n_prior_gp_input: 1225, n_addon_gp_input: 100, n_cat_covariates_embed_input: 0, n_output: 3047
#   全量 nodes: 4371
#   全量 edges: 34968
#   lambda_edge_recon = 10000000.0
#   lambda_gene_expr_recon = 250.0
#
# --- INITIALIZING TRAINER ---
# Number of training nodes: 4371
# Number of validation nodes: 0
# Number of training edges: 17477
# Number of validation edges: 0
# Edge batch size: 34968
# Node batch size: 4371
#
# --- MODEL TRAINING ---
# Epoch 1/30 |--------------------| 3.3% train_global_loss: 9975239.0000; train_optim_loss: 9975239.0000
# Epoch 2/30 |█-------------------| 6.7% train_global_loss: 9888727.0000; train_optim_loss: 9888727.0000
# Epoch 3/30 |██------------------| 10.0% train_global_loss: 9843181.0000; train_optim_loss: 9843181.0000
# Epoch 4/30 |██------------------| 13.3% train_global_loss: 9821599.0000; train_optim_loss: 9821599.0000
# Epoch 5/30 |███-----------------| 16.7% train_global_loss: 9807348.0000; train_optim_loss: 9807348.0000
# Epoch 6/30 |████----------------| 20.0% train_global_loss: 9796699.0000; train_optim_loss: 9796699.0000
# Epoch 7/30 |████----------------| 23.3% train_global_loss: 9785469.0000; train_optim_loss: 9785469.0000
# Epoch 8/30 |█████---------------| 26.7% train_global_loss: 9775464.0000; train_optim_loss: 9775464.0000
# Epoch 9/30 |██████--------------| 30.0% train_global_loss: 9766288.0000; train_optim_loss: 9766288.0000
# Epoch 10/30 |██████--------------| 33.3% train_global_loss: 9751113.0000; train_optim_loss: 9751113.0000
# Epoch 11/30 |███████-------------| 36.7% train_global_loss: 9739308.0000; train_optim_loss: 9739308.0000
# Epoch 12/30 |████████------------| 40.0% train_global_loss: 9726270.0000; train_optim_loss: 9726270.0000
# Epoch 13/30 |████████------------| 43.3% train_global_loss: 9706915.0000; train_optim_loss: 9706915.0000
# Epoch 14/30 |█████████-----------| 46.7% train_global_loss: 9681630.0000; train_optim_loss: 9681630.0000
# Epoch 15/30 |██████████----------| 50.0% train_global_loss: 9661398.0000; train_optim_loss: 9661398.0000
# Epoch 16/30 |██████████----------| 53.3% train_global_loss: 9631940.0000; train_optim_loss: 9631940.0000
# Epoch 17/30 |███████████---------| 56.7% train_global_loss: 9594620.0000; train_optim_loss: 9594620.0000
# Epoch 18/30 |████████████--------| 60.0% train_global_loss: 9556537.0000; train_optim_loss: 9556537.0000
# Epoch 19/30 |████████████--------| 63.3% train_global_loss: 9495543.0000; train_optim_loss: 9495543.0000
# Epoch 20/30 |█████████████-------| 66.7% train_global_loss: 9454177.0000; train_optim_loss: 9454177.0000
# Epoch 21/30 |██████████████------| 70.0% train_global_loss: 9392067.0000; train_optim_loss: 9392067.0000
# Epoch 22/30 |██████████████------| 73.3% train_global_loss: 9320906.0000; train_optim_loss: 9320906.0000
# Epoch 23/30 |███████████████-----| 76.7% train_global_loss: 9231669.0000; train_optim_loss: 9231669.0000
# Epoch 24/30 |████████████████----| 80.0% train_global_loss: 9160430.0000; train_optim_loss: 9160430.0000
# Epoch 25/30 |████████████████----| 83.3% train_global_loss: 9073871.0000; train_optim_loss: 9073871.0000
# Epoch 26/30 |█████████████████---| 86.7% train_global_loss: 8988329.0000; train_optim_loss: 8988329.0000
# Epoch 27/30 |██████████████████--| 90.0% train_global_loss: 8895830.0000; train_optim_loss: 8895830.0000
# Epoch 28/30 |██████████████████--| 93.3% train_global_loss: 8827408.0000; train_optim_loss: 8827408.0000
# Epoch 29/30 |███████████████████-| 96.7% train_global_loss: 8798870.0000; train_optim_loss: 8798870.0000
# Epoch 30/30 |████████████████████| 100.0% train_global_loss: 8734760.0000; train_optim_loss: 8734760.0000
#
# Model training finished after 0 min 46 sec.
# Using best model state, which was in epoch 30.
# ✅ lambda_edge_recon=10000000.0 | lambda_gene_expr_recon=250.0 | ARI=0.5150 | valid spots=4371
#
# ==========================================================================================
# 🚀 [35/35] 参数组合: lambda_edge_recon=10000000.0, lambda_gene_expr_recon=400.0
# ==========================================================================================
# --- INITIALIZING NEW NETWORK MODULE: VARIATIONAL GENE PROGRAM GRAPH AUTOENCODER ---
# LOSS -> include_edge_recon_loss: True, include_gene_expr_recon_loss: True, rna_recon_loss: nb
# NODE LABEL METHOD -> one-hop-norm
# ACTIVE GP THRESHOLD RATIO -> 0.01
# LOG VARIATIONAL -> True
# ONE HOP GCN NORM RNA NODE LABEL AGGREGATOR
# ENCODER -> n_input: 3047, n_cat_covariates_embed_input: 0, n_hidden: 1325, n_latent: 1225, n_addon_latent: 100, n_fc_layers: 1, n_layers: 1, conv_layer: gcnconv, n_attention_heads: 0, dropout_rate: 0.0,
# COSINE SIM GRAPH DECODER -> dropout_rate: 0.0
# MASKED TARGET RNA DECODER -> n_prior_gp_input: 1225, n_addon_gp_input: 100, n_cat_covariates_embed_input: 0, n_output: 3047
# MASKED SOURCE RNA DECODER -> n_prior_gp_input: 1225, n_addon_gp_input: 100, n_cat_covariates_embed_input: 0, n_output: 3047
#   全量 nodes: 4371
#   全量 edges: 34968
#   lambda_edge_recon = 10000000.0
#   lambda_gene_expr_recon = 400.0
#
# --- INITIALIZING TRAINER ---
# Number of training nodes: 4371
# Number of validation nodes: 0
# Number of training edges: 17477
# Number of validation edges: 0
# Edge batch size: 34968
# Node batch size: 4371
#
# --- MODEL TRAINING ---
# Epoch 1/30 |--------------------| 3.3% train_global_loss: 11394414.0000; train_optim_loss: 11394414.0000
# Epoch 2/30 |█-------------------| 6.7% train_global_loss: 11258660.0000; train_optim_loss: 11258660.0000
# Epoch 3/30 |██------------------| 10.0% train_global_loss: 11189383.0000; train_optim_loss: 11189383.0000
# Epoch 4/30 |██------------------| 13.3% train_global_loss: 11156067.0000; train_optim_loss: 11156067.0000
# Epoch 5/30 |███-----------------| 16.7% train_global_loss: 11135452.0000; train_optim_loss: 11135452.0000
# Epoch 6/30 |████----------------| 20.0% train_global_loss: 11120977.0000; train_optim_loss: 11120977.0000
# Epoch 7/30 |████----------------| 23.3% train_global_loss: 11107103.0000; train_optim_loss: 11107103.0000
# Epoch 8/30 |█████---------------| 26.7% train_global_loss: 11095505.0000; train_optim_loss: 11095505.0000
# Epoch 9/30 |██████--------------| 30.0% train_global_loss: 11085542.0000; train_optim_loss: 11085542.0000
# Epoch 10/30 |██████--------------| 33.3% train_global_loss: 11070619.0000; train_optim_loss: 11070619.0000
# Epoch 11/30 |███████-------------| 36.7% train_global_loss: 11060527.0000; train_optim_loss: 11060527.0000
# Epoch 12/30 |████████------------| 40.0% train_global_loss: 11049615.0000; train_optim_loss: 11049615.0000
# Epoch 13/30 |████████------------| 43.3% train_global_loss: 11033817.0000; train_optim_loss: 11033817.0000
# Epoch 14/30 |█████████-----------| 46.7% train_global_loss: 11015475.0000; train_optim_loss: 11015475.0000
# Epoch 15/30 |██████████----------| 50.0% train_global_loss: 11000082.0000; train_optim_loss: 11000082.0000
# Epoch 16/30 |██████████----------| 53.3% train_global_loss: 10978154.0000; train_optim_loss: 10978154.0000
# Epoch 17/30 |███████████---------| 56.7% train_global_loss: 10951658.0000; train_optim_loss: 10951658.0000
# Epoch 18/30 |████████████--------| 60.0% train_global_loss: 10922686.0000; train_optim_loss: 10922686.0000
# Epoch 19/30 |████████████--------| 63.3% train_global_loss: 10880096.0000; train_optim_loss: 10880096.0000
# Epoch 20/30 |█████████████-------| 66.7% train_global_loss: 10851144.0000; train_optim_loss: 10851144.0000
# Epoch 21/30 |██████████████------| 70.0% train_global_loss: 10803180.0000; train_optim_loss: 10803180.0000
# Epoch 22/30 |██████████████------| 73.3% train_global_loss: 10750144.0000; train_optim_loss: 10750144.0000
# Epoch 23/30 |███████████████-----| 76.7% train_global_loss: 10681948.0000; train_optim_loss: 10681948.0000
# Epoch 24/30 |████████████████----| 80.0% train_global_loss: 10621000.0000; train_optim_loss: 10621000.0000
# Epoch 25/30 |████████████████----| 83.3% train_global_loss: 10546100.0000; train_optim_loss: 10546100.0000
# Epoch 26/30 |█████████████████---| 86.7% train_global_loss: 10466978.0000; train_optim_loss: 10466978.0000
# Epoch 27/30 |██████████████████--| 90.0% train_global_loss: 10371285.0000; train_optim_loss: 10371285.0000
# Epoch 28/30 |██████████████████--| 93.3% train_global_loss: 10292336.0000; train_optim_loss: 10292336.0000
# Epoch 29/30 |███████████████████-| 96.7% train_global_loss: 10234303.0000; train_optim_loss: 10234303.0000
# Epoch 30/30 |████████████████████| 100.0% train_global_loss: 10151766.0000; train_optim_loss: 10151766.0000
#
# Model training finished after 1 min 18 sec.
# Using best model state, which was in epoch 30.
# ✅ lambda_edge_recon=10000000.0 | lambda_gene_expr_recon=400.0 | ARI=0.5058 | valid spots=4371
#
# ==========================================================================================
# 🎉 lambda_edge_recon × lambda_gene_expr_recon 参数组合分析完成！
# ✅ 长表 CSV: /home/zhangjunyi/xiangmu/nichecompass-main/outputs/case/parameter_analysis/edge_recon_And_gene_expr_recon/Human_Prostate_Cancer/parameter_sensitivity_lambda_edge_recon_AND_lambda_gene_expr_recon_ARI.csv
# ✅ 热图矩阵 CSV: /home/zhangjunyi/xiangmu/nichecompass-main/outputs/case/parameter_analysis/edge_recon_And_gene_expr_recon/Human_Prostate_Cancer/ARI_heatmap_matrix_lambda_edge_recon_AND_lambda_gene_expr_recon.csv
# ==========================================================================================
#     lambda_edge_recon  lambda_gene_expr_recon       ARI  valid_spots_for_ARI  \
# 0              1000.0                    25.0  0.487938                 4371
# 1              1000.0                    50.0  0.510132                 4371
# 2              1000.0                   100.0  0.495823                 4371
# 3              1000.0                   150.0  0.510710                 4371
# 4              1000.0                   200.0  0.493204                 4371
# 5              1000.0                   250.0  0.503518                 4371
# 6              1000.0                   400.0  0.497775                 4371
# 7             10000.0                    25.0  0.468970                 4371
# 8             10000.0                    50.0  0.502952                 4371
# 9             10000.0                   100.0  0.497044                 4371
# 10            10000.0                   150.0  0.499691                 4371
# 11            10000.0                   200.0  0.506811                 4371
# 12            10000.0                   250.0  0.502922                 4371
# 13            10000.0                   400.0  0.504283                 4371
# 14           100000.0                    25.0  0.527755                 4371
# 15           100000.0                    50.0  0.465786                 4371
# 16           100000.0                   100.0  0.516032                 4371
# 17           100000.0                   150.0  0.510132                 4371
# 18           100000.0                   200.0  0.500352                 4371
# 19           100000.0                   250.0  0.492617                 4371
# 20           100000.0                   400.0  0.504931                 4371
# 21          1000000.0                    25.0  0.532812                 4371
# 22          1000000.0                    50.0  0.521633                 4371
# 23          1000000.0                   100.0  0.517716                 4371
# 24          1000000.0                   150.0  0.533101                 4371
# 25          1000000.0                   200.0  0.524432                 4371
# 26          1000000.0                   250.0  0.519192                 4371
# 27          1000000.0                   400.0  0.510761                 4371
# 28         10000000.0                    25.0  0.516292                 4371
# 29         10000000.0                    50.0  0.535501                 4371
# 30         10000000.0                   100.0  0.538883                 4371
# 31         10000000.0                   150.0  0.514985                 4371
# 32         10000000.0                   200.0  0.513042                 4371
# 33         10000000.0                   250.0  0.514989                 4371
# 34         10000000.0                   400.0  0.505801                 4371
#
#         pathology_column                                          h5ad_path
# 0   Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 1   Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 2   Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 3   Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 4   Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 5   Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 6   Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 7   Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 8   Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 9   Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 10  Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 11  Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 12  Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 13  Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 14  Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 15  Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 16  Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 17  Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 18  Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 19  Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 20  Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 21  Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 22  Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 23  Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 24  Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 25  Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 26  Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 27  Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 28  Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 29  Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 30  Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 31  Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 32  Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 33  Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 34  Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# lambda_gene_expr_recon     25.0      50.0      100.0     150.0     200.0  \
# lambda_edge_recon
# 1000.0                  0.487938  0.510132  0.495823  0.510710  0.493204
# 10000.0                 0.468970  0.502952  0.497044  0.499691  0.506811
# 100000.0                0.527755  0.465786  0.516032  0.510132  0.500352
# 1000000.0               0.532812  0.521633  0.517716  0.533101  0.524432
# 10000000.0              0.516292  0.535501  0.538883  0.514985  0.513042
#
# lambda_gene_expr_recon     250.0     400.0
# lambda_edge_recon
# 1000.0                  0.503518  0.497775
# 10000.0                 0.502922  0.504283
# 100000.0                0.492617  0.504931
# 1000000.0               0.519192  0.510761
# 10000000.0              0.514989  0.505801

# %%
# =========================================================
# Cell 4: 读取结果 CSV 并绘制 lambda_edge_recon × lambda_gene_expr_recon 的 ARI 热图
# =========================================================

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

csv_path = os.path.join(
    CONFIG["save_root"],
    "parameter_sensitivity_lambda_edge_recon_AND_lambda_gene_expr_recon_ARI.csv"
)

results_df = pd.read_csv(csv_path)

display(results_df)

matrix_df = results_df.pivot(
    index="lambda_edge_recon",
    columns="lambda_gene_expr_recon",
    values="ARI"
).sort_index(axis=0).sort_index(axis=1)

fig, ax = plt.subplots(figsize=(9, 6))

im = ax.imshow(matrix_df.values, aspect="auto", cmap="YlGnBu")

ax.set_xticks(np.arange(matrix_df.shape[1]))
ax.set_yticks(np.arange(matrix_df.shape[0]))
ax.set_xticklabels([f"{x:g}" for x in matrix_df.columns])
ax.set_yticklabels([f"{y:g}" for y in matrix_df.index])

ax.set_xlabel("lambda_gene_expr_recon")
ax.set_ylabel("lambda_edge_recon")
ax.set_title(
    f"ARI under different parameter combinations\n"
    f"{CONFIG['dataset_name']}"
)

for i in range(matrix_df.shape[0]):
    for j in range(matrix_df.shape[1]):
        val = matrix_df.values[i, j]
        if pd.notna(val):
            ax.text(j, i, f"{val:.3f}", ha="center", va="center", fontsize=9)

cbar = plt.colorbar(im, ax=ax)
cbar.set_label("ARI Score")

plt.tight_layout()

fig_path = os.path.join(
    CONFIG["save_root"],
    "ARI_heatmap_lambda_edge_recon_AND_lambda_gene_expr_recon.png"
)
plt.savefig(fig_path, dpi=300, bbox_inches="tight")
plt.show()

matrix_csv_path = os.path.join(
    CONFIG["save_root"],
    "ARI_heatmap_matrix_lambda_edge_recon_AND_lambda_gene_expr_recon.csv"
)
matrix_df.to_csv(matrix_csv_path, encoding="utf-8-sig")

print(f"✅ ARI 热图已保存至: {fig_path}")
print(f"✅ ARI 热图矩阵已保存至: {matrix_csv_path}")
# Out:
#     lambda_edge_recon  lambda_gene_expr_recon       ARI  valid_spots_for_ARI  \
# 0              1000.0                    25.0  0.487938                 4371
# 1              1000.0                    50.0  0.510132                 4371
# 2              1000.0                   100.0  0.495823                 4371
# 3              1000.0                   150.0  0.510710                 4371
# 4              1000.0                   200.0  0.493204                 4371
# 5              1000.0                   250.0  0.503518                 4371
# 6              1000.0                   400.0  0.497775                 4371
# 7             10000.0                    25.0  0.468970                 4371
# 8             10000.0                    50.0  0.502952                 4371
# 9             10000.0                   100.0  0.497044                 4371
# 10            10000.0                   150.0  0.499691                 4371
# 11            10000.0                   200.0  0.506811                 4371
# 12            10000.0                   250.0  0.502922                 4371
# 13            10000.0                   400.0  0.504283                 4371
# 14           100000.0                    25.0  0.527755                 4371
# 15           100000.0                    50.0  0.465786                 4371
# 16           100000.0                   100.0  0.516032                 4371
# 17           100000.0                   150.0  0.510132                 4371
# 18           100000.0                   200.0  0.500352                 4371
# 19           100000.0                   250.0  0.492617                 4371
# 20           100000.0                   400.0  0.504931                 4371
# 21          1000000.0                    25.0  0.532812                 4371
# 22          1000000.0                    50.0  0.521633                 4371
# 23          1000000.0                   100.0  0.517716                 4371
# 24          1000000.0                   150.0  0.533101                 4371
# 25          1000000.0                   200.0  0.524432                 4371
# 26          1000000.0                   250.0  0.519192                 4371
# 27          1000000.0                   400.0  0.510761                 4371
# 28         10000000.0                    25.0  0.516292                 4371
# 29         10000000.0                    50.0  0.535501                 4371
# 30         10000000.0                   100.0  0.538883                 4371
# 31         10000000.0                   150.0  0.514985                 4371
# 32         10000000.0                   200.0  0.513042                 4371
# 33         10000000.0                   250.0  0.514989                 4371
# 34         10000000.0                   400.0  0.505801                 4371
#
#         pathology_column                                          h5ad_path
# 0   Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 1   Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 2   Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 3   Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 4   Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 5   Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 6   Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 7   Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 8   Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 9   Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 10  Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 11  Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 12  Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 13  Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 14  Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 15  Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 16  Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 17  Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 18  Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 19  Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 20  Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 21  Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 22  Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 23  Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 24  Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 25  Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 26  Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 27  Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 28  Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 29  Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 30  Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 31  Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 32  Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 33  Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# 34  Pathology_Annotation  /home/zhangjunyi/xiangmu/nichecompass-main/out...
# ✅ ARI 热图已保存至: /home/zhangjunyi/xiangmu/nichecompass-main/outputs/case/parameter_analysis/edge_recon_And_gene_expr_recon/Human_Prostate_Cancer/ARI_heatmap_lambda_edge_recon_AND_lambda_gene_expr_recon.png
# ✅ ARI 热图矩阵已保存至: /home/zhangjunyi/xiangmu/nichecompass-main/outputs/case/parameter_analysis/edge_recon_And_gene_expr_recon/Human_Prostate_Cancer/ARI_heatmap_matrix_lambda_edge_recon_AND_lambda_gene_expr_recon.csv
